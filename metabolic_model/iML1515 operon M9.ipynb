# %% [markdown]
# Load of model from smbl file, convert into excel and exploration

# %%
import cobra
from cobra.io import read_sbml_model
model = read_sbml_model("iML1515.xml")
print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))
# Out:
# 2712
# 1877
# 1516

# %%
from importExcelModel import *
cobrapy_to_excel(model,"iML1515.xlsx")

# %% [markdown]
# Write all metabolic genes to a text file to use as the functional enrichment backgorund

# %%
with open('metabolic genes.txt', 'w') as f:
    for i in model.genes:
        f.write(i.id)
        f.write('\n')

# %% [markdown]
# Saving/Restoring a Jupyter Notebook Session

# %% [markdown]
# #Save
# import dill
# dill.dump_session('iML1515_operon_M9_env.db')

# %% [markdown]
# #Restore
# import dill
# dill.load_session("iML1515_operon_M9_env.db")

# %% [markdown]
# LB media model

# %%
M9_medium=model.medium
print(M9_medium)
model_M9=model.copy()
model_M9.medium=M9_medium
model_M9.optimize()
# Out:
# {'EX_pi_e': 1000.0, 'EX_co2_e': 1000.0, 'EX_fe3_e': 1000.0, 'EX_h_e': 1000.0, 'EX_mn2_e': 1000.0, 'EX_fe2_e': 1000.0, 'EX_glc__D_e': 10.0, 'EX_zn2_e': 1000.0, 'EX_mg2_e': 1000.0, 'EX_ca2_e': 1000.0, 'EX_ni2_e': 1000.0, 'EX_cu2_e': 1000.0, 'EX_sel_e': 1000.0, 'EX_cobalt2_e': 1000.0, 'EX_h2o_e': 1000.0, 'EX_mobd_e': 1000.0, 'EX_so4_e': 1000.0, 'EX_nh4_e': 1000.0, 'EX_k_e': 1000.0, 'EX_na1_e': 1000.0, 'EX_cl_e': 1000.0, 'EX_o2_e': 1000.0, 'EX_tungs_e': 1000.0, 'EX_slnt_e': 1000.0}
# <Solution 0.877 at 0x2315a9cfed0>

# %% [markdown]
# Extracting reactions associated to differentially methylated genes

# %%
#Forward single reactions to file and variable
import re

def gene_read(path):
    gene_list=[]
    with open (path,"r") as file:
        for line in file:
            line_elements = line.strip().split(',')
            gene_list.extend(line_elements)
    return(gene_list)


def gene_reaction_list (path):
    gene_list=[]
    with open (path,"r") as file:
        for line in file:
            line_elements = line.strip().split(',')
            gene_list.extend(line_elements)
    def gene_to_reaction(gene_list):
        associated_reactions = []
        for gene_id in gene_list:
            gene_obj = model.genes.get_by_id(gene_id)
            reactions = [reaction.id for reaction in gene_obj.reactions]
            associated_reactions.extend(reactions)
        return(associated_reactions)
    reactions= list(set(gene_to_reaction(gene_list)))
    start_index = path.index("_genelist")
    end_index = path.index("operon_")+len("operon_")
    substring = path[end_index:start_index]
    with open("reactions_"+ substring +"_operon.txt", 'w') as f:
        for i in reactions:
            f.write(i)
            f.write('\n')
    return(reactions)

# %%
gene_list_SRR1536433= gene_read (r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_SRR1536433_genelist_metabolic.txt")
gene_list_genes_0_0=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_0_0_genelist_metabolic.txt")
gene_list_genes_7_7=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_7_7_genelist_metabolic.txt")
gene_list_genes_4_4=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_4_4_genelist_metabolic.txt")
gene_list_genes_6_6=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_6_6_genelist_metabolic.txt")

# %%
reaction_list_SRR1536433= gene_reaction_list (r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_SRR1536433_genelist_metabolic.txt")
reaction_list_genes_0_0=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_0_0_genelist_metabolic.txt")
reaction_list_genes_7_7=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_7_7_genelist_metabolic.txt")
reaction_list_genes_4_4=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_4_4_genelist_metabolic.txt")
reaction_list_genes_6_6=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\M9\operon_6_6_genelist_metabolic.txt")

# %% [markdown]
# Getting non-essential REACTIONS from my datasets

# %%
#Essential reactions according to the model
from cobra.flux_analysis import variability
essential_reactions_id=[]
essential_reactions=cobra.flux_analysis.variability.find_essential_reactions(model_M9)
for i in essential_reactions:
    essential_reactions_id.append(i.id)
    
len(essential_reactions_id)
essential_reactions_id
# Out:
# ['UAGAAT',
#  'DTMPK',
#  'OMPDC',
#  'PPCDC',
#  'ATPPRT',
#  'Zn2tex',
#  'SHCHD2',
#  'RHCCE',
#  'NNATr',
#  'ADSS',
#  'IPMD',
#  'EX_cobalt2_e',
#  'ACLS',
#  'ACHBS',
#  'UPPDC1',
#  'PPND',
#  'ACODA',
#  'MEPCT',
#  'ALAALAr',
#  'DHAD1',
#  'METS',
#  'DM_amob_c',
#  'IPPMIb',
#  'ORPT',
#  'ANPRT',
#  'BIOMASS_Ec_iML1515_core_75p37M',
#  'MCTP1App',
#  'ACGS',
#  'CU2tpp',
#  'COBALT2tex',
#  'PPA',
#  'MG2tex',
#  'AMPMS2',
#  'COBALT2tpp',
#  'DXPRIi',
#  'HMBS',
#  'IPPS',
#  'MCOATA',
#  'PPNCL2',
#  'KDOPP',
#  'P5CR',
#  'GLNS',
#  'DHQTi',
#  'EX_cu2_e',
#  'DHAD2',
#  'GLU5K',
#  'AGPAT160',
#  'MOBDtex',
#  'DASYN161',
#  'HISTD',
#  'KDOPS',
#  'PHETA1',
#  'ICDHyr',
#  'IGPDH',
#  'CHORS',
#  'APRAUR',
#  'SDPTA',
#  'METAT',
#  'PSSA160',
#  'HSDy',
#  'PRAMPC',
#  'RBFK',
#  'DNTPPA',
#  'MEOHtrpp',
#  'DASYN160',
#  'OCTDPS',
#  'DHDPS',
#  'SHKK',
#  'GRTT',
#  'RBFSa',
#  'UAMAS',
#  'HISTP',
#  'DHQS',
#  'GLUPRT',
#  'PSCVT',
#  'EX_so4_e',
#  'G1PACT',
#  'EPMEACPR',
#  'EX_zn2_e',
#  'KARA1',
#  'UDCPDPS',
#  'ACGK',
#  'DHORTS',
#  'OPMEACPD',
#  'AOXSr2',
#  '5DOAN',
#  'MECDPDH5',
#  'PMPK',
#  'DAPDC',
#  'DHPS2',
#  'DDPA',
#  'EX_mobd_e',
#  'CYSTL',
#  'SO4tex',
#  'IMPC',
#  'AHCYSNS',
#  'LEUTAi',
#  'THRD_L',
#  'PRAIi',
#  'MOHMT',
#  'HSST',
#  'ALAR',
#  'DPCOAK',
#  'PAPPT3',
#  'UHGADA',
#  'SERAT',
#  'TYRTA',
#  'DMATT',
#  'UMPK',
#  'NNDPR',
#  'DNMPPA',
#  'ANS',
#  '3OAR140',
#  'UAGDP',
#  'IG3PS',
#  'USHD',
#  'UAMAGS',
#  'CU2tex',
#  'PRASCSi',
#  'TMDS',
#  'UAGPT3',
#  'OPMEACPR',
#  'PE161abcpp',
#  'QULNS',
#  'SULR',
#  'OGMEACPD',
#  'ACCOAC',
#  'ICYSDS',
#  'EGMEACPR',
#  'A5PISO',
#  'OPMEACPS',
#  'K2L4Aabcpp',
#  'UAPGR',
#  'UPP3MT',
#  'DHDPRy',
#  'EX_meoh_e',
#  'ASP1DC',
#  'EX_cl_e',
#  'AIRC2',
#  'Ktex',
#  'ASPCT',
#  'ASPK',
#  'CDPMEK',
#  'GTPCI',
#  'MPTG',
#  'K2L4Aabctex',
#  'DHFR',
#  'PPNDH',
#  'BPNT',
#  'ARGSL',
#  'HPPK2',
#  'NADS1',
#  'CTPS2',
#  'PRAIS',
#  'FCLT',
#  'G5SD',
#  'FMNAT',
#  'CA2tex',
#  'OCBT',
#  'DHNPA2r',
#  'TYRL',
#  'CAt6pp',
#  'EX_glc__D_e',
#  'OPHBDC',
#  'CYSS',
#  'PTPATi',
#  'MOAT2',
#  'ADCS',
#  'PE160abcpp',
#  'NH4tex',
#  'ILETA',
#  'G1SAT',
#  'ACONTa',
#  'UAGCVT',
#  'PANTS',
#  'GLUTRR',
#  'PNTK',
#  'UAAGDS',
#  'PMDPHT',
#  'DM_4crsol_c',
#  'PPBNGS',
#  'SADT2',
#  'HSK',
#  'CLtex',
#  'UDCPDP',
#  'PRFGS',
#  'PMEACPE',
#  'EX_mg2_e',
#  'NH4tpp',
#  'G5SADs',
#  'GLUR',
#  'HCO3E',
#  'KDOCT2',
#  'ADCL',
#  'TMPK',
#  'THZPSN3',
#  'DHFS',
#  'GLUTRS',
#  'HSTPT',
#  'CS',
#  'PSD161',
#  'PGAMT',
#  'AICART',
#  'THRS',
#  'TDSK',
#  'CHRPL',
#  'MECDPS',
#  'UPP3S',
#  'SHCHF',
#  'MTHFR2',
#  'RBFSb',
#  'LPADSS',
#  'HBZOPT',
#  '3OAS140',
#  'ADSK',
#  'PSD160',
#  'ADSL1r',
#  'ASPTA',
#  'TMPPP',
#  'GF6PTA',
#  'EX_k_e',
#  'EX_ni2_e',
#  'DM_5drib_c',
#  'PSSA161',
#  'PDX5PS',
#  'BTS5',
#  'DXPS',
#  'MNtex',
#  'OGMEACPS',
#  'UGMDDS',
#  'AGPAT161',
#  'EX_pi_e',
#  'MEOHtex',
#  'GTPCII2',
#  'MALCOAMT',
#  'ACOTA',
#  'MOBDabcpp',
#  'AGPR',
#  'NADK',
#  'IPPMIa',
#  'ADSL2r',
#  'EX_mn2_e',
#  'THDPS',
#  'PItex',
#  'DHPPDA2',
#  'ACONTb',
#  'IGPS',
#  'OMCDC',
#  'GK1',
#  'SDPDS',
#  'EX_ca2_e',
#  'AMAOTr',
#  'U23GAAT',
#  'CHORM',
#  'AIRC3',
#  'DB4PS',
#  'PRATPP',
#  'MOAT',
#  'NI2tex',
#  'SHK3Dr',
#  'SHSL1',
#  'OGMEACPR',
#  'EX_nh4_e',
#  'DBTS',
#  'KARA2',
#  'ARGSS',
#  'PRMICI',
#  'ASAD',
#  'DPR',
#  'PRAGSr',
#  'DAPE']

# %%
#Intersection of my reactions to the non-essential
def non_essential(reaction_list):
    non_essential_reactions=[]
    for i in reaction_list:
        if i not in essential_reactions_id:
            non_essential_reactions.append(i)
    return (non_essential_reactions)

# %%
non_essential_reactions_SRR1536433 = non_essential(reaction_list_SRR1536433)
non_essential_reactions_genes_0_0=non_essential(reaction_list_genes_0_0)
non_essential_reactions_genes_7_7=non_essential(reaction_list_genes_7_7)
non_essential_reactions_genes_6_6=non_essential(reaction_list_genes_6_6)
non_essential_reactions_genes_4_4=non_essential(reaction_list_genes_4_4)

# %% [markdown]
# Flux balance analysis and active reactions

# %%
#Active reactions in the wt strain solved with FBA
solutionFBA = model_M9.optimize()
active_reactionsFBA=[]
for i in range(0,len(solutionFBA.fluxes)):
    if abs(solutionFBA.fluxes[i])>0.0001:
        active_reactionsFBA.append(solutionFBA.fluxes.index[i])

print(len(active_reactionsFBA))
active_reactionsFBA
# Out:
# 404
# ['SHK3Dr',
#  'DHORTS',
#  'OMPDC',
#  'G5SD',
#  'CS',
#  'ICDHyr',
#  'PPA',
#  'APRAUR',
#  'TRPAS2',
#  'DB4PS',
#  'ALAR',
#  'RBFK',
#  'ALATA_L',
#  'PPM',
#  'ASPTA',
#  'RBFSb',
#  'EX_pi_e',
#  'PYK',
#  'SHCHD2',
#  'EX_co2_e',
#  'A5PISO',
#  'PMDPHT',
#  'CPPPGO',
#  'ILETA',
#  'VALTA',
#  'IPPMIb',
#  'ORPT',
#  'RBFSa',
#  'ACHBS',
#  'DHAD2',
#  'ACLS',
#  'PSCVT',
#  'ANS',
#  'ANPRT',
#  'CHORM',
#  'PTAr',
#  'CHORS',
#  'IGPS',
#  'ACKr',
#  'LEUTAi',
#  'EX_h_e',
#  'DMATT',
#  'GRTT',
#  'UPP3S',
#  'UPPDC1',
#  'EX_mn2_e',
#  'MOAT',
#  'ECOAH6',
#  'USHD',
#  'ENO',
#  'FBA',
#  'HCO3E',
#  'IMPC',
#  'IMPD',
#  'ECOAH4',
#  'LPADSS',
#  'GLUTRS',
#  'TDSK',
#  'PGI',
#  'TMPPP',
#  'PGK',
#  'PGL',
#  'RPE',
#  'DHQTi',
#  'IPMD',
#  'AIRC3',
#  'TALA',
#  'PUNP1',
#  'ADSL2r',
#  'TKT1',
#  'EX_fe2_e',
#  'TMDS',
#  'PPCDC',
#  'EX_glc__D_e',
#  'DHAD1',
#  'IPPMIa',
#  'MDH',
#  'FUM',
#  'FMNAT',
#  'OHPBAT',
#  'KARA1',
#  'KARA2',
#  'ACCOAC',
#  'NADK',
#  'GLUTRR',
#  'HACD6',
#  'ECOAH1',
#  'ECOAH2',
#  'ARGSS',
#  'AGPR',
#  'G1SAT',
#  'KDOCT2',
#  'ECOAH3',
#  'DXPS',
#  'CDPMEK',
#  'MECDPS',
#  'PGAMT',
#  'UAGDP',
#  'UAGCVT',
#  'GLUR',
#  'GLYCL',
#  'NNDPR',
#  'PPC',
#  'HACD4',
#  'EX_zn2_e',
#  'HACD5',
#  'HACD7',
#  'DNMPPA',
#  'HPPK2',
#  'PTPATi',
#  'DXPRIi',
#  'GTPCII2',
#  'SADT2',
#  'OPHBDC',
#  'GHMT2r',
#  'SDPDS',
#  'ADCS',
#  'ADCL',
#  'UMPK',
#  'UAPGR',
#  'CTPS2',
#  'PAPPT3',
#  'UAGPT3',
#  'TRPS3',
#  'FADRx',
#  'NDPK2',
#  'NDPK3',
#  'NDPK4',
#  'ACODA',
#  'FCLT',
#  'HBZOPT',
#  'PNTK',
#  'ADSS',
#  'OCTDPS',
#  'DPCOAK',
#  'ASNS2',
#  'ASPCT',
#  'KDOPS',
#  'KDOPP',
#  'DMPPS',
#  'MCOATA',
#  'IPDPS',
#  'DAPE',
#  'DHDPRy',
#  'HSK',
#  'SDPTA',
#  'THRS',
#  'HSST',
#  'PPNDH',
#  'DTMPK',
#  'TRDR',
#  'DDPA',
#  'RHCCE',
#  'G3PD2',
#  'AACPS3',
#  'U23GAAT',
#  'UAAGDS',
#  'AACPS4',
#  'UAMAS',
#  'UAMAGS',
#  'P5CR',
#  'DHPPDA2',
#  'G5SADs',
#  'AKGDH',
#  'ASP1DC',
#  'UGMDDS',
#  'UHGADA',
#  'UAGAAT',
#  'ATPPRT',
#  'HISTD',
#  'DHDPS',
#  'G1PACT',
#  'GART',
#  'GF6PTA',
#  'IGPDH',
#  'PRPPS',
#  'PRATPP',
#  'PRMICI',
#  'GLUPRT',
#  'SERAT',
#  'CYSS',
#  'NADS1',
#  'BPNT',
#  'PAPSR',
#  'ASPK',
#  'ASAD',
#  'DAPDC',
#  'OCBT',
#  'GARFT',
#  'PHETA1',
#  'PPND',
#  'METAT',
#  'PRAMPC',
#  'TMPK',
#  'ACOTA',
#  'PDX5PS',
#  'PPBNGS',
#  'SULR',
#  'CBMKr',
#  'PPNCL2',
#  'PRAGSr',
#  'PRFGS',
#  'NNATr',
#  'PSERT',
#  'AIRC2',
#  'GAPD',
#  'GND',
#  'MOAT2',
#  'G6PDH2r',
#  'ARGSL',
#  'GLU5K',
#  'IPPS',
#  'EX_mg2_e',
#  'MOHMT',
#  'SPODM',
#  'AHCYSNS',
#  'GMPS',
#  'CHRPL',
#  'PMPK',
#  'ACACT7r',
#  'PSP_L',
#  'ADK3',
#  'ACACT2r',
#  'ADSK',
#  'ACACT3r',
#  'ACACT4r',
#  'HSDy',
#  'CYSTL',
#  'SHSL1',
#  'EX_ca2_e',
#  'Kt2pp',
#  'Htex',
#  'H2Otex',
#  'O2tpp',
#  'GTPCI',
#  'TKT2',
#  'UDCPDP',
#  'ATPS4rpp',
#  'CYTK1',
#  'CO2tpp',
#  'GK1',
#  'HACD1',
#  'Ktex',
#  'O2tex',
#  'HACD2',
#  'ECOAH5',
#  'DHFS',
#  'EX_ni2_e',
#  'GLCtex_copy1',
#  'PItex',
#  'METS',
#  'ASPO6',
#  'EX_cu2_e',
#  'ACACT5r',
#  'PRASCSi',
#  'FE2tex',
#  'DHPS2',
#  'MTHFC',
#  'MTHFD',
#  'QULNS',
#  'ACACT6r',
#  'SO4tex',
#  'R1PK',
#  'R15BPK',
#  'FACOAE160',
#  'NH4tpp',
#  'PROt2rpp',
#  'PROt4pp',
#  'NI2tex',
#  'DNTPPA',
#  'NH4tex',
#  'MG2tex',
#  'Zn2tex',
#  'H2Otpp',
#  'CO2tex',
#  'ACGK',
#  'HMBS',
#  'MEPCT',
#  'GLUDy',
#  'GLCptspp',
#  'EX_h2o_e',
#  'HSTPT',
#  'THDPS',
#  'ATPM',
#  'THRD_L',
#  'DHFR',
#  'PRAIi',
#  'HACD3',
#  'TYRTA',
#  'SHKK',
#  'EX_so4_e',
#  'OMCDC',
#  'E4PD',
#  'IG3PS',
#  'PDH',
#  'MTHFR2',
#  'EX_nh4_e',
#  'DUTPDP',
#  'DPR',
#  'GLNS',
#  'EX_k_e',
#  'ACACT1r',
#  'ACGS',
#  'CU2tex',
#  'ALAALAr',
#  'CLtex',
#  'ADNK1',
#  'MNtex',
#  'SHCHF',
#  'SUCOAS',
#  'PRAIS',
#  'AACPS7',
#  'PANTS',
#  'ECOAH7',
#  'HISTP',
#  'QMO2',
#  'UPP3MT',
#  'DHQS',
#  'DASYN160',
#  'DASYN161',
#  'PGCD',
#  'FACOAE161',
#  'ADSL1r',
#  'AICART',
#  'EX_cl_e',
#  'PPPGO3',
#  'PFK',
#  'PDX5PO2',
#  'PGM',
#  'CYTBO3_4pp',
#  'TPI',
#  'MPTG',
#  'RPI',
#  'MCTP1App',
#  'PERD',
#  '5DOAN',
#  'DM_5drib_c',
#  'DHORDfum',
#  'K2L4Aabcpp',
#  'FACOAE120',
#  'SO4t2pp',
#  'AMPMS2',
#  'PSSA161',
#  'PSD160',
#  'PSD161',
#  'ACONTb',
#  'CA2tex',
#  'SUCDi',
#  'EX_o2_e',
#  'G3PAT161',
#  'AGPAT160',
#  '3OAS140',
#  '3OAR140',
#  'PE160abcpp',
#  'PE161abcpp',
#  'ACONTa',
#  'PSSA160',
#  'AGPAT161',
#  'ZN2tpp',
#  'NI2tpp',
#  'ACOAD7f',
#  'ACOAD5f',
#  'CAt6pp',
#  'ACOAD3f',
#  'ACOAD2f',
#  'ACOAD4f',
#  'ACOAD6f',
#  'NADH16pp',
#  'OPHHX3',
#  'DALAt2pp',
#  'FE2tpp',
#  'MN2tpp',
#  'CLt3_2pp',
#  'POR5',
#  'CU2tpp',
#  'MG2t3_2pp',
#  'CTECOAI7',
#  'K2L4Aabctex',
#  'APG3PAT160',
#  'ICYSDS',
#  'MECDPDH5',
#  'RNTR1c2',
#  'RNTR2c2',
#  'I4FE4SR',
#  'RNTR3c2',
#  'RNTR4c2',
#  'I2FE2SS',
#  'FESR',
#  'I2FE2SS2',
#  'I4FE4ST',
#  'DM_4crsol_c',
#  'ACOAD1fr',
#  'ACPPAT160',
#  'AI2K',
#  'DHNPA2r',
#  'PIt2rpp',
#  'PAI2I',
#  'FESD1s',
#  '4HTHRA',
#  'TYRL',
#  'THZPSN3',
#  'PAI2T',
#  '4HTHRK',
#  'BIOMASS_Ec_iML1515_core_75p37M']

# %%
#Growth rate in wt 
model.summary()._objective_value
# Out:
# 0.8769972142571599

# %% [markdown]
# Flux variability analysis deviating o.5 and 0.8 from the optimum and active reactions

# %%
#Reactions ranges in the wt strain solved with FVA at 0.5 of optimization
from cobra.flux_analysis import flux_variability_analysis
solutionFVA05=flux_variability_analysis(model_M9, fraction_of_optimum=0.5,loopless=False)

# %%
def active_solution(solution):
    active_reactions_list=[]
    for i in range(0,len(solution)):
        if abs(solution["minimum"].values[i]) >=0.0001 or abs(solution["maximum"].values[i]) >=0.0001:
            active_reactions_list.append(solution.index[i])
    return(active_reactions_list)

# %%
#Active reactions in the wt strain solved with FVA at 0.5 and 0.8 of optimization
active_reactions_FVA05=active_solution(solutionFVA05)

# %% [markdown]
# Active and non-essential reactions regulated by methylation

# %%
#Active reactions each solution crossed with methylation-regulated reactions
def active_reactions(reaction_list,solution_reaction):
    active=[]
    for i in reaction_list:
        if i in solution_reaction:
            active.append(i)
    return (active)

# %%
active_reactions_0_0_FBA=active_reactions(reaction_list_genes_0_0,active_reactionsFBA)
active_reactions_7_7_FBA=active_reactions(reaction_list_genes_7_7,active_reactionsFBA)
active_reactions_4_4_FBA=active_reactions(reaction_list_genes_4_4,active_reactionsFBA)
active_reactions_6_6_FBA=active_reactions(reaction_list_genes_6_6,active_reactionsFBA)
active_reactions_SRR1536433_FBA=active_reactions(reaction_list_SRR1536433,active_reactionsFBA)

# %%
active_reactions_0_0_FVA05=active_reactions(reaction_list_genes_0_0,active_reactions_FVA05)
active_reactions_7_7_FVA05=active_reactions(reaction_list_genes_7_7,active_reactions_FVA05)
active_reactions_4_4_FVA05=active_reactions(reaction_list_genes_4_4,active_reactions_FVA05)
active_reactions_6_6_FVA05=active_reactions(reaction_list_genes_6_6,active_reactions_FVA05)
active_reactions_SRR1536433_FVA05=active_reactions(reaction_list_SRR1536433,active_reactions_FVA05)

# %%
#Active, non-essential & methylation-regulated
def active_nonessential (non_essential_reactions,active_reactions):
    reaction_list_active=[]
    for reaction in active_reactions:
        if reaction in non_essential_reactions:
            reaction_list_active.append(reaction)
    return(reaction_list_active)

# %%
reaction_list_active=[]
for reaction in active_reactionsFBA:
    if reaction in non_essential_reactions_genes_0_0:
        reaction_list_active.append(reaction)

# %%
reaction_list_genes_0_0_act_ne = active_nonessential(non_essential_reactions_genes_0_0,active_reactionsFBA)
reaction_list_genes_7_7_act_ne =active_nonessential (non_essential_reactions_genes_7_7,active_reactionsFBA)
reaction_list_SRR1536433_act_ne =active_nonessential (non_essential_reactions_SRR1536433,active_reactionsFBA)
reaction_list_genes_6_6_act_ne =active_nonessential (non_essential_reactions_genes_6_6,active_reactionsFBA)
reaction_list_genes_4_4_act_ne =active_nonessential (non_essential_reactions_genes_4_4,active_reactionsFBA)

# %%
reaction_list_genes_0_0_act_ne_FVA05 = active_nonessential(non_essential_reactions_genes_0_0,active_reactions_FVA05)
reaction_list_genes_7_7_act_ne_FVA05 =active_nonessential (non_essential_reactions_genes_7_7,active_reactions_FVA05)
reaction_list_SRR1536433_act_ne_FVA05 =active_nonessential (non_essential_reactions_SRR1536433,active_reactions_FVA05)
reaction_list_genes_6_6_act_ne_FVA05 =active_nonessential (non_essential_reactions_genes_6_6,active_reactions_FVA05)
reaction_list_genes_4_4_act_ne_FVA05 =active_nonessential (non_essential_reactions_genes_4_4,active_reactions_FVA05)

# %%
import pandas as pd
def reaction_class(reactions,active_reactions_FBA, active_reactions_FVA05,essential_reactions,output_name):
    data = {'reactions': reactions, 
    'FBA': ['active' if x else 'innactive' for x in [r in active_reactions_FBA for r in reactions]],    
    'FVA05': ['active' if x else 'innactive' for x in [r in active_reactions_FVA05 for r in reactions]],
    'essentiality': ['essential' if x else 'non-essential' for x in [r in essential_reactions for r in reactions]]}
    df = pd.DataFrame(data)
    df.to_csv(str(output_name) +".txt", sep='\t', index=False)
    return df

# %%
reaction_class(reaction_list_genes_0_0,active_reactions_0_0_FBA,active_reactions_0_0_FVA05,essential_reactions_id,"reaction_0_0_summary")
reaction_class(reaction_list_genes_7_7,active_reactions_0_0_FBA,active_reactions_7_7_FVA05,essential_reactions_id,"reaction_7_7_summary")
reaction_class(reaction_list_genes_6_6,active_reactions_6_6_FBA,active_reactions_6_6_FVA05,essential_reactions_id,"reaction_6_6_summary")
reaction_class(reaction_list_genes_4_4,active_reactions_4_4_FBA,active_reactions_4_4_FVA05,essential_reactions_id,"reaction_4_4_summary")
reaction_class(reaction_list_SRR1536433,active_reactions_SRR1536433_FBA,active_reactions_SRR1536433_FVA05,essential_reactions_id,"reaction_SRR1536433_summary")
# Out:
#     reactions        FBA      FVA05   essentiality
# 0      NADHHR  innactive     active  non-essential
# 1      HYD1pp  innactive  innactive  non-essential
# 2    CYANSTpp  innactive  innactive  non-essential
# 3      HYD2pp  innactive  innactive  non-essential
# 4     NADPHHR  innactive     active  non-essential
# 5        GAPD     active     active  non-essential
# 6      GLUTRR     active     active      essential
# 7   INOSTt4pp  innactive  innactive  non-essential
# 8        E4PD     active     active  non-essential
# 9    ILEabcpp  innactive     active  non-essential
# 10  NI2uabcpp  innactive     active  non-essential
# 11   THRabcpp  innactive     active  non-essential
# 12  PTRCabcpp  innactive     active  non-essential
# 13   VALabcpp  innactive     active  non-essential
# 14      AMANK  innactive  innactive  non-essential
# 15  ACNAMt2pp  innactive  innactive  non-essential
# 16   ALAabcpp  innactive     active  non-essential
# 17     NADHHS  innactive     active  non-essential
# 18    NADPHHS  innactive     active  non-essential
# 19      ACNML  innactive  innactive  non-essential
# 20        CAT  innactive     active  non-essential
# 21   AMANAPEr  innactive  innactive  non-essential
# 22     HYD3pp  innactive  innactive  non-essential
# 23  ACGAptspp  innactive  innactive  non-essential
# 24   LEUabcpp  innactive     active  non-essential
# 25   ATPS4rpp     active     active  non-essential

# %% [markdown]
# Reaction knockouts FBA

# %%
def model_KO_solution(reaction_list_active):
    model_KO={}
    for reaction in reaction_list_active:
        model_copy=model_M9.copy()
        model_copy.reactions.get_by_id(reaction).bounds=(0,0)
        model_KO[reaction]=model_copy.optimize().objective_value
    return(model_KO)

# %%
print(solutionFBA)
model_genes_0_0_KO =model_KO_solution (reaction_list_genes_0_0_act_ne)
print("0_0",model_genes_0_0_KO)
model_genes_7_7_KO =model_KO_solution (reaction_list_genes_7_7_act_ne)
print("7_7",model_genes_7_7_KO)
model_SRR1536433_KO= model_KO_solution (reaction_list_SRR1536433_act_ne)
print("SRR1536433", model_SRR1536433_KO)
model_genes_4_4_KO =model_KO_solution (reaction_list_genes_4_4_act_ne)
print("4_4",model_genes_4_4_KO)
model_genes_6_6_KO =model_KO_solution (reaction_list_genes_6_6_act_ne)
print("6_6",model_genes_6_6_KO)
# Out:
# <Solution 0.877 at 0x2315ccc58d0>
# 0_0 {'VALTA': 0.8769972144269725, 'ACKr': 0.8750807916210794, 'ECOAH6': 0.8734774973024533, 'ECOAH4': 0.8717998444556747, 'HACD6': 0.8734774973024533, 'ECOAH1': 0.869774270138796, 'ECOAH2': 0.8697742701388264, 'ECOAH3': 0.8697742701387683, 'GLYCL': 0.8768631103828168, 'HACD4': 0.8717998444556747, 'HACD5': 0.8726378645547601, 'HACD7': 0.8758520852665916, 'ACACT7r': 0.8758520852665916, 'ACACT2r': 0.8697742701388235, 'ACACT3r': 0.8697742701388067, 'ACACT4r': 0.8717998444556746, 'H2Otex': 0.4297653385609479, 'HACD1': 0.8697742701388294, 'HACD2': 0.8697742701388166, 'ECOAH5': 0.8726378645547601, 'ACACT5r': 0.8726378645547601, 'ACACT6r': 0.8734774973024533, 'HACD3': 0.8697742701388192, 'ACACT1r': 0.8697742701388291, 'ECOAH7': 0.8758520852665916, 'PAI2I': 0.8769683954878542, 'PAI2T': 0.8769683954878542}
# 7_7 {'PPM': 0.8769949942192934, 'VALTA': 0.8769972144269725, 'ECOAH6': 0.8734774973024533, 'ECOAH4': 0.8717998444556747, 'PUNP1': 0.8769949942192934, 'HACD6': 0.8734774973024533, 'ECOAH1': 0.869774270138796, 'ECOAH2': 0.8697742701388264, 'ECOAH3': 0.8697742701387683, 'HACD4': 0.8717998444556747, 'HACD5': 0.8726378645547601, 'HACD7': 0.8758520852665916, 'TRPS3': 0.8767628721873966, 'DMPPS': 0.8769972144269725, 'IPDPS': 0.8769972144269725, 'AKGDH': 0.8633703561644759, 'ACACT7r': 0.8758520852665916, 'ACACT2r': 0.8697742701388235, 'ACACT3r': 0.8697742701388067, 'ACACT4r': 0.8717998444556746, 'Kt2pp': 0.8765145269378009, 'HACD1': 0.8697742701388294, 'HACD2': 0.8697742701388166, 'ECOAH5': 0.8726378645547601, 'ACACT5r': 0.8726378645547601, 'ACACT6r': 0.8734774973024533, 'PROt2rpp': 0.8769972144269725, 'HACD3': 0.8697742701388192, 'ACACT1r': 0.8697742701388291, 'SUCOAS': 0.8651154798175358, 'ECOAH7': 0.8758520852665916, 'PPPGO3': 0.8769950074151448, 'CYTBO3_4pp': 0.777614283084774, 'SUCDi': 0.8418157926999615, 'NADH16pp': 0.8769972144261089, 'CTECOAI7': 0.8763773292510858, 'RNTR1c2': 0.8769756346826467, 'RNTR2c2': 0.8769749328598292, 'RNTR3c2': 0.8769749328598292, 'RNTR4c2': 0.8769972144269725}
# SRR1536433 {'GAPD': 0.7594428152438896, 'ATPS4rpp': 0.2849329232733456, 'E4PD': 0.8769955591670601}
# 4_4 {'PPM': 0.8769949942192934, 'PUNP1': 0.8769949942192934, 'SPODM': 0.8769931913397527, 'H2Otex': 0.4297653385609479, 'PAI2I': 0.8769683954878542, 'PAI2T': 0.8769683954878542}
# 6_6 {'PPM': 0.8769949942192934, 'PUNP1': 0.8769949942192934, 'R15BPK': 0.8769972144269725, 'CYTBO3_4pp': 0.777614283084774, 'RPI': 0.2557468657001129, 'NADH16pp': 0.8769972144261089}

# %% [markdown]
# Constraints FVA 0.5

# %%
#Selecting active reaction rows in the table that has the reaction bounds for FVA 0.5 and 0.8
reaction_list_genes_0_0_active_FVA05_solution = solutionFVA05.loc[reaction_list_genes_0_0_act_ne_FVA05]
reaction_list_genes_7_7_active_FVA05_solution = solutionFVA05.loc[reaction_list_genes_7_7_act_ne_FVA05]
reaction_list_SRR1536433_active_FVA05_solution = solutionFVA05.loc[reaction_list_SRR1536433_act_ne_FVA05]
reaction_list_genes_4_4_active_FVA05_solution=solutionFVA05.loc[reaction_list_genes_4_4_act_ne_FVA05]
reaction_list_genes_6_6_active_FVA05_solution=solutionFVA05.loc[reaction_list_genes_6_6_act_ne_FVA05]

# %%
#for each active reaction solve the system by FBA constraining the lowerbound
def model_KO_minimum(reaction_list_active_solution):
    model_KO_minimum={}
    for reaction, row in reaction_list_active_solution.iterrows():
        min_bound = row['minimum']
        model_copy = model_M9.copy()
        model_copy.reactions.get_by_id(reaction).bounds = (min_bound, min_bound)
        model_KO_minimum[reaction]=model_copy.optimize().objective_value

    return(model_KO_minimum)

# %%
model_KO_minimum_genes_0_0_FVA05=model_KO_minimum(reaction_list_genes_0_0_active_FVA05_solution)
model_KO_minimum_genes_7_7_FVA05=model_KO_minimum(reaction_list_genes_7_7_active_FVA05_solution)
model_KO_minimum_SRR1536433_FVA05=model_KO_minimum(reaction_list_SRR1536433_active_FVA05_solution)
model_KO_minimum_genes_6_6_FVA05=model_KO_minimum(reaction_list_genes_6_6_active_FVA05_solution)
model_KO_minimum_genes_4_4_FVA05=model_KO_minimum(reaction_list_genes_4_4_active_FVA05_solution)

# %%
#for each active reaction solve the system by FBA constraining the upperbound

def model_KO_maximum(reaction_list_active_solution):
    model_KO_maximum={}
    for reaction, row in reaction_list_active_solution.iterrows():
        max_bound = row['maximum']
        model_copy = model_M9.copy()
        model_copy.reactions.get_by_id(reaction).bounds = (max_bound, max_bound)
        model_KO_maximum[reaction]=model_copy.optimize().objective_value
    return(model_KO_maximum)

# %%
model_KO_maximum_genes_0_0_FVA05=model_KO_maximum(reaction_list_genes_0_0_active_FVA05_solution)
model_KO_maximum_genes_7_7_FVA05=model_KO_maximum(reaction_list_genes_7_7_active_FVA05_solution)
model_KO_maximum_SRR1536433_FVA05=model_KO_maximum(reaction_list_SRR1536433_active_FVA05_solution)
model_KO_maximum_genes_6_6_FVA05=model_KO_maximum(reaction_list_genes_6_6_active_FVA05_solution)
model_KO_maximum_genes_4_4_FVA05=model_KO_maximum(reaction_list_genes_4_4_active_FVA05_solution)

# %% [markdown]
# Summary table

# %%
def summary (model_KO,reaction_list_active_solution_05,model_KO_minimum_05,model_KO_maximum_05):
    wt_ko=pd.DataFrame({'reaction':list(model_KO.keys()),
    'bounds FBA':(solutionFBA.fluxes.loc[list(model_KO.keys())]).tolist(),
    'solutionFBA_KO':list(model_KO.values())
    })
    FVA05=pd.DataFrame({'reaction':reaction_list_active_solution_05.index,
    'min_bound_05':reaction_list_active_solution_05["minimum"].tolist(),
    "max_bound_05":reaction_list_active_solution_05["maximum"].tolist(),
    'solution_min_05':list(model_KO_minimum_05.values()),
    'solution_max_05':list(model_KO_maximum_05.values())
    })
    df1 = pd.merge(wt_ko, FVA05, on="reaction",how="outer")
    df1['deviation_FBA_KO']=((df1['solutionFBA_KO']-model_M9.summary()._objective_value))
    df1['deviation_min_05']=((df1['solution_min_05']-model_M9.summary()._objective_value))
    df1['deviation_max_05']=((df1['solution_max_05']-model_M9.summary()._objective_value))
    df1.iloc[:,1:]=df1.iloc[:,1:].round(3)
    return(df1)

# %%
SRR1536433_summary=summary(model_SRR1536433_KO,reaction_list_SRR1536433_active_FVA05_solution,model_KO_minimum_SRR1536433_FVA05,
model_KO_maximum_SRR1536433_FVA05)

# %%
pd.DataFrame(SRR1536433_summary).to_csv("SRR1536433_summary_bounds_M9" + ".txt", sep='\t', index=False)

# %%
gene_0_0_summary=summary(model_genes_0_0_KO,reaction_list_genes_0_0_active_FVA05_solution,model_KO_minimum_genes_0_0_FVA05,model_KO_maximum_genes_0_0_FVA05)

# %%
pd.DataFrame(gene_0_0_summary).to_csv("summary_bounds_0_0_M9" + ".txt", sep='\t', index=False)

# %%
gene_4_4_summary=summary(model_genes_4_4_KO,reaction_list_genes_4_4_active_FVA05_solution,model_KO_minimum_genes_4_4_FVA05,model_KO_maximum_genes_4_4_FVA05)

# %%
pd.DataFrame(gene_4_4_summary).to_csv("summary_bounds_4_4_M9" + ".txt", sep='\t', index=False)

# %%
gene_7_7_summary=summary(model_genes_7_7_KO,reaction_list_genes_7_7_active_FVA05_solution,model_KO_minimum_genes_7_7_FVA05,model_KO_maximum_genes_7_7_FVA05)

# %%
pd.DataFrame(gene_7_7_summary).to_csv("summary_bounds_7_7_M9" + ".txt", sep='\t', index=False)

# %%
gene_6_6_summary=summary(model_genes_6_6_KO,reaction_list_genes_6_6_active_FVA05_solution,model_KO_minimum_genes_6_6_FVA05,model_KO_maximum_genes_6_6_FVA05)

# %%
pd.DataFrame(gene_6_6_summary).to_csv("summary_bounds_6_6_M9" + ".txt", sep='\t', index=False)

# %% [markdown]
# Double reaction knock out FBA

# %%
import pandas as pd
from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)


cobra_model=model_M9.copy()

# %%
double_KO_reaction_gene_0_0= double_reaction_deletion(cobra_model,reaction_list_genes_0_0_act_ne)
double_KO_reaction_gene_4_4= double_reaction_deletion(cobra_model,reaction_list_genes_4_4_act_ne)
double_KO_reaction_gene_6_6= double_reaction_deletion(cobra_model,reaction_list_genes_6_6_act_ne)
double_KO_reaction_gene_7_7= double_reaction_deletion(cobra_model,reaction_list_genes_7_7_act_ne)
double_KO_reaction_SRR1536433=double_reaction_deletion(cobra_model,reaction_list_SRR1536433_act_ne)

# %%
double_KO_reaction_gene_0_0.sort_values(by="growth")
# Out:
#                    ids    growth   status
# 317   {ECOAH2, H2Otex}  0.425541  optimal
# 367   {ECOAH1, H2Otex}  0.425541  optimal
# 34    {ECOAH3, H2Otex}  0.425541  optimal
# 297  {ACACT2r, H2Otex}  0.425541  optimal
# 215    {H2Otex, HACD2}  0.425541  optimal
# ..                 ...       ...      ...
# 76      {VALTA, PAI2I}  0.876968  optimal
# 350            {PAI2I}  0.876968  optimal
# 186     {PAI2T, PAI2I}  0.876968  optimal
# 325            {PAI2T}  0.876968  optimal
# 331            {VALTA}  0.876997  optimal
#
# [378 rows x 3 columns]

# %%
double_KO_reaction_gene_7_7["growth"]=double_KO_reaction_gene_7_7["growth"].round(6)
double_KO_reaction_gene_7_7.sort_values(by="growth")[0:50]
# Out:
#                         ids    growth   status
# 636          {IPDPS, DMPPS}  0.000000  optimal
# 789     {CYTBO3_4pp, SUCDi}  0.720647  optimal
# 56        {NADH16pp, SUCDi}  0.721268  optimal
# 398     {AKGDH, CYTBO3_4pp}  0.749046  optimal
# 675    {SUCOAS, CYTBO3_4pp}  0.751040  optimal
# 490   {ACACT3r, CYTBO3_4pp}  0.769980  optimal
# 362     {HACD3, CYTBO3_4pp}  0.769980  optimal
# 816    {ECOAH3, CYTBO3_4pp}  0.769980  optimal
# 16    {ACACT2r, CYTBO3_4pp}  0.769980  optimal
# 314   {ACACT1r, CYTBO3_4pp}  0.769980  optimal
# 565     {CYTBO3_4pp, HACD1}  0.769980  optimal
# 308     {HACD2, CYTBO3_4pp}  0.769980  optimal
# 648    {ECOAH1, CYTBO3_4pp}  0.769980  optimal
# 796    {ECOAH2, CYTBO3_4pp}  0.769980  optimal
# 374   {ACACT4r, CYTBO3_4pp}  0.772118  optimal
# 725     {CYTBO3_4pp, HACD4}  0.772118  optimal
# 396    {ECOAH4, CYTBO3_4pp}  0.772118  optimal
# 442     {HACD5, CYTBO3_4pp}  0.773004  optimal
# 763   {ACACT5r, CYTBO3_4pp}  0.773004  optimal
# 492    {ECOAH5, CYTBO3_4pp}  0.773004  optimal
# 360     {HACD6, CYTBO3_4pp}  0.773891  optimal
# 660    {ECOAH6, CYTBO3_4pp}  0.773891  optimal
# 265   {ACACT6r, CYTBO3_4pp}  0.773891  optimal
# 214   {ACACT7r, CYTBO3_4pp}  0.776402  optimal
# 226    {ECOAH7, CYTBO3_4pp}  0.776402  optimal
# 545     {CYTBO3_4pp, HACD7}  0.776402  optimal
# 267  {CTECOAI7, CYTBO3_4pp}  0.776958  optimal
# 118     {Kt2pp, CYTBO3_4pp}  0.777103  optimal
# 609     {TRPS3, CYTBO3_4pp}  0.777366  optimal
# 123   {RNTR1c2, CYTBO3_4pp}  0.777591  optimal
# 336   {RNTR2c2, CYTBO3_4pp}  0.777591  optimal
# 450   {RNTR3c2, CYTBO3_4pp}  0.777591  optimal
# 744     {PUNP1, CYTBO3_4pp}  0.777612  optimal
# 519       {PPM, CYTBO3_4pp}  0.777612  optimal
# 785    {PPPGO3, CYTBO3_4pp}  0.777613  optimal
# 237  {NADH16pp, CYTBO3_4pp}  0.777614  optimal
# 365     {VALTA, CYTBO3_4pp}  0.777614  optimal
# 105     {IPDPS, CYTBO3_4pp}  0.777614  optimal
# 743            {CYTBO3_4pp}  0.777614  optimal
# 76      {CYTBO3_4pp, DMPPS}  0.777614  optimal
# 229   {CYTBO3_4pp, RNTR4c2}  0.777614  optimal
# 87   {CYTBO3_4pp, PROt2rpp}  0.777614  optimal
# 737         {ECOAH2, SUCDi}  0.836120  optimal
# 717        {ACACT1r, SUCDi}  0.836120  optimal
# 573        {ACACT2r, SUCDi}  0.836120  optimal
# 200          {HACD2, SUCDi}  0.836120  optimal
# 596          {HACD1, SUCDi}  0.836120  optimal
# 85          {ECOAH1, SUCDi}  0.836120  optimal
# 311          {HACD3, SUCDi}  0.836120  optimal
# 306        {ACACT3r, SUCDi}  0.836120  optimal

# %%
double_KO_reaction_SRR1536433.sort_values(by="growth")[0:30]
# Out:
#                 ids    growth   status
# 0  {GAPD, ATPS4rpp}  0.027338  optimal
# 3  {E4PD, ATPS4rpp}  0.284932  optimal
# 4        {ATPS4rpp}  0.284933  optimal
# 5      {E4PD, GAPD}  0.759441  optimal
# 2            {GAPD}  0.759443  optimal
# 1            {E4PD}  0.876996  optimal

# %% [markdown]
# Non-essential GENES single KO from my datasets, FBA

# %%
essential_genes=cobra.flux_analysis.variability.find_essential_genes(model_M9)
essential_genes_id=[]
for i in essential_genes:
    essential_genes_id.append(i.id)

len(essential_genes_id)
# Out:
# 196

# %%
def non_essential_genes(gene_list):
    non_essential_genes=[]
    for i in gene_list:
        if i not in essential_genes_id:
            non_essential_genes.append(i)
    non_essential_genes = [x for x in non_essential_genes if x.strip()]
    return (non_essential_genes)

# %%
non_essential_genes_0_0 = non_essential_genes(gene_list_genes_0_0)
non_essential_genes_7_7 = non_essential_genes(gene_list_genes_7_7)
non_essential_genes_4_4 = non_essential_genes(gene_list_genes_4_4)
non_essential_genes_6_6 = non_essential_genes(gene_list_genes_6_6)
non_essential_genes_SRR1536433 = non_essential_genes(gene_list_SRR1536433)

# %%
def single_gene_KO(model,non_essential_genes):
    single_KO_gene=single_gene_deletion(model,non_essential_genes)
    def get_associated_reactions(gene_ids):
        associated_reactions = []
        for gene_set in gene_ids:
            gene_list = list(gene_set)
            gene_reactions = []
            for gene in gene_list:
                gene_obj = model_M9.genes.get_by_id(gene)
                gene_reactions.extend([reaction.id for reaction in gene_obj.reactions])
            associated_reactions.append(','.join(gene_reactions))
        return associated_reactions


    single_KO_gene['associated_reactions'] = get_associated_reactions(single_KO_gene['ids'])
    single_KO_gene['growth'] = single_KO_gene['growth'].round(6)
    def concat_gene_ids(ids):
        return list(set.union(*ids))
    summarized_single_KO_gene = single_KO_gene.groupby(['growth', 'associated_reactions'], as_index=False).agg({'ids': concat_gene_ids})
    summarized_single_KO_gene = summarized_single_KO_gene.rename(columns={'ids': 'genes'})
    summarized_single_KO_gene['associated_reactions'] = summarized_single_KO_gene['associated_reactions'].apply(lambda x: [r for r in x.split(',') if r.strip() in active_reactionsFBA])
    summarized_single_KO_gene = summarized_single_KO_gene[summarized_single_KO_gene['associated_reactions'].str.len() > 0]
    return(summarized_single_KO_gene)

# %%
pd.DataFrame(single_gene_KO(cobra_model,non_essential_genes_0_0)).to_csv("single_genes_0_0_KO" + ".txt", sep='\t', index=False)

# %%
pd.DataFrame(single_gene_KO(cobra_model,non_essential_genes_4_4)).to_csv("single_genes_4_4_KO" + ".txt", sep='\t', index=False)

# %%
pd.DataFrame(single_gene_KO(cobra_model,non_essential_genes_6_6)).to_csv("single_genes_6_6_KO" + ".txt", sep='\t', index=False)

# %%
pd.DataFrame(single_gene_KO(cobra_model,non_essential_genes_7_7)).to_csv("single_genes_7_7_KO" + ".txt", sep='\t', index=False)

# %%
pd.DataFrame(single_gene_KO(cobra_model,non_essential_genes_SRR1536433)).to_csv("single_genes_SRR1536433_KO" + ".txt", sep='\t', index=False)

# %% [markdown]
# Double GENE KO, associated reactions

# %%
#Doing the KO of two genes, depending on the GPR, the associated reaction/s will be set to bounds=0. Retrieve these associated reactions
#when the resulting growth rate of two or more  double gene KOs is identical compare the KO reactions associated and find the common one/s
#in all cases and retrieve only once the growth rate of the associated reaction/s KO. Do not retrieve the KOs that don't influience the 
#growth rate
def double_gene_KO(model,non_essential_genes):
    double_KO_gene=double_gene_deletion(model,non_essential_genes)
    def get_reactions(gene_ids):
        reactions = set()
        for gene in gene_ids:
            gene_obj = model.genes.get_by_id(gene)
            reactions |= set(gene_obj.reactions)
        return list(reactions)

    double_KO_gene['reactions'] = double_KO_gene['ids'].apply(get_reactions)
    def get_reactions_ids(reaction_list):
        reactions_id=[]
        for n in range(len(reaction_list)):
            id=reaction_list[n].id
            if id in active_reactionsFBA:
                reactions_id.append(id)
        return list(reactions_id)
    double_KO_gene['growth'] = double_KO_gene['growth'].round(4)
    double_KO_gene['reactions_id'] = double_KO_gene['reactions'].apply(get_reactions_ids)
    double_KO_gene['reactions_id_sorted'] = double_KO_gene['reactions_id'].apply(lambda x: sorted(x))
    double_KO_gene['reactions_id_sorted_tuple'] = double_KO_gene['reactions_id_sorted'].apply(tuple)
    double_KO_reactions = double_KO_gene.groupby('reactions_id_sorted_tuple').agg({'growth': 'first', 'ids': lambda x: list(x.values)})
    double_KO_reactions = double_KO_reactions.reset_index()  # Reset the index to make the grouped column a regular column
    double_KO_reactions = double_KO_reactions[['reactions_id_sorted_tuple', 'growth', 'ids']]  # Select the desired columns
    double_KO_reactions = double_KO_reactions[double_KO_reactions['growth'] != 0.8770]
    def find_common_reaction(x):
            reactions = set(x.iloc[0])
            for r in x:
                reactions = reactions.intersection(set(r))
            return reactions

    common_reactions = double_KO_reactions.groupby('growth')['reactions_id_sorted_tuple'].apply(find_common_reaction)
    common_reactions = common_reactions.reset_index()
    grouped_ids = double_KO_reactions.groupby('growth')['ids'].apply(list).reset_index()
    result = common_reactions.merge(grouped_ids, on='growth')
    result['ids'] = result['ids'].apply(lambda x: x[0])
    return(result)

# %%
pd.DataFrame(double_gene_KO(cobra_model,non_essential_genes_0_0)).to_csv("double_gene_KO_0_0_M9" +".txt", sep='\t', index=False)

# %%
pd.DataFrame(double_gene_KO(cobra_model,non_essential_genes_SRR1536433)).to_csv("double_gene_KO_SRR1536433_M9" +".txt", sep='\t', index=False)

# %%
pd.DataFrame(double_gene_KO(cobra_model,non_essential_genes_7_7)).to_csv("double_gene_KO_7_7_M9" +".txt", sep='\t', index=False)

# %%
pd.DataFrame(double_gene_KO(cobra_model,non_essential_genes_4_4)).to_csv("double_gene_KO_4_4_M9" +".txt", sep='\t', index=False)
# Out:
# C:\Users\e\AppData\Local\Temp\ipykernel_2220\2012341876.py:36: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   common_reactions = double_KO_reactions.groupby('growth')['reactions_id_sorted_tuple'].apply(find_common_reaction)
# C:\Users\e\AppData\Local\Temp\ipykernel_2220\2012341876.py:38: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   grouped_ids = double_KO_reactions.groupby('growth')['ids'].apply(list).reset_index()

# %%
pd.DataFrame(double_gene_KO(cobra_model,non_essential_genes_6_6)).to_csv("double_gene_KO_6_6_M9" +".txt", sep='\t', index=False)

# %% [markdown]
# GENE constraints 0.5

# %%
#Selected genes--> associated reactions--> reactions active in condition FVA 0.5
#set upperbound maximum for all the associated reactions to that gene
def gene_upperbound(gene_from_list):
    reaction_list=[]
    results=pd.DataFrame()
    reaction_id=model_M9.genes.get_by_id(gene_from_list).reactions
    for i in reaction_id:
        reaction_list.append(i.id)
    reactions= list(set(reaction_list))
    active=[]
    for i in reactions:
        if i in reaction_list_genes_7_7_active_FVA05_solution.index:
            active.append(reaction_list_genes_7_7_active_FVA05_solution.loc[i])
    model_copy=model_M9.copy()
    active=pd.DataFrame()
    if len(active) ==0:
        return
    else:
        for i in active.index:
            max_bound = max(abs(active["maximum"][i]),abs(active["minimum"][i]))
            model_copy.reactions.get_by_id(i).bounds = (max_bound, max_bound)
            data={"gene": gene_from_list, "reactions": active.index, "solution": model_copy.optimize().objective_value}
            df=pd.DataFrame(data)
            results=pd.concat(results,df,axis=1)
    return(results)

# %%
def gene_upperbound(gene_list,solution):
    results = pd.DataFrame()

    for gene in gene_list:
        reaction_list = []
        reaction_id = model_M9.genes.get_by_id(gene).reactions

        for i in reaction_id:
            reaction_list.append(i.id)

        reactions = list(set(reaction_list))
        active_reactions = []

        for i in reactions:
            if i in solution.index:
                active_reactions.append(solution.loc[i])

        model_copy = model_M9.copy()

        if len(active_reactions) == 0:
            continue
        else:
            for i in active_reactions:
                max_bound = max(abs(i["maximum"]), abs(i["minimum"]))
                model_copy.reactions.get_by_id(i.name).bounds = (max_bound, max_bound)

            model_copy.optimize()
            objective_value = model_copy.objective.value

            for i in active_reactions:
                data = {"gene": gene, "reaction": i.name, "bound": max(abs(i["maximum"]), abs(i["minimum"])).round(4), "solution": objective_value}
                df = pd.DataFrame(data, index=[0])
                results = pd.concat([results, df])
    results_collapsed = results.groupby("gene").agg(lambda x: x.tolist() if x.nunique() > 1 else x.iloc[0]).reset_index()
    return(results_collapsed)

# %%
gene_upperbound_7_7=gene_upperbound(gene_list_genes_7_7,reaction_list_genes_7_7_active_FVA05_solution)

# %%
print(list(map(gene_upperbound, gene_list_genes_7_7)))
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
print(list(map(gene_upperbound, gene_list_genes_0_0)))
# Out:
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b2342 Index(['ACACT6r', 'ACACT2r', 'ACACT3r', 'ACACT5r', 'ACACT4r', 'ACACT7r',
#        'ACACT1r'],
#       dtype='object') 0.876997214426983
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b2341 Index(['HACD4', 'ECOAH1', 'HACD2', 'HACD1', 'HACD7', 'ECOAH4', 'HACD3',
#        'HACD5', 'ECOAH2', 'ECOAH7', 'ECOAH5', 'ECOAH6', 'HACD6', 'ECOAH3'],
#       dtype='object') 0.8769972144269801
# b2201 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2200 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2199 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2198 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2197 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b3770 Index(['VALTA'], dtype='object') 0.8769972144269751
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3199 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3200 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3201 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
print(list(map(gene_upperbound, gene_list_genes_4_4)))
# Out:
# b4382 Index(['DURIPP', 'TMDPP'], dtype='object') 0.32707356748294264
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b4383 Index(['PPM'], dtype='object') 0.0
# b4384 Index(['PUNP1', 'DURIPP'], dtype='object') 0.047681943096397304
# b2201 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2200 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2199 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2198 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2197 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
print(list(map(gene_upperbound, gene_list_genes_6_6)))
# Out:
# b0432 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0431 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0430 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0429 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b4382 Index(['DURIPP', 'TMDPP'], dtype='object') 0.32707356748294264
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b4383 Index(['PPM'], dtype='object') 0.0
# b4384 Index(['PUNP1', 'DURIPP'], dtype='object') 0.047681943096397304
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b0180 Index(['3HAD60', '3HAD100', '3HAD120', '3HAD40', '3HAD160', '3HAD121',
#        '3HAD141', '3HAD80', '3HAD140', '3HAD161'],
#       dtype='object') 0.422237661186144
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b0641 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# b2201 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2200 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2199 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2198 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2197 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2288 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2287 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2286 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2285 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2284 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2283 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2282 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2281 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2280 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2279 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2278 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2277 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2276 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 print(list(map(gene_upperbound, gene_list_genes_6_6)))
#
# Cell In[215], line 5, in gene_upperbound(gene_from_list)
#       3 def gene_upperbound(gene_from_list):
#       4     reaction_list=[]
# ----> 5     reaction_id=model.genes.get_by_id(gene_from_list).reactions
#       6     for i in reaction_id:
#       7         reaction_list.append(i.id)
#
# File c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\core\dictlist.py:75, in DictList.get_by_id(self, id)
#      73 def get_by_id(self, id: Union[Object, str]) -> Object:
#      74     """Return the element with a matching id."""
# ---> 75     return list.__getitem__(self, self._dict[id])
#
# KeyError: ''

# %%
print(list(map(gene_upperbound, gene_list_SRR1536433)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 print(list(map(gene_upperbound, gene_list_SRR1536433)))
#
# Cell In[215], line 5, in gene_upperbound(gene_from_list)
#       3 def gene_upperbound(gene_from_list):
#       4     reaction_list=[]
# ----> 5     reaction_id=model.genes.get_by_id(gene_from_list).reactions
#       6     for i in reaction_id:
#       7         reaction_list.append(i.id)
#
# File c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\core\dictlist.py:75, in DictList.get_by_id(self, id)
#      73 def get_by_id(self, id: Union[Object, str]) -> Object:
#      74     """Return the element with a matching id."""
# ---> 75     return list.__getitem__(self, self._dict[id])
#
# KeyError: ''

# %% [markdown]
# Flux deviations

# %%
import numpy as np
def deviation_reactions (reaction1,solutionFBA,reaction2=None, reaction3=None,reaction4=None,reaction5=None,reaction6=None):
    model_double_KO=model_M9.copy()
    model_double_KO.reactions.get_by_id(reaction1).bounds=(0,0)
    if reaction2 is not None and reaction2 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction2).bounds = (0, 0)
    if reaction3 is not None and reaction3 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction3).bounds = (0, 0)
    if reaction4 is not None and reaction4 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction4).bounds = (0, 0)
    if reaction5 is not None and reaction5 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction5).bounds = (0, 0)
    if reaction6 is not None and reaction6 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction6).bounds = (0, 0)
    solutionKO=model_double_KO.optimize()
    names=[]
    distances= []
    fluxes=[]
    new_fluxes=[]
    percentaje=[]
    for flux in range(0,len(solutionKO.fluxes.index)):
        name=solutionKO.fluxes.index[flux]
        distance=solutionKO[flux] - solutionFBA[flux]
        if abs(distance) > abs(solutionFBA[flux])*0.1 and abs(distance) > 0.1:
            names.append(name)
            distances.append(round(distance,6))
            fluxes.append(round(solutionFBA[flux],6))
            new_fluxes.append(round(solutionKO[flux],6))
            if solutionFBA[flux] == 0:
                percent= np.nan
            else:
                percent=solutionKO[flux]*100/solutionFBA[flux]
            percentaje.append(round(percent,6))
    wt_vs_KO={"Reaction":names,"Deviation":distances,"flux":fluxes,"new_flux":new_fluxes,"percentaje":percentaje}
    df=pd.DataFrame(wt_vs_KO, columns=["Reaction","Deviation","percentaje","flux","new_flux"])
    df = df[df['Reaction'] != reaction1]
    df = df[df['Reaction'] != reaction2]
    df = df[df['Reaction'] != reaction3]
    df = df[df['Reaction'] != reaction4]
    df = df[df['Reaction'] != reaction5]
    df = df[df['Reaction'] != reaction6]   
    df=df.set_index("Reaction")
    df = df.sort_values(
    by=['Deviation', 'percentaje'],
    ascending=[False, False],
    key=lambda col:col.abs(),
    na_position='first')
    return df

# %%
deviation_reactions(reaction1="AKGDH",solutionFBA=solutionFBA,reaction2="CYTBO3_4pp")
# Out:
#           Deviation  percentaje       flux   new_flux
# Reaction
# CYTBDpp   55.307027         NaN   0.000000  55.307027
# ATPS4rpp  -9.982717   85.826546  70.432494  60.449776
# NADH16pp   8.374517  122.039917  37.997044  46.371561
# MDH        6.689075  197.160131   6.884588  13.573663
# PDH        6.319658  165.220454   9.689687  16.009345
# ...             ...         ...        ...        ...
# PIt2rpp   -0.123422   85.410355   0.845957   0.722535
# ACLS      -0.111876   85.410355   0.766817   0.654941
# DHAD1     -0.111876   85.410355   0.766817   0.654941
# KARA1      0.111876   85.410355  -0.766817  -0.654941
# ADK3       0.101083   85.410355  -0.692840  -0.591757
#
# [71 rows x 4 columns]

# %%
deviation_reactions(reaction1="E4PD",solutionFBA=solutionFBA,reaction2="GAPD")
# Out:
#                                 Deviation  percentaje      flux  new_flux
# Reaction
# Htex                             1.080150   86.595645 -8.058200 -6.978051
# RPI                              0.871513   39.074748 -1.430463 -0.558950
# TALA                            -0.761793  -24.491739  0.611922 -0.149870
# TKT1                            -0.761793  -24.491739  0.611922 -0.149870
# TKT2                            -0.717381 -157.982817  0.278073 -0.439308
# XYLI2                            0.660937         NaN  0.000000  0.660937
# HEX7                             0.660937         NaN  0.000000  0.660937
# PPA                             -0.411629   86.595645  3.070861  2.659232
# PPM                              0.401357   86.595645 -2.994230 -2.592873
# R1PK                            -0.401278   86.595645  2.993640  2.592362
# R15BPK                          -0.401278   86.595645  2.993640  2.592362
# VALTA                            0.371112   -0.000000 -0.371112  0.000000
# VPAMTr                           0.321367         NaN  0.000000  0.321367
# PRPPS                            0.291637   86.595645 -2.175690 -1.884053
# FADRx                           -0.256964   86.595645  1.917019  1.660055
# ALATA_L                         -0.252968  149.574701 -0.510276 -0.763243
# PSERT                           -0.243448   83.840524  1.506536  1.263088
# PSP_L                           -0.243448   83.840524  1.506536  1.263088
# PGCD                            -0.243448   83.840524  1.506536  1.263088
# MTHFC                           -0.198858   77.057164  0.866753  0.667895
# MTHFD                           -0.198858   77.057164  0.866753  0.667895
# GLNS                            -0.184146   86.595645  1.373778  1.189632
# GHMT2r                          -0.172644   82.352970  0.978319  0.805675
# GARFT                           -0.135054   65.438052  0.390758  0.255705
# ASPK                            -0.125676   86.595645  0.937577  0.811901
# ASAD                             0.125676   86.595645 -0.937577 -0.811901
# BIOMASS_Ec_iML1515_core_75p37M  -0.117556   86.595645  0.876997  0.759441
# EX_pi_e                          0.113395   86.595645 -0.845957 -0.732562
# PItex                           -0.113395   86.595645  0.845957  0.732562
# PIt2rpp                         -0.113395   86.595645  0.845957  0.732562
# ACLS                            -0.102787   86.595645  0.766817  0.664030
# DHAD1                           -0.102787   86.595645  0.766817  0.664030
# KARA1                            0.102787   86.595645 -0.766817 -0.664030

# %%
deviation_reactions(reaction1="NADH16pp",solutionFBA=solutionFBA,reaction2="NADH18pp", reaction3="NADH17pp"
, reaction4="AKGDH")
# Out:
#           Deviation  percentaje      flux   new_flux
# Reaction
# FORtppi   18.639823         NaN  0.000000  18.639823
# PFL       18.638018         NaN  0.000000  18.638018
# FDH4pp    18.636950         NaN  0.000000  18.636950
# GLYCTO2   16.845006         NaN  0.000000  16.845006
# GLYCLTDx  16.845006         NaN  0.000000  16.845006
# ...             ...         ...       ...        ...
# PIt2rpp   -0.136123   83.908968  0.845957   0.709834
# ADK3       0.131366   81.039438 -0.692840  -0.561474
# ACLS      -0.123389   83.908968  0.766817   0.643429
# DHAD1     -0.123389   83.908968  0.766817   0.643429
# KARA1      0.123389   83.908968 -0.766817  -0.643429
#
# [78 rows x 4 columns]

# %%
deviation_reactions(reaction1="NADH16pp",solutionFBA=solutionFBA,reaction2="NADH18pp", reaction3="NADH17pp"
, reaction4="SUCOAS")[0:50]
# Out:
#             Deviation  percentaje       flux   new_flux
# Reaction
# FORtppi     18.171711         NaN   0.000000  18.171711
# PFL         18.169902         NaN   0.000000  18.169902
# FDH4pp      18.168832         NaN   0.000000  18.168832
# NADH5       17.225886         NaN   0.000000  17.225886
# CO2tpp      12.438658   48.179370 -24.003293 -11.564635
# CYTBO3_4pp  12.063401  127.258049  44.256288  56.319688
# MDH2        11.815238         NaN   0.000000  11.815238
# ATPS4rpp   -11.521706   83.641490  70.432494  58.910787
# PDH         -9.689687    0.000000   9.689687   0.000000
# MDH         -6.884588    0.000000   6.884588   0.000000
# ICL          6.100532         NaN   0.000000   6.100532
# MALS         6.100532         NaN   0.000000   6.100532
# O2tpp        6.031124  127.250987  22.131763  28.162887
# O2tex        6.031124  127.250987  22.131763  28.162887
# EX_o2_e     -6.031124  127.250987 -22.131763 -28.162887
# EX_co2_e     5.733053  123.884442  24.003293  29.736346
# CO2tex      -5.733053  123.884442 -24.003293 -29.736346
# AKGDH       -5.583000    6.483395   5.970063   0.387063
# PYK          4.072011  278.925464   2.275814   6.347824
# ME2          3.917896         NaN   0.000000   3.917896
# ICDHyr      -3.357043   51.438710   6.913003   3.555960
# SUCDi        2.849063  145.507315   6.260670   9.109732
# FUM          2.748014  139.915444   6.884588   9.632602
# CS           2.743489  139.685915   6.913003   9.656492
# ACONTb       2.743489  139.685915   6.913003   9.656492
# ACONTa       2.743489  139.685915   6.913003   9.656492
# PPC         -2.596107    0.000000   2.596107   0.000000
# ABTA         2.376135         NaN   0.000000   2.376135
# GLUDC        2.376135         NaN   0.000000   2.376135
# SSALy        2.376135         NaN   0.000000   2.376135
# PGI          2.355366  130.810714   7.644634  10.000000
# PGL         -2.355366   -0.000000   2.355366  -0.000000
# GND         -2.355366    0.000000   2.355366   0.000000
# G6PDH2r     -2.355366   -0.000000   2.355366  -0.000000
# NH4tpp      -1.508487   84.073397   9.471495   7.963008
# NH4tex      -1.508487   84.073397   9.471495   7.963008
# EX_nh4_e     1.508487   84.073397  -9.471495  -7.963008
# RPE         -1.461904  -64.259633   0.889996  -0.571908
# EX_h_e      -1.283398   84.073397   8.058200   6.774803
# Htex         1.283398   84.073397  -8.058200  -6.774803
# GLUDy        1.193510   84.085455  -7.499495  -6.305984
# TPI          0.926335  111.122826   8.328232   9.254566
# FBA          0.906660  110.727468   8.451764   9.358424
# PFK          0.906660  110.727468   8.451764   9.358424
# RPI          0.887903   37.928965  -1.430463  -0.542560
# TALA        -0.757537  -23.796288   0.611922  -0.145615
# TKT1        -0.757537  -23.796288   0.611922  -0.145615
# TKT2        -0.704366 -153.302455   0.278073  -0.426293
# PPM          0.496799   83.408110  -2.994230  -2.497431
# R1PK        -0.496705   83.407979   2.993640   2.496934

# %%
deviation_reactions(reaction1="CYTBO3_4pp",solutionFBA=solutionFBA)
# Out:
#           Deviation  percentaje       flux   new_flux
# Reaction
# CYTBDpp   52.839704         NaN   0.000000  52.839704
# ATPS4rpp -12.643599   82.048627  70.432494  57.788894
# NADH16pp   6.573001  117.298717  37.997044  44.570045
# O2tpp      4.291298  119.389770  22.131763  26.423061
# O2tex      4.291298  119.389770  22.131763  26.423061
# EX_o2_e   -4.291298  119.389770 -22.131763 -26.423061
# EX_co2_e   4.079213  116.994388  24.003293  28.082506
# CO2tpp    -4.079213  116.994388 -24.003293 -28.082506
# CO2tex    -4.079213  116.994388 -24.003293 -28.082506
# SUCOAS    -2.095357  138.030501  -5.509676  -7.605033
# AKGDH      2.043186  134.223854   5.970063   8.013248
# SUCDi      2.010253  132.109239   6.260670   8.270923
# MDH        1.939550  128.172342   6.884588   8.824138
# FUM        1.939550  128.172342   6.884588   8.824138
# CS         1.936330  128.009966   6.913003   8.849333
# ICDHyr     1.936330  128.009966   6.913003   8.849333
# ACONTb     1.936330  128.009966   6.913003   8.849333
# ACONTa     1.936330  128.009966   6.913003   8.849333
# PGI        1.626776  121.279978   7.644634   9.271410
# PGL       -1.626776   30.933186   2.355366   0.728590
# GND       -1.626776   30.933186   2.355366   0.728590
# G6PDH2r   -1.626776   30.933186   2.355366   0.728590
# PDH        1.621671  116.736051   9.689687  11.311358
# PYK        1.328606  158.379389   2.275814   3.604420
# NH4tpp    -1.073327   88.667817   9.471495   8.398168
# NH4tex    -1.073327   88.667817   9.471495   8.398168
# EX_nh4_e   1.073327   88.667817  -9.471495  -8.398168
# RPE       -1.007431  -13.194996   0.889996  -0.117435
# EX_h_e    -0.913170   88.667817   8.058200   7.145030
# Htex       0.913170   88.667817  -8.058200  -7.145030
# GLUDy      0.849856   88.667817  -7.499495  -6.649638
# RPI        0.615390   56.979651  -1.430463  -0.815073
# TALA      -0.522632   14.591871   0.611922   0.089291
# TKT1      -0.522632   14.591871   0.611922   0.089291
# TKT2      -0.484799  -74.342216   0.278073  -0.206726
# VALTA      0.371112   -0.000000  -0.371112   0.000000
# PPA       -0.347996   88.667817   3.070861   2.722865
# PPM        0.339312   88.667817  -2.994230  -2.654918
# R1PK      -0.339245   88.667817   2.993640   2.654395
# R15BPK    -0.339245   88.667817   2.993640   2.654395
# VPAMTr     0.329057         NaN   0.000000   0.329057
# PPC       -0.294196   88.667817   2.596107   2.301912
# ASPTA      0.290976   88.667817  -2.567693  -2.276717
# ALATA_L   -0.271231  153.153917  -0.510276  -0.781507
# PRPPS      0.246553   88.667817  -2.175690  -1.929137
# FADRx     -0.217240   88.667817   1.917019   1.699779
# PSERT     -0.170723   88.667817   1.506536   1.335813
# PSP_L     -0.170723   88.667817   1.506536   1.335813
# PGCD      -0.170723   88.667817   1.506536   1.335813
# GLNS      -0.155679   88.667817   1.373778   1.218099
# GHMT2r    -0.110865   88.667817   0.978319   0.867454
# ASPK      -0.106248   88.667817   0.937577   0.831329
# ASAD       0.106248   88.667817  -0.937577  -0.831329

# %%
deviation_reactions("SUCDi",solutionFBA,reaction2="NADH16pp")
# Out:
#             Deviation  percentaje       flux   new_flux
# Reaction
# NADH17pp    34.513658         NaN   0.000000  34.513658
# CYTBD2pp    34.510842         NaN   0.000000  34.510842
# CYTBO3_4pp -21.061440   52.410288  44.256288  23.194848
# FORtppi     18.140787         NaN   0.000000  18.140787
# FDH4pp      18.140787         NaN   0.000000  18.140787
# ...               ...         ...        ...        ...
# ADK3         0.142515   79.430349  -0.692840  -0.550325
# ACLS        -0.136165   82.242903   0.766817   0.630653
# DHAD1       -0.136165   82.242903   0.766817   0.630653
# KARA1        0.136165   82.242903  -0.766817  -0.630653
# HSDy         0.108719   82.242903  -0.612255  -0.503537
#
# [82 rows x 4 columns]

# %%
deviation_reactions(reaction1="SUCDi",solutionFBA=solutionFBA,reaction2="CYTBO3_4pp")
# Out:
#           Deviation   percentaje      flux   new_flux
# Reaction
# CYTBDpp   57.758751          NaN  0.000000  57.758751
# ASPT      45.876322          NaN  0.000000  45.876322
# ASPTA    -45.418555  1868.847043 -2.567693 -47.986248
# GLUDy    -44.540441   693.912558 -7.499495 -52.039936
# MDH       39.743841   677.287105  6.884588  46.628429
# ...             ...          ...       ...        ...
# ACLS      -0.136708    82.172064  0.766817   0.630110
# DHAD1     -0.136708    82.172064  0.766817   0.630110
# KARA1      0.136708    82.172064 -0.766817  -0.630110
# ADK3       0.123519    82.172064 -0.692840  -0.569321
# HSDy       0.109153    82.172064 -0.612255  -0.503103
#
# [75 rows x 4 columns]

# %%
deviation_reactions(reaction1="PHEMEabcpp",solutionFBA=solutionFBA,reaction2="AACPS3")
# Out:
#            Deviation  percentaje      flux  new_flux
# Reaction
# HACD7      -0.112009   54.067447  0.243854  0.131846
# ACACT7r    -0.112009   54.067447  0.243854  0.131846
# ECOAH7     -0.112009   54.067447  0.243854  0.131846
# FACOAE160  -0.111929    0.000000  0.111929  0.000000
# ACOAD7f     0.111929   -0.000000 -0.111929  0.000000
# AACPS1      0.111862         NaN  0.000000  0.111862
# FACOAE140   0.111862         NaN  0.000000  0.111862
# 3OAR160     0.111862         NaN  0.000000  0.111862
# 3OAS160     0.111862         NaN  0.000000  0.111862
# EAR160x     0.111862         NaN  0.000000  0.111862
# 3HAD160     0.111862         NaN  0.000000  0.111862
# MCOATA      0.111821  263.828925  0.068255  0.180076
# ACCOAC      0.111821  263.824714  0.068257  0.180078
# HCO3E       0.111586  124.206696  0.460971  0.572557

# %% [markdown]
# Flux deviation NOT biomass-related heterogenity reactions

# %%
reactions_expressed_not_biomass_SRR1536433=gene_to_reaction(expressed_not_biomass_SRR1536433)
reactions_expressed_not_biomass_0_0=gene_to_reaction(expressed_not_biomass_0_0)
reactions_expressed_not_biomass_7_7=gene_to_reaction(expressed_not_biomass_7_7)
reactions_expressed_not_biomass_4_4=gene_to_reaction(expressed_not_biomass_4_4)
reactions_expressed_not_biomass_6_6=gene_to_reaction(expressed_not_biomass_6_6)

# %%
non_essential_reactions_not_biomass_SRR1536433 =non_essential(reactions_expressed_not_biomass_SRR1536433)
reaction_list_SRR1536433_not_biomass_active =active (non_essential_reactions_not_biomass_SRR1536433,active_reactionsFBA)
non_essential_reactions_not_biomass_0_0 =non_essential(reactions_expressed_not_biomass_0_0)
reaction_list_0_0_not_biomass_active =active (non_essential_reactions_not_biomass_0_0,active_reactionsFBA)
non_essential_reactions_not_biomass_7_7 =non_essential(reactions_expressed_not_biomass_7_7)
reaction_list_7_7_not_biomass_active =active (non_essential_reactions_not_biomass_7_7,active_reactionsFBA)
non_essential_reactions_not_biomass_4_4 =non_essential(reactions_expressed_not_biomass_4_4)
reaction_list_4_4_not_biomass_active =active (non_essential_reactions_not_biomass_4_4,active_reactionsFBA)
non_essential_reactions_not_biomass_6_6 =non_essential(reactions_expressed_not_biomass_6_6)
reaction_list_6_6_not_biomass_active =active (non_essential_reactions_not_biomass_6_6,active_reactionsFBA)

# %%
import itertools
import numpy as np

# %%
def deviation_reactions_pairwise (list_active,solutionFBA):
    combination= []
    for c in itertools.combinations(list_active, 2):
        combination.append(c)
    combinations_array = np.array(combination)
    lista=[]
    for i in range(1,len(combinations_array)):
        model_double_KO=model_M9.copy()
        model_double_KO.reactions.get_by_id(combinations_array[i][0]).bounds=(0,0)
        model_double_KO.reactions.get_by_id(combinations_array[i][1]).bounds=(0,0)
        solutionKO=model_double_KO.optimize()
        names=[]
        distances= []
        for flux in range(0,len(solutionKO.fluxes.index)):
            name=solutionKO.fluxes.index[flux]
            distance=abs(solutionKO[flux] - solutionFBA[flux])
            if distance > abs(solutionFBA[flux])*0.1 and distance > 0.1:
                names.append(name)
                distances.append(distance)
        wt_vs_KO={"Reaction":names,"Deviation":distances}
        df=pd.DataFrame(wt_vs_KO, columns=["Reaction","Deviation"])
        df=df.set_index("Reaction").sort_values(by="Deviation")
        pair=[combinations_array[i][0],combinations_array[i][1]]
        lista.append(pair)
        lista.append(df)
    return lista

# %%
flux_deviation_SRR1536433_not_biomass=deviation_reactions_pairwise(reaction_list_SRR1536433_not_biomass_active,solutionFBA)
flux_deviation_0_0_not_biomass=deviation_reactions_pairwise(reaction_list_0_0_not_biomass_active,solutionFBA)
flux_deviation_7_7_not_biomass=deviation_reactions_pairwise(reaction_list_7_7_not_biomass_active,solutionFBA)
flux_deviation_4_4_not_biomass=deviation_reactions_pairwise(reaction_list_4_4_not_biomass_active,solutionFBA)
flux_deviation_6_6_not_biomass=deviation_reactions_pairwise(reaction_list_6_6_not_biomass_active,solutionFBA)

# %%
flux_deviation_SRR1536433_not_biomass[0:4]
# Out:
# [['GAPD', 'E4PD'],
#            Deviation
#  Reaction
#  ACLS       0.102787
#  DHAD1      0.102787
#  KARA1      0.102787
#  EX_pi_e    0.113395
#  PItex      0.113395
#  ...             ...
#  PGM       16.861985
#  ENO       16.861985
#  GAPD      17.105434
#  PGK       17.105434
#  TPI       17.269003
#
#  [88 rows x 1 columns],
#  ['ATPS4rpp', 'E4PD'],
#              Deviation
#  Reaction
#  CYTK1        0.107166
#  PPNDH        0.109689
#  PHETA1       0.109689
#  EX_k_e       0.115567
#  Ktex         0.115567
#  ...               ...
#  QMO2        32.755910
#  LEUt2rpp    43.937619
#  LEUt3pp     43.937619
#  CYTBO3_4pp  44.256288
#  ATPS4rpp    70.432494
#
#  [200 rows x 1 columns]]
