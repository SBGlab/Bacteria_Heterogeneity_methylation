# %% [markdown]
# Load of model from smbl file, convert into excel and exploration

# %%
import cobra
from cobra.io import read_sbml_model
model = read_sbml_model("iML1515.xml")
from importExcelModel import *
cobrapy_to_excel(model,"iML1515.xlsx")
print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))
# Out:
# 2712
# 1877
# 1516

# %% [markdown]
# Write all metabolic genes to a text file to use as the functional enrichment backgorund

# %%
with open('metabolic genes.txt', 'w') as f:
    for i in model.genes:
        f.write(i.id)
        f.write('\n')

# %% [markdown]
# Saving/Restoring a Jupyter Notebook Session

# %% [markdown]
# #Save
# import dill
# dill.dump_session('iML1515_operon_env.db')

# %% [markdown]
# #Restore
# import dill
# dill.load_session("iML1515_operon_env.db")

# %% [markdown]
# LB media model

# %%
LB_medium = {key: 0.0 for key in model.medium}
print(LB_medium)
# Out:
# {'EX_pi_e': 0.0, 'EX_co2_e': 0.0, 'EX_fe3_e': 0.0, 'EX_h_e': 0.0, 'EX_mn2_e': 0.0, 'EX_fe2_e': 0.0, 'EX_glc__D_e': 0.0, 'EX_zn2_e': 0.0, 'EX_mg2_e': 0.0, 'EX_ca2_e': 0.0, 'EX_ni2_e': 0.0, 'EX_cu2_e': 0.0, 'EX_sel_e': 0.0, 'EX_cobalt2_e': 0.0, 'EX_h2o_e': 0.0, 'EX_mobd_e': 0.0, 'EX_so4_e': 0.0, 'EX_nh4_e': 0.0, 'EX_k_e': 0.0, 'EX_na1_e': 0.0, 'EX_cl_e': 0.0, 'EX_o2_e': 0.0, 'EX_tungs_e': 0.0, 'EX_slnt_e': 0.0}

# %%
import pandas as pd
df = pd.read_csv('media_db.tsv', sep='\t')
filtered_rows = df[df.iloc[:, 0] == 'LB']
metabolites = filtered_rows.iloc[:, 2].tolist()
exchange_metabolites = []
for i in metabolites:
    new_element = "EX_" + str(i) + "_e"
    exchange_metabolites.append(new_element)
print(exchange_metabolites)

elements_to_remove = ['EX_cro4_e', 'EX_fol_e',"EX_ribflv_e"]
exchange_metabolites = [x for x in exchange_metabolites if x not in elements_to_remove]

for exchange in LB_medium:
    LB_medium[exchange]=0.0

for i in exchange_metabolites:
    LB_medium[i]=1000

model_LB=model.copy()
model_LB.medium=LB_medium
# Out:
# ['EX_adn_e', 'EX_ala__L_e', 'EX_amp_e', 'EX_arg__L_e', 'EX_aso3_e', 'EX_asp__L_e', 'EX_ca2_e', 'EX_cbl1_e', 'EX_cd2_e', 'EX_cl_e', 'EX_cmp_e', 'EX_cobalt2_e', 'EX_cro4_e', 'EX_cu2_e', 'EX_cys__L_e', 'EX_dad_2_e', 'EX_dcyt_e', 'EX_fe2_e', 'EX_fe3_e', 'EX_fol_e', 'EX_glc__D_e', 'EX_glu__L_e', 'EX_gly_e', 'EX_gmp_e', 'EX_gsn_e', 'EX_h2o_e', 'EX_h2s_e', 'EX_h_e', 'EX_hg2_e', 'EX_his__L_e', 'EX_hxan_e', 'EX_ile__L_e', 'EX_ins_e', 'EX_k_e', 'EX_leu__L_e', 'EX_lipoate_e', 'EX_lys__L_e', 'EX_met__L_e', 'EX_mg2_e', 'EX_mn2_e', 'EX_mobd_e', 'EX_na1_e', 'EX_nac_e', 'EX_nh4_e', 'EX_ni2_e', 'EX_o2_e', 'EX_phe__L_e', 'EX_pheme_e', 'EX_pi_e', 'EX_pnto__R_e', 'EX_pro__L_e', 'EX_pydx_e', 'EX_ribflv_e', 'EX_ser__L_e', 'EX_so4_e', 'EX_thm_e', 'EX_thr__L_e', 'EX_thymd_e', 'EX_trp__L_e', 'EX_tyr__L_e', 'EX_ump_e', 'EX_ura_e', 'EX_uri_e', 'EX_val__L_e', 'EX_zn2_e']

# %%
model_LB.medium
# Out:
# {'EX_pi_e': 1000,
#  'EX_met__L_e': 1000,
#  'EX_hxan_e': 1000,
#  'EX_ile__L_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_leu__L_e': 1000,
#  'EX_h_e': 1000,
#  'EX_pro__L_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_ala__L_e': 1000,
#  'EX_arg__L_e': 1000,
#  'EX_asp__L_e': 1000,
#  'EX_thymd_e': 1000,
#  'EX_tyr__L_e': 1000,
#  'EX_dcyt_e': 1000,
#  'EX_glu__L_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_glc__D_e': 1000,
#  'EX_ura_e': 1000,
#  'EX_val__L_e': 1000,
#  'EX_gly_e': 1000,
#  'EX_lys__L_e': 1000,
#  'EX_ser__L_e': 1000,
#  'EX_thm_e': 1000,
#  'EX_trp__L_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_h2s_e': 1000,
#  'EX_amp_e': 1000,
#  'EX_adn_e': 1000,
#  'EX_ins_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_cbl1_e': 1000,
#  'EX_nac_e': 1000,
#  'EX_dad_2_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_ni2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_hg2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_pheme_e': 1000,
#  'EX_cd2_e': 1000,
#  'EX_gmp_e': 1000,
#  'EX_ump_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_pnto__R_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phe__L_e': 1000,
#  'EX_thr__L_e': 1000,
#  'EX_uri_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_cmp_e': 1000,
#  'EX_his__L_e': 1000,
#  'EX_k_e': 1000,
#  'EX_na1_e': 1000,
#  'EX_aso3_e': 1000,
#  'EX_cys__L_e': 1000,
#  'EX_gsn_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_lipoate_e': 1000,
#  'EX_pydx_e': 1000,
#  'EX_o2_e': 1000}

# %%
model_LB.optimize()
# Out:
# <Solution 63.279 at 0x1615c19cf90>

# %% [markdown]
# Extracting reactions associated to differentially methylated genes

# %%
associated_reactions = []
for gene_id in gene_list_genes_0_0:
    gene_obj = model.genes.get_by_id(gene_id)
    reactions = [reaction.id for reaction in gene_obj.reactions]
    associated_reactions.extend(reactions)
associated_reactions
# Out:
# ['DDPA',
#  'CFAS180G',
#  'CFAS160E',
#  'CFAS180E',
#  'CFAS160G',
#  'ACACT8r',
#  'ACACT7r',
#  'ACACT5r',
#  'ACACT1r',
#  'ACACT6r',
#  'ACACT4r',
#  'ACACT2r',
#  'ACACT3r',
#  'ECOAH6',
#  'HACD5',
#  'HACD2',
#  'ECOAH2',
#  'HACD3',
#  'ECOAH8',
#  'ECOAH3',
#  'HACD8',
#  'HACD7',
#  'HACD6',
#  'ECOAH5',
#  'ECOAH1',
#  'ECOAH4',
#  'ECOAH7',
#  'HACD1',
#  'HACD4',
#  'GLYCL',
#  'GLYCL',
#  'GLYCL',
#  'CAT',
#  'QULNS',
#  'NMNPtpp',
#  'ACNML',
#  'ACNAMt2pp',
#  'AMANAPEr',
#  'AMANK',
#  'AICART',
#  'IMPC',
#  'PRAGSr',
#  'KDOCT2',
#  'NO3R1bpp',
#  'NO3R2bpp',
#  'NO3R1bpp',
#  'NO3R1bpp',
#  'NO3R1bpp',
#  'NO3R2bpp',
#  'NO3R1bpp',
#  'NO3R2bpp',
#  'PHEMEabcpp',
#  'PHEMEabcpp',
#  'PHEMEabcpp',
#  'PHEMEabcpp',
#  'PHEMEabcpp',
#  'ILETA',
#  'TYRTA',
#  'PHETA1',
#  'LEUTAi',
#  'VALTA',
#  'DHAD1',
#  'DHAD2',
#  'THRD_L',
#  'FHL',
#  'FHL',
#  'FHL',
#  'FHL',
#  'FHL',
#  'FHL',
#  'FHL',
#  'FHL',
#  'FHL',
#  'FHL',
#  'FORtppi',
#  'FORt2pp',
#  'CAt6pp',
#  'A5PISO',
#  'KDOPP',
#  'ECA4COLIPAabctex',
#  'K2L4Aabctex',
#  'COLIPAPabctex',
#  'COLIPAabctex',
#  'LIPAabctex',
#  'O16A4COLIPAabctex',
#  'CLIPAabctex',
#  'ACOLIPAabctex',
#  'ENLIPAabctex',
#  'ECA4COLIPAabctex',
#  'K2L4Aabctex',
#  'COLIPAPabctex',
#  'COLIPAabctex',
#  'LIPAabctex',
#  'O16A4COLIPAabctex',
#  'CLIPAabctex',
#  'ACOLIPAabctex',
#  'ENLIPAabctex',
#  'ECA4COLIPAabctex',
#  'K2L4Aabctex',
#  'COLIPAPabctex',
#  'COLIPAabctex',
#  'LIPAabctex',
#  'O16A4COLIPAabctex',
#  'CLIPAabctex',
#  'ACOLIPAabctex',
#  'ENLIPAabctex',
#  'CUt2pp',
#  'NTP3',
#  'AI2abcpp',
#  'AI2abcpp',
#  'AI2abcpp',
#  'AI2abcpp',
#  'PAI2T',
#  'PAI2I',
#  'ACONMT',
#  'ACGAMT',
#  'ECAP3pp',
#  'ECAP2pp',
#  'ECAP1pp',
#  'UAG2E',
#  'UACMAMO',
#  'TDPGDH',
#  'G1PTT',
#  'TDPADGAT',
#  'TDPAGTA',
#  'ECAtpp',
#  'AADDGT',
#  'ECAP3pp',
#  'ECAP2pp',
#  'ECAP1pp',
#  'ACMAMUT',
#  'SBTptspp',
#  'MNLptspp',
#  'SBTptspp',
#  'MNLptspp',
#  'SBTptspp',
#  'MNLptspp',
#  'SBTPD',
#  'A5PISO',
#  'THRD_L',
#  'SERD_L',
#  'SERt2rpp',
#  'THRt2rpp',
#  'PPAKr',
#  'ACKr',
#  'PFL',
#  'OBTFL',
#  'SERD_L',
#  'EDTXS2',
#  'EDTXS4',
#  'NADPHXE',
#  'NADPHXD',
#  'NADHXE',
#  'NADHXD',
#  'AGM3PApp',
#  'AGM4PApp',
#  'NTP3',
#  'MCITL2',
#  'MCITS',
#  'MCITD',
#  'ACCOAL',
#  'PGMT',
#  'H2Otex']

# %%
#Forward single reactions to file and variable
import re

def gene_read(path):
    gene_list=[]
    with open (path,"r") as file:
        for line in file:
            line_elements = line.strip().split(',')
            gene_list.extend(line_elements)
    return(gene_list)


def gene_reaction_list (path):
    gene_list=[]
    with open (path,"r") as file:
        for line in file:
            line_elements = line.strip().split(',')
            gene_list.extend(line_elements)
    def gene_to_reaction(gene_list):
        associated_reactions = []
        for gene_id in gene_list:
            gene_obj = model.genes.get_by_id(gene_id)
            reactions = [reaction.id for reaction in gene_obj.reactions]
            associated_reactions.extend(reactions)
        return(associated_reactions)
    reactions= list(set(gene_to_reaction(gene_list)))
    start_index = path.index("_genelist")
    end_index = path.index("cobra_operon\\")+len("cobra_operon\\")
    substring = path[end_index:start_index]
    with open("reactions_"+ substring +"_operon.txt", 'w') as f:
        for i in reactions:
            f.write(i)
            f.write('\n')
    return(reactions)

# %%
gene_list_SRR1536433= gene_read (r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_SRR1536433_genelist_metabolic.txt")
gene_list_BSeq1=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_Bseq_1_genelist_metabolic.txt")
gene_list_BSeq2=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_Bseq_2_genelist_metabolic.txt")
gene_list_genes_0_0=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_0_0_genelist_metabolic.txt")
gene_list_genes_7_7=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_7_7_genelist_metabolic.txt")
gene_list_genes_4_4=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_4_4_genelist_metabolic.txt")
gene_list_genes_6_6=gene_read(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_6_6_genelist_metabolic.txt")

# %%
reaction_list_SRR1536433= gene_reaction_list (r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_SRR1536433_genelist_metabolic.txt")
reaction_list_BSeq1=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_Bseq_1_genelist_metabolic.txt")
reaction_list_BSeq2=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_Bseq_2_genelist_metabolic.txt")
reaction_list_genes_0_0=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_0_0_genelist_metabolic.txt")
reaction_list_genes_7_7=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_7_7_genelist_metabolic.txt")
reaction_list_genes_4_4=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_4_4_genelist_metabolic.txt")
reaction_list_genes_6_6=gene_reaction_list(r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\operon_6_6_genelist_metabolic.txt")

# %% [markdown]
# Expresion data heterogenity biomass

# %%
#Intersection of methylated genes with data from transcriptomics for genes responsible of heterogenity related to biomass production
expressed_biomass= open (r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\expressed_genes_heterogenity_biomass.txt", "r")
gene_expressed_biomass = expressed_biomass.read().split("\n")
def expressed_biomass_meth(gene_list):
    expressed_biomass_genes=[]
    for i in gene_expressed_biomass:
        if i in gene_list:
            expressed_biomass_genes.append(i)
    return(expressed_biomass_genes)

# %%
expressed_biomass_Bseq1=expressed_biomass_meth(gene_list_BSeq1)
expressed_biomass_Bseq2=expressed_biomass_meth(gene_list_BSeq2)
expressed_biomass_0_0=expressed_biomass_meth(gene_list_genes_0_0)
expressed_biomass_7_7=expressed_biomass_meth(gene_list_genes_7_7)
expressed_biomass_6_6=expressed_biomass_meth(gene_list_genes_6_6)
expressed_biomass_4_4=expressed_biomass_meth(gene_list_genes_4_4)
expressed_biomass_SRR1536433=expressed_biomass_meth(gene_list_SRR1536433)

# %%
with open('expressed_biomass.txt', 'w') as f:
    f.write("SRR1536433\n")
    for i in expressed_biomass_SRR1536433:
        f.write(i)
        f.write('\n')
    f.write("\n7_7\n")
    for i in expressed_biomass_7_7:
        f.write(i)
        f.write('\n')
    f.write("\n0_0\n")
    for i in expressed_biomass_0_0:
        f.write(i)        
        f.write('\n')
    f.write("\nBseq1\n")
    for i in expressed_biomass_Bseq1:
        f.write(i) 
        f.write('\n')
    f.write("\nBseq2\n")
    for i in expressed_biomass_Bseq2:
        f.write(i) 
        f.write('\n')
    f.write('\n4_4\n')
    for i in expressed_biomass_4_4:
        f.write(i)
        f.write('\n')
    f.write("\n6_6\n")
    for i in expressed_biomass_6_6:
        f.write(i)
        f.write("\n")

# %% [markdown]
# Expresion data heterogenity not biomass

# %%
#Intersection of methylated genes with data from transcriptomics for genes responsible of heterogenity related to metabolism different from biomass production

expressed_not_biomass= open (r"E:\Universidad\MBB\TFM\metabolic_model\cobra_operon\expressed_genes_nobiomass.txt", "r")
gene_expressed_not_biomass = expressed_not_biomass.read().split("\n")
def expressed_not_biomass_meth(gene_list):
    expressed_not_biomass_genes=[]
    for i in gene_expressed_not_biomass:
        if i in gene_list:
            expressed_not_biomass_genes.append(i)
    return(expressed_not_biomass_genes)

# %%
expressed_not_biomass_Bseq1=expressed_not_biomass_meth(gene_list_BSeq1)
expressed_not_biomass_Bseq2=expressed_not_biomass_meth(gene_list_BSeq2)
expressed_not_biomass_0_0=expressed_not_biomass_meth(gene_list_genes_0_0)
expressed_not_biomass_7_7=expressed_not_biomass_meth(gene_list_genes_7_7)
expressed_not_biomass_6_6=expressed_not_biomass_meth(gene_list_genes_6_6)
expressed_not_biomass_4_4=expressed_not_biomass_meth(gene_list_genes_4_4)
expressed_not_biomass_SRR1536433=expressed_not_biomass_meth(gene_list_SRR1536433)

# %%
with open('expressed_not_biomass.txt', 'w') as f:
    f.write("SRR1536433\n")
    for i in expressed_not_biomass_SRR1536433:
        f.write(i)
        f.write('\n')
    f.write("\n7_7\n")
    for i in expressed_not_biomass_7_7:
        f.write(i)
        f.write('\n')
    f.write("\n0_0\n")
    for i in expressed_not_biomass_0_0:
        f.write(i)
        f.write('\n')
    f.write("\nBseq1\n")
    for i in expressed_not_biomass_Bseq1:
        f.write(i)
        f.write('\n')
    f.write("\nBseq2\n")
    for i in expressed_not_biomass_Bseq2:
        f.write(i)
        f.write('\n')
    f.write('\n4_4\n')
    for i in expressed_not_biomass_4_4:
        f.write(i)
        f.write('\n')
    f.write("\n6_6\n")
    for i in expressed_not_biomass_6_6:
        f.write(i)
        f.write('\n')

# %% [markdown]
# Getting non-essential REACTIONS from my datasets

# %%
#Essential reactions according to the model
from cobra.flux_analysis import variability
essential_reactions_id=[]
essential_reactions=cobra.flux_analysis.variability.find_essential_reactions(model_LB)
for i in essential_reactions:
    essential_reactions_id.append(i.id)
    
len(essential_reactions_id)
essential_reactions_id
# Out:
# ['EX_mn2_e',
#  'LPADSS',
#  'CU2tpp',
#  'GLNS',
#  'AHCYSNS',
#  'Ktex',
#  'TDSK',
#  'PSD161',
#  'KDOPS',
#  'UAMAS',
#  'MOAT',
#  'PMDPHT',
#  'MTHFR2',
#  'PPCDC',
#  'HCO3E',
#  'SHCHD2',
#  'PGAMT',
#  'SDPTA',
#  'EX_ca2_e',
#  'DHNPA2r',
#  'TMPK',
#  'MOBDtex',
#  'DHDPS',
#  'GRTT',
#  'ADCS',
#  'GLUTRR',
#  'DXPS',
#  'METS',
#  'OPHBDC',
#  'PAPPT3',
#  'OCTDPS',
#  'MG2tex',
#  'ACCOAC',
#  'UGMDDS',
#  'MCOATA',
#  'MEPCT',
#  'DASYN160',
#  'G1PACT',
#  'DHFS',
#  'COBALT2tex',
#  'DHPPDA2',
#  'PE160abcpp',
#  'SHK3Dr',
#  'K2L4Aabctex',
#  'ADCL',
#  'UAGPT3',
#  'Zn2tex',
#  'METAT',
#  'EX_zn2_e',
#  'AGPAT160',
#  'UPP3S',
#  'DB4PS',
#  'DPCOAK',
#  'DASYN161',
#  'RHCCE',
#  'HPPK2',
#  'PE161abcpp',
#  'DNMPPA',
#  'DHPS2',
#  'SHCHF',
#  'EX_k_e',
#  'EX_ni2_e',
#  'DBTS',
#  'GTPCI',
#  'DTMPK',
#  'MEOHtex',
#  'PTPATi',
#  'OGMEACPR',
#  'UDCPDPS',
#  'SDPDS',
#  'ASPK',
#  'CDPMEK',
#  'DNTPPA',
#  'OPMEACPD',
#  'ALAR',
#  'EX_mg2_e',
#  'DMATT',
#  'MEOHtrpp',
#  'COBALT2tpp',
#  'PPNCL2',
#  'GF6PTA',
#  'MALCOAMT',
#  'DHQS',
#  'UDCPDP',
#  'AGPAT161',
#  'NADK',
#  'G1SAT',
#  'PSSA160',
#  'DXPRIi',
#  'A5PISO',
#  'K2L4Aabcpp',
#  'ASAD',
#  'OGMEACPS',
#  'EX_cobalt2_e',
#  'CHORS',
#  'UAPGR',
#  'DM_amob_c',
#  'OPMEACPR',
#  'UHGADA',
#  'FCLT',
#  'EPMEACPR',
#  'GK1',
#  'UAGDP',
#  'OPMEACPS',
#  'UPPDC1',
#  'U23GAAT',
#  'BIOMASS_Ec_iML1515_core_75p37M',
#  'EX_meoh_e',
#  'KDOCT2',
#  'DAPE',
#  'ALAALAr',
#  'AMAOTr',
#  'UAAGDS',
#  'MOBDabcpp',
#  'OGMEACPD',
#  'NI2tex',
#  'GTPCII2',
#  'EGMEACPR',
#  'MNtex',
#  '5DOAN',
#  'PMEACPE',
#  'CLtex',
#  'MOAT2',
#  'SHKK',
#  'RBFK',
#  'MPTG',
#  '3OAS140',
#  'PPA',
#  'NADS1',
#  'RBFSb',
#  'DM_5drib_c',
#  'UAGAAT',
#  'MECDPS',
#  'MECDPDH5',
#  'DHDPRy',
#  'DHQTi',
#  'BTS5',
#  'USHD',
#  'APRAUR',
#  'UPP3MT',
#  'FMNAT',
#  'CAt6pp',
#  'HMBS',
#  'GLUR',
#  'KDOPP',
#  'GLUTRS',
#  'EX_cu2_e',
#  'PSCVT',
#  'EX_cl_e',
#  '3OAR140',
#  'DHFR',
#  'CA2tex',
#  'DDPA',
#  'UMPK',
#  'PPBNGS',
#  'NNATr',
#  'EX_mobd_e',
#  'PSSA161',
#  'PNTK',
#  'CU2tex',
#  'AOXSr2',
#  'MCTP1App',
#  'RBFSa',
#  'UAGCVT',
#  'PSD160',
#  'HBZOPT',
#  'THDPS',
#  'CHRPL',
#  'UAMAGS']

# %%
#Intersection of my reactions to the non-essential
def non_essential(reaction_list):
    non_essential_reactions=[]
    for i in reaction_list:
        if i not in essential_reactions_id:
            non_essential_reactions.append(i)
    return (non_essential_reactions)

# %%
non_essential_reactions_SRR1536433 = non_essential(reaction_list_SRR1536433)
non_essential_reactions_BSeq1=non_essential(reaction_list_BSeq1)
non_essential_reactions_BSeq2 =non_essential(reaction_list_BSeq2)
non_essential_reactions_genes_0_0=non_essential(reaction_list_genes_0_0)
non_essential_reactions_genes_7_7=non_essential(reaction_list_genes_7_7)
non_essential_reactions_genes_6_6=non_essential(reaction_list_genes_6_6)
non_essential_reactions_genes_4_4=non_essential(reaction_list_genes_4_4)

# %% [markdown]
# Flux balance analysis and active reactions

# %%
#Active reactions in the wt strain solved with FBA
solutionFBA = model_LB.optimize()
active_reactionsFBA=[]
for i in range(0,len(solutionFBA.fluxes)):
    if abs(solutionFBA.fluxes[i])>0.0001:
        active_reactionsFBA.append(solutionFBA.fluxes.index[i])

print(len(active_reactionsFBA))
active_reactionsFBA
# Out:
# 480
# ['NDPK5',
#  'SHK3Dr',
#  'NDPK8',
#  'PYNP2r',
#  'CS',
#  'ICDHyr',
#  'ACALD',
#  'PPA',
#  'APRAUR',
#  'DB4PS',
#  'ALAR',
#  'RBFK',
#  'ALATA_L',
#  'PPM',
#  'ASPTA',
#  'RBFSb',
#  'PYK',
#  'SHCHD2',
#  'EX_co2_e',
#  'A5PISO',
#  'PMDPHT',
#  'CPPPGO',
#  'EX_met__L_e',
#  'ILETA',
#  'VALTA',
#  'RBFSa',
#  'ACHBS',
#  'DHAD2',
#  'ACLS',
#  'PSCVT',
#  'PTAr',
#  'CHORS',
#  'ACKr',
#  'EX_ile__L_e',
#  'EX_fe3_e',
#  'EX_leu__L_e',
#  'EX_h_e',
#  'DMATT',
#  'GRTT',
#  'UPP3S',
#  'EX_pro__L_e',
#  'UPPDC1',
#  'EX_ade_e',
#  'EX_mn2_e',
#  'EX_ac_e',
#  'EX_ala__L_e',
#  'EX_arg__L_e',
#  'EX_asp__L_e',
#  'EX_succ_e',
#  'EX_tyr__L_e',
#  'EX_dcyt_e',
#  'MOAT',
#  'EX_fum_e',
#  'EX_glu__L_e',
#  'UDCPDPS',
#  'ECOAH6',
#  'USHD',
#  'ENO',
#  'HCO3E',
#  'MGSA',
#  'ECOAH4',
#  'LPADSS',
#  'GLUTRS',
#  'TDSK',
#  'PGK',
#  'EX_xtsn_e',
#  'URIK1',
#  'CYTDK1',
#  'RPE',
#  'DHQTi',
#  'TALA',
#  'PUNP1',
#  'PUNP2',
#  'PUNP3',
#  'TKT1',
#  'EX_fe2_e',
#  'PUNP7',
#  'RNDR1',
#  'RNDR3',
#  'TMDS',
#  'PPCDC',
#  'DHAD1',
#  'EX_ura_e',
#  'EX_val__L_e',
#  'MDH',
#  'FUM',
#  'FMNAT',
#  'OHPBAT',
#  'THRD',
#  'KARA1',
#  'KARA2',
#  'EX_for_e',
#  'EX_gly_e',
#  'EX_lys__L_e',
#  'ACCOAC',
#  'NADK',
#  'EX_ser__L_e',
#  'EX_thm_e',
#  'EX_trp__L_e',
#  'GLUTRR',
#  'HACD6',
#  'ECOAH1',
#  'ECOAH2',
#  'G1SAT',
#  'KDOCT2',
#  'ECOAH3',
#  'DXPS',
#  'CDPMEK',
#  'MECDPS',
#  'PGAMT',
#  'UAGDP',
#  'UAGCVT',
#  'GLUR',
#  'NNDPR',
#  'HACD4',
#  'EX_zn2_e',
#  'HACD5',
#  'HACD7',
#  'DNMPPA',
#  'HPPK2',
#  'PTPATi',
#  'DXPRIi',
#  'GTPCII2',
#  'URIC',
#  'OPHBDC',
#  'GHMT2r',
#  'SDPDS',
#  'ADCS',
#  'ADCL',
#  'UMPK',
#  'DURIK1',
#  'ALLTN',
#  'UAPGR',
#  'PAPPT3',
#  'UAGPT3',
#  'NDPK7',
#  'GLYAT',
#  'F6PA',
#  'FADRx',
#  'NDPK4',
#  'FCLT',
#  'HBZOPT',
#  'PNTK',
#  'OCTDPS',
#  'DPCOAK',
#  'ASNS2',
#  'KDOPS',
#  'KDOPP',
#  'DMPPS',
#  'MCOATA',
#  'IPDPS',
#  'DAPE',
#  'DHDPRy',
#  'SDPTA',
#  'GUAD',
#  'DTMPK',
#  'TRDR',
#  'DDPA',
#  'RHCCE',
#  'EX_dha_e',
#  'G3PD2',
#  'GSNK',
#  'AACPS3',
#  'U23GAAT',
#  'UAAGDS',
#  'AACPS4',
#  'UAMAS',
#  'UAMAGS',
#  'DHPPDA2',
#  'AKGDH',
#  'UGMDDS',
#  'DCYTD',
#  'DBTS',
#  'UHGADA',
#  'UAGAAT',
#  'DHDPS',
#  'G1PACT',
#  'GF6PTA',
#  'PRPPS',
#  'NADS1',
#  'ASPK',
#  'ASAD',
#  'METAT',
#  'TMPK',
#  'PDX5PS',
#  'PPBNGS',
#  'URDGLYCD',
#  'CBMKr',
#  'PPNCL2',
#  'NNATr',
#  'GAPD',
#  'DM_amob_c',
#  'PPM2',
#  'MOAT2',
#  'EX_adn_e',
#  'EX_mg2_e',
#  'AHCYSNS',
#  'TMK',
#  'CAT',
#  'ACtex',
#  'CHRPL',
#  'ACACT7r',
#  'ADK3',
#  'ACACT2r',
#  'ACACT3r',
#  'ACACT4r',
#  'EX_dad_2_e',
#  'EX_ca2_e',
#  'GLUtex',
#  'Kt2pp',
#  'GLYtex',
#  'Htex',
#  'H2Otex',
#  'O2tpp',
#  'THMabcpp',
#  'THD2pp',
#  'TRPt2rpp',
#  'TYRt2rpp',
#  'URIt2pp_copy1',
#  'XTSNt2rpp',
#  'THRt4pp',
#  'GTPCI',
#  'DRPA',
#  'TKT2',
#  'UDCPDP',
#  'ATPS4rpp',
#  'CYTK1',
#  'ADEt2rpp',
#  'CO2tpp',
#  'DHAtpp',
#  'ADNt2pp_copy1',
#  'GK1',
#  'HIStex',
#  'HACD1',
#  'ILEtex',
#  'Ktex',
#  'O2tex',
#  'HACD2',
#  'ECOAH5',
#  'DHFS',
#  'EX_ni2_e',
#  'ASPtex',
#  'ABUTt2pp',
#  'PHEtex',
#  'CYSabcpp',
#  'CYTBDpp',
#  'CYTDt2pp_copy1',
#  'DADNt2pp',
#  'DCYTt2pp',
#  'CYTBD2pp',
#  'ACt2rpp',
#  'EX_meoh_e',
#  'METS',
#  'ASPO5',
#  'EX_cu2_e',
#  'LEUtex',
#  'LYStex',
#  'FUMtex',
#  'ACACT5r',
#  'FE2tex',
#  'DHPS2',
#  'MTHFC',
#  'MTHFD',
#  'QULNS',
#  'EX_cobalt2_e',
#  'ACACT6r',
#  'TRPtex',
#  'PTRCt2pp',
#  'PNTOtex',
#  'TYRtex',
#  'URAtex',
#  'URItex',
#  'VALtex',
#  'FORtppi',
#  'SERtex',
#  'FEROpp',
#  'SO4tex',
#  'SUCCtex',
#  'R1PK',
#  'R15BPK',
#  'FACOAE160',
#  'THRtex',
#  'METabcpp',
#  'NH4tpp',
#  'METtex',
#  'PNTOt4pp',
#  'PROt2rpp',
#  'MOBDabcpp',
#  'MOBDtex',
#  'NI2tex',
#  'EX_gmp_e',
#  'NTD4pp',
#  'DNTPPA',
#  'NTD9pp',
#  'NH4tex',
#  'ADEtex',
#  'ADNtex',
#  'ALAtex',
#  'DALAtex',
#  'ARGtex',
#  'FE3tex',
#  'MG2tex',
#  'Zn2tex',
#  'H2Otpp',
#  'CO2tex',
#  'GLUABUTt7pp',
#  'HISt2rpp',
#  'COBALT2tex',
#  'HMBS',
#  'MEPCT',
#  'GLUDy',
#  'PTRCORNt7pp',
#  'EX_h2o_e',
#  'EX_ala__D_e',
#  'THDPS',
#  'XTSNtex',
#  'ATPM',
#  'CYStex',
#  'THRD_L',
#  'DADNtex',
#  'EX_pnto__R_e',
#  'DHAtex',
#  'RNDR2',
#  'DHFR',
#  'XAND',
#  'HACD3',
#  'SHKK',
#  'DCYTtex',
#  'EX_mobd_e',
#  'EX_so4_e',
#  'EX_phe__L_e',
#  'EX_thr__L_e',
#  'EX_uri_e',
#  'E4PD',
#  'MTHFR2',
#  'EX_nh4_e',
#  'EX_cmp_e',
#  'AMAOTr',
#  'GLNS',
#  'EX_his__L_e',
#  'EX_k_e',
#  'ACACT1r',
#  'ARGORNt7pp',
#  'CMPtex',
#  'CU2tex',
#  'ALAALAr',
#  'CLtex',
#  'GMPtex',
#  'ADNK1',
#  'MNtex',
#  'SHCHF',
#  'SUCOAS',
#  'AACPS7',
#  'ECOAH7',
#  'UPP3MT',
#  'DHQS',
#  'DASYN160',
#  'DASYN161',
#  'EX_cys__L_e',
#  'FACOAE161',
#  'EX_gsn_e',
#  'THMtex',
#  'PROtex',
#  'EX_cl_e',
#  'GSNt2pp',
#  'GSNtex',
#  'FORtex',
#  'PHEt2rpp',
#  'PPPGO3',
#  'PDX5PO2',
#  'PGM',
#  'CYTBO3_4pp',
#  'TPI',
#  'OXAMTC',
#  'MPTG',
#  'RPI',
#  'MCTP1App',
#  'PERD',
#  '5DOAN',
#  'DM_5drib_c',
#  '12PPDRtpp',
#  'K2L4Aabcpp',
#  'FACOAE120',
#  'SO4t2pp',
#  'DM_oxam_c',
#  'ALR4x',
#  'PSSA161',
#  'PSD160',
#  'PSD161',
#  'ACONTb',
#  'CA2tex',
#  'SUCDi',
#  '12PPDRtex',
#  'EX_o2_e',
#  'G3PAT160',
#  'G3PAT161',
#  'AGPAT160',
#  '3OAS140',
#  '3OAR140',
#  'PE160abcpp',
#  'PE161abcpp',
#  'ACONTa',
#  'EX_12ppd__R_e',
#  'PSSA160',
#  'AGPAT161',
#  'ZN2tpp',
#  'NI2tpp',
#  'ACOAD7f',
#  'ACOAD5f',
#  'CAt6pp',
#  'ACOAD3f',
#  'ACOAD2f',
#  'ACOAD4f',
#  'ACOAD6f',
#  'NADH16pp',
#  'NADH17pp',
#  'LYSt2pp',
#  'COBALT2tpp',
#  'FE2tpp',
#  'MN2tpp',
#  'CLt3_2pp',
#  'POR5',
#  'MTHTHFSs',
#  'MALCOAMT',
#  'CU2tpp',
#  'MG2t3_2pp',
#  'OGMEACPS',
#  'OGMEACPR',
#  'OPMEACPS',
#  'CTECOAI7',
#  'K2L4Aabctex',
#  'OPMEACPD',
#  'EPMEACPR',
#  'AOXSr2',
#  'MEOHtrpp',
#  'OGMEACPD',
#  'EGMEACPR',
#  'OPMEACPR',
#  'PMEACPE',
#  'MEOHtex',
#  'ICYSDS',
#  'MECDPDH5',
#  'I4FE4SR',
#  'FLDR2',
#  'I2FE2SS',
#  'I2FE2ST',
#  'FESR',
#  'I2FE2SS2',
#  'I4FE4ST',
#  'BTS5',
#  'VPAMTr',
#  'PYK4',
#  'ALAtpp',
#  'DXYLONtpp',
#  'DXYLTD',
#  '2DDARAA',
#  'ALLTAMH2',
#  'UGCIAMH',
#  'SUCASPtpp',
#  'ACOAD1fr',
#  'DXYLONtex',
#  'ALR2x',
#  'EX_dxylnt_e',
#  'DHNPA2r',
#  'PYK2',
#  'PIt2rpp',
#  'LEUt2rpp',
#  'ILEt3pp',
#  'FESD1s',
#  'GLYtpp',
#  'I2FE2SR',
#  'THRt2rpp',
#  'SERt2rpp',
#  'URAtpp',
#  'FUMt1pp',
#  'BIOMASS_Ec_iML1515_core_75p37M',
#  'OPHHXy',
#  'DHPTDCs2',
#  'VALt3pp',
#  'DM_mththf_c']

# %%
#Growth rate in wt 
model.summary()._objective_value
# Out:
# 0.8769972142571599

# %% [markdown]
# Flux variability analysis deviating o.5 and 0.8 from the optimum and active reactions

# %%
#Reactions ranges in the wt strain solved with FVA at 0.5 of optimization
from cobra.flux_analysis import flux_variability_analysis
solutionFVA05=flux_variability_analysis(model_LB, fraction_of_optimum=0.5,loopless=False)

# %%
solutionFVA08=flux_variability_analysis(model_LB, fraction_of_optimum=0.8,loopless=False)

# %%
def active_solution(solution):
    active_reactions_list=[]
    for i in range(0,len(solution)):
        if abs(solution["minimum"].values[i]) >=0.0001 or abs(solution["maximum"].values[i]) >=0.0001:
            active_reactions_list.append(solution.index[i])
    return(active_reactions_list)

# %%
#Active reactions in the wt strain solved with FVA at 0.5 and 0.8 of optimization
active_reactions_FVA05=active_solution(solutionFVA05)
active_reactions_FVA08=active_solution(solutionFVA08)

# %% [markdown]
# Active and non-essential reactions regulated by methylation

# %%
#Active reactions each solution crossed with methylation-regulated reactions
def active_reactions(reaction_list,solution_reaction):
    active=[]
    for i in reaction_list:
        if i in solution_reaction:
            active.append(i)
    return (active)

# %%
active_reactions_BSeq1_FBA=active_reactions(reaction_list_BSeq1,active_reactionsFBA)
active_reactions_BSeq2_FBA=active_reactions(reaction_list_BSeq2,active_reactionsFBA)
active_reactions_0_0_FBA=active_reactions(reaction_list_genes_0_0,active_reactionsFBA)
active_reactions_7_7_FBA=active_reactions(reaction_list_genes_7_7,active_reactionsFBA)
active_reactions_4_4_FBA=active_reactions(reaction_list_genes_4_4,active_reactionsFBA)
active_reactions_6_6_FBA=active_reactions(reaction_list_genes_6_6,active_reactionsFBA)
active_reactions_SRR1536433_FBA=active_reactions(reaction_list_SRR1536433,active_reactionsFBA)

# %%
active_reactions_BSeq1_FVA05=active_reactions(reaction_list_BSeq1,active_reactions_FVA05)
active_reactions_BSeq2_FVA05=active_reactions(reaction_list_BSeq2,active_reactions_FVA05)
active_reactions_0_0_FVA05=active_reactions(reaction_list_genes_0_0,active_reactions_FVA05)
active_reactions_7_7_FVA05=active_reactions(reaction_list_genes_7_7,active_reactions_FVA05)
active_reactions_4_4_FVA05=active_reactions(reaction_list_genes_4_4,active_reactions_FVA05)
active_reactions_6_6_FVA05=active_reactions(reaction_list_genes_6_6,active_reactions_FVA05)
active_reactions_SRR1536433_FVA05=active_reactions(reaction_list_SRR1536433,active_reactions_FVA05)

# %%
active_reactions_BSeq1_FVA08=active_reactions(reaction_list_BSeq1,active_reactions_FVA08)
active_reactions_BSeq2_FVA08=active_reactions(reaction_list_BSeq2,active_reactions_FVA08)
active_reactions_0_0_FVA08=active_reactions(reaction_list_genes_0_0,active_reactions_FVA08)
active_reactions_7_7_FVA08=active_reactions(reaction_list_genes_7_7,active_reactions_FVA08)
active_reactions_4_4_FVA08=active_reactions(reaction_list_genes_4_4,active_reactions_FVA08)
active_reactions_6_6_FVA08=active_reactions(reaction_list_genes_6_6,active_reactions_FVA08)
active_reactions_SRR1536433_FVA08=active_reactions(reaction_list_SRR1536433,active_reactions_FVA08)

# %%
#Active, non-essential & methylation-regulated
def active_nonessential (non_essential_reactions,active_reactions):
    reaction_list_active=[]
    for reaction in active_reactions:
        if reaction in non_essential_reactions:
            reaction_list_active.append(reaction)
    return(reaction_list_active)

# %%
reaction_list_BSeq1_act_ne = active_nonessential(non_essential_reactions_BSeq1,active_reactionsFBA)
reaction_list_BSeq2_act_ne = active_nonessential(non_essential_reactions_BSeq2,active_reactionsFBA)
reaction_list_genes_0_0_act_ne = active_nonessential(non_essential_reactions_genes_0_0,active_reactionsFBA)
reaction_list_genes_7_7_act_ne =active_nonessential (non_essential_reactions_genes_7_7,active_reactionsFBA)
reaction_list_SRR1536433_act_ne =active_nonessential (non_essential_reactions_SRR1536433,active_reactionsFBA)
reaction_list_genes_6_6_act_ne =active_nonessential (non_essential_reactions_genes_6_6,active_reactionsFBA)
reaction_list_genes_4_4_act_ne =active_nonessential (non_essential_reactions_genes_4_4,active_reactionsFBA)

# %%
reaction_list_BSeq1_act_ne_FVA05 = active_nonessential(non_essential_reactions_BSeq1,active_reactions_FVA05)
reaction_list_BSeq2_act_ne_FVA05 = active_nonessential(non_essential_reactions_BSeq2,active_reactions_FVA05)
reaction_list_genes_0_0_act_ne_FVA05 = active_nonessential(non_essential_reactions_genes_0_0,active_reactions_FVA05)
reaction_list_genes_7_7_act_ne_FVA05 =active_nonessential (non_essential_reactions_genes_7_7,active_reactions_FVA05)
reaction_list_SRR1536433_act_ne_FVA05 =active_nonessential (non_essential_reactions_SRR1536433,active_reactions_FVA05)
reaction_list_genes_6_6_act_ne_FVA05 =active_nonessential (non_essential_reactions_genes_6_6,active_reactions_FVA05)
reaction_list_genes_4_4_act_ne_FVA05 =active_nonessential (non_essential_reactions_genes_4_4,active_reactions_FVA05)

# %%
reaction_list_BSeq1_act_ne_FVA08 = active_nonessential(non_essential_reactions_BSeq1,active_reactions_FVA08)
reaction_list_BSeq2_act_ne_FVA08 = active_nonessential(non_essential_reactions_BSeq2,active_reactions_FVA08)
reaction_list_genes_0_0_act_ne_FVA08 = active_nonessential(non_essential_reactions_genes_0_0,active_reactions_FVA08)
reaction_list_genes_7_7_act_ne_FVA08 =active_nonessential (non_essential_reactions_genes_7_7,active_reactions_FVA08)
reaction_list_SRR1536433_act_ne_FVA08 =active_nonessential (non_essential_reactions_SRR1536433,active_reactions_FVA08)
reaction_list_genes_6_6_act_ne_FVA08 =active_nonessential (non_essential_reactions_genes_6_6,active_reactions_FVA08)
reaction_list_genes_4_4_act_ne_FVA08 =active_nonessential (non_essential_reactions_genes_4_4,active_reactions_FVA08)

# %%
import pandas as pd
def reaction_class(reactions,active_reactions_FBA, active_reactions_FVA05, active_reactions_FVA08,essential_reactions,output_name):
    data = {'reactions': reactions, 
    'FBA': ['active' if x else 'innactive' for x in [r in active_reactions_FBA for r in reactions]],
    'FVA08': ['active' if x else 'innactive' for x in [r in active_reactions_FVA08 for r in reactions]],     
    'FVA05': ['active' if x else 'innactive' for x in [r in active_reactions_FVA05 for r in reactions]],
    'essentiality': ['essential' if x else 'non-essential' for x in [r in essential_reactions for r in reactions]]}
    df = pd.DataFrame(data)
    df.to_csv(str(output_name) +".txt", sep='\t', index=False)
    return df

# %%
reaction_class(reaction_list_genes_0_0,active_reactions_0_0_FBA,active_reactions_0_0_FVA05,active_reactions_0_0_FVA08,essential_reactions_id,"reaction_0_0_summary")
reaction_class(reaction_list_genes_7_7,active_reactions_0_0_FBA,active_reactions_7_7_FVA05,active_reactions_7_7_FVA08,essential_reactions_id,"reaction_7_7_summary")
reaction_class(reaction_list_genes_6_6,active_reactions_6_6_FBA,active_reactions_6_6_FVA05,active_reactions_6_6_FVA08,essential_reactions_id,"reaction_6_6_summary")
reaction_class(reaction_list_genes_4_4,active_reactions_4_4_FBA,active_reactions_4_4_FVA05,active_reactions_4_4_FVA08,essential_reactions_id,"reaction_4_4_summary")
reaction_class(reaction_list_SRR1536433,active_reactions_SRR1536433_FBA,active_reactions_SRR1536433_FVA05,active_reactions_SRR1536433_FVA08,essential_reactions_id,"reaction_SRR1536433_summary")
reaction_class(reaction_list_BSeq1,active_reactions_BSeq1_FBA,active_reactions_BSeq1_FVA05,active_reactions_BSeq1_FVA08,essential_reactions_id,"reaction_BSeq1_summary")
reaction_class(reaction_list_BSeq2,active_reactions_BSeq2_FBA,active_reactions_BSeq2_FVA05,active_reactions_BSeq2_FVA08,essential_reactions_id,"reaction_BSeq2_summary")
# Out:
#             reactions        FBA      FVA08      FVA05   essentiality
# 0          LIPAabctex  innactive  innactive  innactive  non-essential
# 1             ARMEPNS  innactive  innactive  innactive  non-essential
# 2           MEPNabcpp  innactive  innactive  innactive  non-essential
# 3                HXCT  innactive  innactive  innactive  non-essential
# 4               AP4AH  innactive  innactive  innactive  non-essential
# 5              HYD1pp  innactive  innactive  innactive  non-essential
# 6           PTRCabcpp  innactive  innactive  innactive  non-essential
# 7           MELIBt2pp  innactive  innactive  innactive  non-essential
# 8             NO3R2pp  innactive  innactive  innactive  non-essential
# 9            MNLptspp  innactive  innactive  innactive  non-essential
# 10              MI1PP  innactive  innactive  innactive  non-essential
# 11              CHOLD  innactive  innactive  innactive  non-essential
# 12        CLIPAabctex  innactive  innactive  innactive  non-essential
# 13           HEXt2rpp  innactive  innactive  innactive  non-essential
# 14             RPNTPH  innactive  innactive  innactive  non-essential
# 15               IPMD     active     active     active      essential
# 16               LACZ  innactive  innactive  innactive  non-essential
# 17           BETALDHy  innactive  innactive  innactive  non-essential
# 18           GLUabcpp  innactive  innactive  innactive  non-essential
# 19           NO3R2bpp  innactive  innactive  innactive  non-essential
# 20            LCTStpp  innactive  innactive  innactive  non-essential
# 21              DMPPS     active     active     active  non-essential
# 22         PHEMEabcpp  innactive     active     active  non-essential
# 23              PRCPD  innactive  innactive  innactive  non-essential
# 24               IPPS     active     active     active      essential
# 25            ACACT1r     active     active     active  non-essential
# 26               RBFK     active     active     active      essential
# 27              IPDPS     active     active     active  non-essential
# 28             HYD3pp  innactive  innactive  innactive  non-essential
# 29               DAPE     active     active     active      essential
# 30        K2L4Aabctex     active     active     active      essential
# 31               G2PP  innactive  innactive  innactive  non-essential
# 32           ACACt2pp  innactive  innactive  innactive  non-essential
# 33             R15BPK     active     active     active  non-essential
# 34      COLIPAPabctex  innactive  innactive  innactive  non-essential
# 35      ACOLIPAabctex  innactive  innactive  innactive  non-essential
# 36             PDX5PS     active     active     active      essential
# 37             HYD2pp  innactive  innactive  innactive  non-essential
# 38       ENLIPAabctex  innactive     active     active  non-essential
# 39             IPPMIa     active     active     active      essential
# 40             IPPMIb     active     active     active      essential
# 41           ACP1_FMN  innactive  innactive  innactive  non-essential
# 42   ECA4COLIPAabctex  innactive     active     active  non-essential
# 43       COLIPAabctex  innactive  innactive  innactive  non-essential
# 44                FBP  innactive  innactive  innactive  non-essential
# 45                CPL  innactive  innactive  innactive  non-essential
# 46         INDOLEt2pp  innactive  innactive  innactive  non-essential
# 47           NO3R1bpp  innactive  innactive  innactive  non-essential
# 48           BETALDHx  innactive  innactive  innactive  non-essential
# 49             ACACCT  innactive  innactive  innactive  non-essential
# 50           ASPabcpp  innactive  innactive  innactive  non-essential
# 51            NO3R1pp  innactive  innactive  innactive  non-essential
# 52           BUTt2rpp  innactive  innactive  innactive  non-essential
# 53  O16A4COLIPAabctex  innactive  innactive  innactive  non-essential
# 54              AP5AH  innactive  innactive  innactive  non-essential
# 55              FMNAT     active     active     active      essential
# 56             PMDPHT     active     active     active      essential
# 57            AMPNTAT  innactive  innactive  innactive  non-essential
# 58              GP4GH  innactive  innactive  innactive  non-essential
# 59              BUTCT  innactive  innactive  innactive  non-essential

# %% [markdown]
# Reaction knockouts FBA

# %%
def model_KO_solution(reaction_list_active):
    model_KO={}
    for reaction in reaction_list_active:
        model_copy=model_LB.copy()
        model_copy.reactions.get_by_id(reaction).bounds=(0,0)
        model_KO[reaction]=model_copy.optimize().objective_value
    return(model_KO)

# %%
print(solutionFBA)
model_Bseq1_KO = model_KO_solution(reaction_list_BSeq1_act_ne)
print("BSeq1",model_Bseq1_KO)
model_Bseq2_KO = model_KO_solution(reaction_list_BSeq2_act_ne)
print("BSeq1",model_Bseq2_KO)
model_genes_0_0_KO =model_KO_solution (reaction_list_genes_0_0_act_ne)
print("0_0",model_genes_0_0_KO)
model_genes_7_7_KO =model_KO_solution (reaction_list_genes_7_7_act_ne)
print("7_7",model_genes_7_7_KO)
model_SRR1536433_KO= model_KO_solution (reaction_list_SRR1536433_act_ne)
print("SRR1536433", model_SRR1536433_KO)
model_genes_4_4_KO =model_KO_solution (reaction_list_genes_4_4_act_ne)
print("4_4",model_genes_4_4_KO)
model_genes_6_6_KO =model_KO_solution (reaction_list_genes_6_6_act_ne)
print("6_6",model_genes_6_6_KO)
# Out:
# <Solution 63.279 at 0x23bbb90fc90>
# BSeq1 {'CS': 63.197824237167865, 'ACALD': 62.78904862420245, 'TALA': 62.98041634233694, 'TKT1': 62.85659153386877, 'FUM': 62.886646563560056, 'DMPPS': 63.27904311387939, 'IPDPS': 63.27904311387939, 'AACPS3': 63.173698368266464, 'AACPS4': 63.15491605754058, 'AKGDH': 54.297115013563825, 'PDX5PS': 63.27892179148904, 'ACtex': 52.70243277010935, 'GLUtex': 59.11336717423514, 'GLYtex': 62.98606008409955, 'Htex': 61.776686205313524, 'H2Otex': 62.68742531239399, 'TKT2': 62.8580169613947, 'ATPS4rpp': 51.081882025831185, 'HIStex': 62.82854155530533, 'ILEtex': 63.27904311387931, 'O2tex': 46.70535077016698, 'ASPtex': 62.806377862503346, 'ABUTt2pp': 63.27904311387939, 'PHEtex': 62.88234203832709, 'LEUtex': 63.197184701535406, 'LYStex': 62.81097653554601, 'FUMtex': 62.88665061003273, 'FE2tex': 62.36968286574876, 'TRPtex': 63.027772322756945, 'PNTOtex': 63.27796039193221, 'TYRtex': 62.972765354966114, 'URAtex': 63.2790431138795, 'VALtex': 63.17124736760366, 'FORtppi': 63.277770684869985, 'SERtex': 63.24486496013374, 'SO4tex': 63.271777879212195, 'SUCCtex': 62.23697839880964, 'R15BPK': 63.27904311387939, 'THRtex': 62.599602884319076, 'METtex': 63.064200566250975, 'NH4tex': 62.722575763279586, 'ADEtex': 63.00809358552812, 'ALAtex': 62.66484489533688, 'DALAtex': 63.278447922795955, 'ARGtex': 62.162734668117146, 'FE3tex': 62.384123853891104, 'CO2tex': 60.01934777798029, 'GLUDy': 63.102373875415466, 'XTSNtex': 63.27904311387939, 'CYStex': 63.02176585087428, 'DHAtex': 63.13424626922463, 'ACACT1r': 61.94106464546786, 'CMPtex': 63.025626619694144, 'GMPtex': 63.27904311387939, 'SUCOAS': 54.312076309728766, 'AACPS7': 63.21476506437721, 'THMtex': 63.27687944187216, 'PROtex': 63.10839351076073, 'GSNtex': 63.27904311387939, 'FORtex': 63.27894853969267, 'CYTBO3_4pp': 62.73317461365767, 'SUCDi': 63.27902354530589, '12PPDRtex': 63.04790287423027, 'G3PAT160': 63.27904311387939, 'G3PAT161': 63.27904311387939, 'NADH16pp': 63.279043113878735, 'NADH17pp': 63.27904311387951, 'SUCASPtpp': 63.27904311387931, 'DXYLONtex': 63.27901445500508, 'OPHHXy': 63.27873550998424}
# BSeq1 {'ACALD': 62.78904862420245, 'DMPPS': 63.27904311387939, 'IPDPS': 63.27904311387939, 'PDX5PS': 63.27892179148904, 'H2Otex': 62.68742531239399, 'URItex': 63.27904311387997, 'R15BPK': 63.27904311387939, 'PROt2rpp': 63.27904311387939, 'ADNtex': 63.27904311387939, 'DADNtex': 63.04341496252642, 'DCYTtex': 63.2785947532622, 'ACACT1r': 61.94106464546786, 'NADH16pp': 63.279043113878735, 'NADH17pp': 63.27904311387951, 'LEUt2rpp': 63.19718470153533}
# 0_0 {'ILETA': 63.269088043047226, 'VALTA': 63.123882946103706, 'DHAD2': 63.269088043047226, 'ACKr': 52.72486789728594, 'ECOAH6': 62.57836359969333, 'ECOAH4': 62.2478724809234, 'DHAD1': 63.14829396886527, 'HACD6': 62.57836359969333, 'ECOAH1': 61.94106464546781, 'ECOAH2': 61.94106464546781, 'ECOAH3': 61.941064645467826, 'HACD4': 62.24787248092328, 'HACD5': 62.412680534608405, 'HACD7': 63.049983848712486, 'CAT': 63.147076672833535, 'ACACT7r': 63.0499838487125, 'ACACT2r': 61.94106464546781, 'ACACT3r': 61.941064645467826, 'ACACT4r': 62.247872480923405, 'H2Otex': 62.68742531239399, 'HACD1': 61.94106464546781, 'HACD2': 61.94106464546781, 'ECOAH5': 62.41268053460842, 'ACACT5r': 62.41268053460838, 'QULNS': 63.277345165348855, 'ACACT6r': 62.57836359969329, 'FORtppi': 63.277770684869985, 'THRD_L': 63.269088043047226, 'HACD3': 61.941064645467826, 'ACACT1r': 61.94106464546786, 'ECOAH7': 63.04998384871252, 'THRt2rpp': 63.27904311387957, 'SERt2rpp': 63.27904311387939}
# 7_7 {'PPM': 63.27904311387939, 'ILETA': 63.269088043047226, 'VALTA': 63.123882946103706, 'DHAD2': 63.269088043047226, 'ECOAH6': 62.57836359969333, 'ECOAH4': 62.2478724809234, 'PUNP1': 63.27904311387939, 'PUNP2': 63.043414962527784, 'PUNP3': 63.15881932615503, 'DHAD1': 63.14829396886527, 'HACD6': 62.57836359969333, 'ECOAH1': 61.94106464546781, 'ECOAH2': 61.94106464546781, 'ECOAH3': 61.941064645467826, 'HACD4': 62.24787248092328, 'HACD5': 62.412680534608405, 'HACD7': 63.049983848712486, 'DMPPS': 63.27904311387939, 'IPDPS': 63.27904311387939, 'GUAD': 63.15881932615494, 'AKGDH': 54.297115013563825, 'PPM2': 62.74347236656262, 'CAT': 63.147076672833535, 'ACACT7r': 63.0499838487125, 'ACACT2r': 61.94106464546781, 'ACACT3r': 61.941064645467826, 'ACACT4r': 62.247872480923405, 'Kt2pp': 63.1280564684265, 'DRPA': 62.74347236656284, 'HACD1': 61.94106464546781, 'HACD2': 61.94106464546781, 'ECOAH5': 62.41268053460842, 'ACACT5r': 62.41268053460838, 'ACACT6r': 62.57836359969329, 'FORtppi': 63.277770684869985, 'PROt2rpp': 63.27904311387939, 'THRD_L': 63.269088043047226, 'HACD3': 61.941064645467826, 'ACACT1r': 61.94106464546786, 'SUCOAS': 54.312076309728766, 'ECOAH7': 63.04998384871252, 'PPPGO3': 63.27902018677779, 'CYTBO3_4pp': 62.73317461365767, 'SUCDi': 63.27902354530589, 'NADH16pp': 63.279043113878735, 'NADH17pp': 63.27904311387951, 'CTECOAI7': 63.15491605754061, 'SUCASPtpp': 63.27904311387931, 'LEUt2rpp': 63.19718470153533}
# SRR1536433 {'GAPD': 39.41105319366917, 'CAT': 63.147076672833535, 'ATPS4rpp': 51.081882025831185, 'E4PD': 63.278936120881}
# 4_4 {'PPM': 63.27904311387939, 'PUNP1': 63.27904311387939, 'PUNP2': 63.043414962527784, 'PUNP3': 63.15881932615503, 'PPM2': 62.74347236656262, 'H2Otex': 62.68742531239399, 'DRPA': 62.74347236656284, 'FORtppi': 63.277770684869985, 'DXYLTD': 63.27901445500508, '2DDARAA': 63.27901445500508}
# 6_6 {'PPM': 63.27904311387939, 'PUNP1': 63.27904311387939, 'PUNP2': 63.043414962527784, 'PUNP3': 63.15881932615503, 'PPM2': 62.74347236656262, 'URIt2pp_copy1': 63.27904311387951, 'DRPA': 62.74347236656284, 'ADNt2pp_copy1': 63.27904311387939, 'ABUTt2pp': 63.27904311387939, 'CYTDt2pp_copy1': 63.27904311387939, 'DADNt2pp': 63.043414962527685, 'DCYTt2pp': 63.2785947532622, 'R15BPK': 63.27904311387939, 'GSNt2pp': 62.75985153248138, 'CYTBO3_4pp': 62.73317461365767, 'RPI': 62.90498880739868, 'NADH16pp': 63.279043113878735, 'NADH17pp': 63.27904311387951, 'DXYLTD': 63.27901445500508, '2DDARAA': 63.27901445500508}

# %% [markdown]
# Constraints FVA 0.5 and 0.8

# %%
solutionFVA05.loc["PHEMEabcpp"]
# Out:
# minimum      0.000000
# maximum    119.832708
# Name: PHEMEabcpp, dtype: float64

# %%
model_copy = model_LB.copy()
model_copy.reactions.get_by_id("PHEMEabcpp").bounds = (119.832708, 119.832708)
model_copy.optimize().objective_value
# Out:
# 31.639524515495793

# %%
#Selecting active reaction rows in the table that has the reaction bounds for FVA 0.5 and 0.8
reaction_list_BSeq1_active_FVA05_solution = solutionFVA05.loc[reaction_list_BSeq1_act_ne_FVA05]
reaction_list_BSeq2_active_FVA05_solution = solutionFVA05.loc[reaction_list_BSeq2_act_ne_FVA05]
reaction_list_genes_0_0_active_FVA05_solution = solutionFVA05.loc[reaction_list_genes_0_0_act_ne_FVA05]
reaction_list_genes_7_7_active_FVA05_solution = solutionFVA05.loc[reaction_list_genes_7_7_act_ne_FVA05]
reaction_list_SRR1536433_active_FVA05_solution = solutionFVA05.loc[reaction_list_SRR1536433_act_ne_FVA05]
reaction_list_genes_4_4_active_FVA05_solution=solutionFVA05.loc[reaction_list_genes_4_4_act_ne_FVA05]
reaction_list_genes_6_6_active_FVA05_solution=solutionFVA05.loc[reaction_list_genes_6_6_act_ne_FVA05]

# %%
reaction_list_BSeq1_active_FVA08_solution = solutionFVA08.loc[reaction_list_BSeq1_act_ne_FVA08]
reaction_list_BSeq2_active_FVA08_solution = solutionFVA08.loc[reaction_list_BSeq2_act_ne_FVA08]
reaction_list_genes_0_0_active_FVA08_solution = solutionFVA08.loc[reaction_list_genes_0_0_act_ne_FVA08]
reaction_list_genes_7_7_active_FVA08_solution = solutionFVA08.loc[reaction_list_genes_7_7_act_ne_FVA08]
reaction_list_SRR1536433_active_FVA08_solution = solutionFVA08.loc[reaction_list_SRR1536433_act_ne_FVA08]
reaction_list_genes_6_6_active_FVA08_solution = solutionFVA08.loc[reaction_list_genes_6_6_act_ne_FVA08]
reaction_list_genes_4_4_active_FVA08_solution = solutionFVA08.loc[reaction_list_genes_4_4_act_ne_FVA08]

# %%
#for each active reaction solve the system by FBA constraining the lowerbound
def model_KO_minimum(reaction_list_active_solution):
    model_KO_minimum={}
    for reaction, row in reaction_list_active_solution.iterrows():
        min_bound = row['minimum']
        model_copy = model_LB.copy()
        model_copy.reactions.get_by_id(reaction).bounds = (min_bound, min_bound)
        model_KO_minimum[reaction]=model_copy.optimize().objective_value

    return(model_KO_minimum)

# %%
model_KO_minimum_BSeq1_FVA05=model_KO_minimum(reaction_list_BSeq1_active_FVA05_solution)
model_KO_minimum_BSeq2_FVA05=model_KO_minimum(reaction_list_BSeq2_active_FVA05_solution)
model_KO_minimum_genes_0_0_FVA05=model_KO_minimum(reaction_list_genes_0_0_active_FVA05_solution)
model_KO_minimum_genes_7_7_FVA05=model_KO_minimum(reaction_list_genes_7_7_active_FVA05_solution)
model_KO_minimum_SRR1536433_FVA05=model_KO_minimum(reaction_list_SRR1536433_active_FVA05_solution)
model_KO_minimum_genes_6_6_FVA05=model_KO_minimum(reaction_list_genes_6_6_active_FVA05_solution)
model_KO_minimum_genes_4_4_FVA05=model_KO_minimum(reaction_list_genes_4_4_active_FVA05_solution)

# %%
#for each active reaction solve the system by FBA constraining the upperbound

def model_KO_maximum(reaction_list_active_solution):
    model_KO_maximum={}
    for reaction, row in reaction_list_active_solution.iterrows():
        max_bound = row['maximum']
        model_copy = model_LB.copy()
        model_copy.reactions.get_by_id(reaction).bounds = (max_bound, max_bound)
        model_KO_maximum[reaction]=model_copy.optimize().objective_value
    return(model_KO_maximum)

# %%
model_KO_maximum_BSeq1_FVA05=model_KO_maximum(reaction_list_BSeq1_active_FVA05_solution)
model_KO_maximum_BSeq2_FVA05=model_KO_maximum(reaction_list_BSeq2_active_FVA05_solution)
model_KO_maximum_genes_0_0_FVA05=model_KO_maximum(reaction_list_genes_0_0_active_FVA05_solution)
model_KO_maximum_genes_7_7_FVA05=model_KO_maximum(reaction_list_genes_7_7_active_FVA05_solution)
model_KO_maximum_SRR1536433_FVA05=model_KO_maximum(reaction_list_SRR1536433_active_FVA05_solution)
model_KO_maximum_genes_6_6_FVA05=model_KO_maximum(reaction_list_genes_6_6_active_FVA05_solution)
model_KO_maximum_genes_4_4_FVA05=model_KO_maximum(reaction_list_genes_4_4_active_FVA05_solution)

# %%
model_KO_minimum_BSeq1_FVA08=model_KO_minimum(reaction_list_BSeq1_active_FVA08_solution)
model_KO_minimum_BSeq2_FVA08=model_KO_minimum(reaction_list_BSeq2_active_FVA08_solution)
model_KO_minimum_genes_0_0_FVA08=model_KO_minimum(reaction_list_genes_0_0_active_FVA08_solution)
model_KO_minimum_genes_7_7_FVA08=model_KO_minimum(reaction_list_genes_7_7_active_FVA08_solution)
model_KO_minimum_SRR1536433_FVA08=model_KO_minimum(reaction_list_SRR1536433_active_FVA08_solution)
model_KO_minimum_genes_6_6_FVA08=model_KO_minimum(reaction_list_genes_6_6_active_FVA08_solution)
model_KO_minimum_genes_4_4_FVA08=model_KO_minimum(reaction_list_genes_4_4_active_FVA08_solution)

# %%
model_KO_maximum_BSeq1_FVA08=model_KO_maximum(reaction_list_BSeq1_active_FVA08_solution)
model_KO_maximum_BSeq2_FVA08=model_KO_maximum(reaction_list_BSeq2_active_FVA08_solution)
model_KO_maximum_genes_0_0_FVA08=model_KO_maximum(reaction_list_genes_0_0_active_FVA08_solution)
model_KO_maximum_genes_7_7_FVA08=model_KO_maximum(reaction_list_genes_7_7_active_FVA08_solution)
model_KO_maximum_SRR1536433_FVA08=model_KO_maximum(reaction_list_SRR1536433_active_FVA08_solution)
model_KO_maximum_genes_6_6_FVA08=model_KO_maximum(reaction_list_genes_6_6_active_FVA08_solution)
model_KO_maximum_genes_4_4_FVA08=model_KO_maximum(reaction_list_genes_4_4_active_FVA08_solution)

# %% [markdown]
# Summary table

# %%
def summary (reaction_list_active_solution_08,model_KO,model_KO_minimum_08,model_KO_maximum_08,
reaction_list_active_solution_05,model_KO_minimum_05,model_KO_maximum_05):
    wt_ko=pd.DataFrame({'reaction':list(model_KO.keys()),
    'bounds FBA':(solutionFBA.fluxes.loc[list(model_KO.keys())]).tolist(),
    'solutionFBA_KO':list(model_KO.values())
    })
    FVA08=pd.DataFrame({'reaction':reaction_list_active_solution_08.index,
    'min_bound_08':reaction_list_active_solution_08["minimum"].tolist(),
    "max_bound_08":reaction_list_active_solution_08["maximum"].tolist(),
    'solution_min_08':list(model_KO_minimum_08.values()),
    'solution_max_08':list(model_KO_maximum_08.values())})
    FVA05=pd.DataFrame({'reaction':reaction_list_active_solution_05.index,
    'min_bound_05':reaction_list_active_solution_05["minimum"].tolist(),
    "max_bound_05":reaction_list_active_solution_05["maximum"].tolist(),
    'solution_min_05':list(model_KO_minimum_05.values()),
    'solution_max_05':list(model_KO_maximum_05.values())
    })
    df1 = pd.merge(wt_ko, FVA05, on="reaction",how="outer")
    df2 = pd.merge(df1, FVA08, on="reaction",how="outer")
    df2['deviation_FBA_KO']=((df2['solutionFBA_KO']-model_LB.summary()._objective_value))
    df2['deviation_min_05']=((df2['solution_min_05']-model_LB.summary()._objective_value))
    df2['deviation_max_05']=((df2['solution_max_05']-model_LB.summary()._objective_value))
    df2['deviation_min_08']=((df2['solution_min_08']-model_LB.summary()._objective_value))
    df2['deviation_max_08']=((df2['solution_max_08']-model_LB.summary()._objective_value))
    df2.iloc[:,1:]=df2.iloc[:,1:].round(6)
    return(df2)

# %%
SRR1536433_summary=summary(reaction_list_SRR1536433_active_FVA08_solution,
model_SRR1536433_KO,model_KO_minimum_SRR1536433_FVA08,model_KO_maximum_SRR1536433_FVA08,
reaction_list_SRR1536433_active_FVA05_solution,model_KO_minimum_SRR1536433_FVA05,
model_KO_maximum_SRR1536433_FVA05)

# %%
SRR1536433_summary
# Out:
#   reaction   bounds FBA  solutionFBA_KO  min_bound_05  max_bound_05  \
# 0     GAPD  1000.000000       39.411053   -303.955452   1000.000000
# 1      CAT    54.053036       63.147077      0.000000   1000.000000
# 2     E4PD     0.014111       63.278936     -0.049404      0.013987
# 3   NADHHR          NaN             NaN      0.000000   1000.000000
# 4  NADPHHR          NaN             NaN      0.000000   1000.000000
# 5  NADPHHS          NaN             NaN      0.000000   1000.000000
# 6   NADHHS          NaN             NaN      0.000000   1000.000000
#
#    solution_min_05  solution_max_05  min_bound_08  max_bound_08  \
# 0        31.639522        63.279043    461.054872   1000.000000
# 1        63.147077        56.197871      0.000000   1000.000000
# 2        31.639522        63.279042     -0.045161      0.014107
# 3        63.279043        50.754986      0.000000   1000.000000
# 4        63.279043        50.754986      0.000000   1000.000000
# 5        63.279043        50.754986      0.000000   1000.000000
# 6        63.279043        50.754986      0.000000   1000.000000
#
#    solution_min_08  solution_max_08  deviation_FBA_KO  deviation_min_05  \
# 0        50.623234        63.279043        -23.867990        -31.639522
# 1        63.147077        56.197871         -0.131966         -0.131966
# 2        50.623234        63.279043         -0.000107        -31.639522
# 3        63.279043        50.754986               NaN          0.000000
# 4        63.279043        50.754986               NaN          0.000000
# 5        63.279043        50.754986               NaN          0.000000
# 6        63.279043        50.754986               NaN          0.000000
#
#    deviation_max_05  deviation_min_08  deviation_max_08
# 0          0.000000        -12.655809          0.000000
# 1         -7.081172         -0.131966         -7.081172
# 2         -0.000001        -12.655809         -0.000000
# 3        -12.524057          0.000000        -12.524057
# 4        -12.524057          0.000000        -12.524057
# 5        -12.524057          0.000000        -12.524057
# 6        -12.524057          0.000000        -12.524057

# %%
gene_0_0_summary=summary(reaction_list_genes_0_0_active_FVA08_solution,
model_genes_0_0_KO,model_KO_minimum_genes_0_0_FVA08,model_KO_maximum_genes_0_0_FVA08,
reaction_list_genes_0_0_active_FVA05_solution,model_KO_minimum_genes_0_0_FVA05,model_KO_maximum_genes_0_0_FVA05)

# %%
gene_0_0_summary
# Out:
#   reaction  bounds FBA  solutionFBA_KO  min_bound_05  max_bound_05  \
# 0      CAT   54.053036       63.147077           0.0   1000.000000
# 1   EDTXS2         NaN             NaN           0.0     59.847542
# 2     NTP3         NaN             NaN           0.0   1000.000000
#
#    solution_min_05  solution_max_05  min_bound_08  max_bound_08  \
# 0        63.147077        56.197871           0.0   1000.000000
# 1        63.279043        31.639522           0.0     28.863462
# 2        63.279043        50.754986           0.0   1000.000000
#
#    solution_min_08  solution_max_08  deviation_FBA_KO  deviation_min_05  \
# 0        63.147077        56.197871         -0.131966         -0.131966
# 1        63.279043        50.623234               NaN          0.000000
# 2        63.279043        50.754986               NaN          0.000000
#
#    deviation_max_05  deviation_min_08  deviation_max_08
# 0         -7.081172         -0.131966         -7.081172
# 1        -31.639522          0.000000        -12.655809
# 2        -12.524057          0.000000        -12.524057

# %%
gene_4_4_summary=summary(reaction_list_genes_4_4_active_FVA08_solution,
model_genes_4_4_KO,model_KO_minimum_genes_4_4_FVA08,model_KO_maximum_genes_4_4_FVA08,
reaction_list_genes_4_4_active_FVA05_solution,model_KO_minimum_genes_4_4_FVA05,model_KO_maximum_genes_4_4_FVA05)

# %%
gene_4_4_summary
# Out:
#     bounds FBA  solutionFBA_KO    reaction  min_bound_05  max_bound_05  \
# 0          NaN             NaN       HXPRT           0.0    958.661668
# 1          NaN             NaN      PTRCTA           0.0   1000.000000
# 2          NaN             NaN       SPODM           0.0   1000.000000
# 3          NaN             NaN      GLCDpp           0.0   1000.000000
# 4          NaN             NaN  FEENTERtex           0.0   1000.000000
# 5          NaN             NaN   AMPTASECG           0.0    638.171584
# 6          NaN             NaN       LALGP           0.0    214.087054
# 7          NaN             NaN    AGM4PApp           0.0    255.001148
# 8          NaN             NaN  INDOLEt2pp           0.0   1000.000000
# 9          NaN             NaN      GUAPRT           0.0    958.661668
# 10         NaN             NaN    AGM3PApp           0.0    256.713776
# 11         NaN             NaN   CDAPPA161           0.0    958.661668
# 12         NaN             NaN   CDAPPA160           0.0    958.661668
# 13         NaN             NaN   CDAPPA141           0.0    958.661668
# 14         NaN             NaN   CDAPPA140           0.0    958.661668
# 15         NaN             NaN   CDAPPA180           0.0    958.661668
# 16         NaN             NaN   CDAPPA181           0.0    958.661668
# 17         NaN             NaN   CDAPPA120           0.0    958.661668
# 18         NaN             NaN       CMtpp           0.0   1000.000000
# 19         NaN             NaN     FUSAtpp           0.0   1000.000000
# 20         NaN             NaN   MINCYCtpp           0.0   1000.000000
# 21         NaN             NaN  DOXRBCNtpp           0.0   1000.000000
# 22         NaN             NaN   NOVBCNtpp           0.0   1000.000000
# 23         NaN             NaN   TTRCYCtpp           0.0   1000.000000
# 24         NaN             NaN    RFAMPtpp           0.0   1000.000000
#
#     solution_min_05  solution_max_05  min_bound_08  max_bound_08  \
# 0         63.279043        31.639522           0.0    505.259946
# 1         63.279043        50.875332           0.0   1000.000000
# 2         63.279043        62.625190           0.0   1000.000000
# 3         63.279043        58.621492           0.0   1000.000000
# 4         63.279043        46.023397           0.0    776.692179
# 5         63.279043        31.639522           0.0    256.541086
# 6         63.279043        31.639522           0.0     85.715809
# 7         63.279043        31.639522           0.0    103.213245
# 8         63.279043        63.279043           0.0   1000.000000
# 9         63.279043        31.639522           0.0    522.679840
# 10        63.279043        31.639522           0.0    103.213245
# 11        63.279043        31.639522           0.0    505.259946
# 12        63.279043        31.639522           0.0    505.259946
# 13        63.279043        31.639522           0.0    505.259946
# 14        63.279043        31.639522           0.0    505.259946
# 15        63.279043        31.639522           0.0    505.259946
# 16        63.279043        31.639522           0.0    505.259946
# 17        63.279043        31.639522           0.0    505.259946
# 18        63.279043        63.008094           0.0   1000.000000
# 19        63.279043        63.008094           0.0   1000.000000
# 20        63.279043        63.008094           0.0   1000.000000
# 21        63.279043        63.008094           0.0   1000.000000
# 22        63.279043        63.008094           0.0   1000.000000
# 23        63.279043        63.008094           0.0   1000.000000
# 24        63.279043        63.008094           0.0   1000.000000
#
#     solution_min_08  solution_max_08  deviation_FBA_KO  deviation_min_05  \
# 0         63.279043        50.623234               NaN               0.0
# 1         63.279043        50.875332               NaN               0.0
# 2         63.279043        62.625190               NaN               0.0
# 3         63.279043        58.621492               NaN               0.0
# 4         63.279043        50.623234               NaN               0.0
# 5         63.279043        50.623234               NaN               0.0
# 6         63.279043        50.623234               NaN               0.0
# 7         63.279043        50.623234               NaN               0.0
# 8         63.279043        63.279043               NaN               0.0
# 9         63.279043        50.623234               NaN               0.0
# 10        63.279043        50.623234               NaN               0.0
# 11        63.279043        50.623234               NaN               0.0
# 12        63.279043        50.623234               NaN               0.0
# 13        63.279043        50.623234               NaN               0.0
# 14        63.279043        50.623234               NaN               0.0
# 15        63.279043        50.623234               NaN               0.0
# 16        63.279043        50.623234               NaN               0.0
# 17        63.279043        50.623234               NaN               0.0
# 18        63.279043        63.008094               NaN               0.0
# 19        63.279043        63.008094               NaN               0.0
# 20        63.279043        63.008094               NaN               0.0
# 21        63.279043        63.008094               NaN               0.0
# 22        63.279043        63.008094               NaN               0.0
# 23        63.279043        63.008094               NaN               0.0
# 24        63.279043        63.008094               NaN               0.0
#
#     deviation_max_05  deviation_min_08  deviation_max_08
# 0         -31.639522               0.0        -12.655809
# 1         -12.403711               0.0        -12.403711
# 2          -0.653854               0.0         -0.653854
# 3          -4.657551               0.0         -4.657551
# 4         -17.255647               0.0        -12.655809
# 5         -31.639522               0.0        -12.655809
# 6         -31.639522               0.0        -12.655809
# 7         -31.639522               0.0        -12.655809
# 8           0.000000               0.0          0.000000
# 9         -31.639522               0.0        -12.655809
# 10        -31.639522               0.0        -12.655809
# 11        -31.639522               0.0        -12.655809
# 12        -31.639522               0.0        -12.655809
# 13        -31.639522               0.0        -12.655809
# 14        -31.639522               0.0        -12.655809
# 15        -31.639522               0.0        -12.655809
# 16        -31.639522               0.0        -12.655809
# 17        -31.639522               0.0        -12.655809
# 18         -0.270950               0.0         -0.270950
# 19         -0.270950               0.0         -0.270950
# 20         -0.270950               0.0         -0.270950
# 21         -0.270950               0.0         -0.270950
# 22         -0.270950               0.0         -0.270950
# 23         -0.270950               0.0         -0.270950
# 24         -0.270950               0.0         -0.270950

# %%
gene_6_6_summary=summary(reaction_list_genes_6_6_active_FVA08_solution,
model_genes_6_6_KO,model_KO_minimum_genes_6_6_FVA08,model_KO_maximum_genes_6_6_FVA08,
reaction_list_genes_6_6_active_FVA05_solution,model_KO_minimum_genes_6_6_FVA05,model_KO_maximum_genes_6_6_FVA05)

# %%
gene_6_6_summary
# Out:
#   reaction  bounds FBA  solutionFBA_KO  min_bound_05  max_bound_05  \
# 0      RPI  338.338119       62.904989       -1000.0   1000.000000
# 1     GLUN         NaN             NaN           0.0    988.663022
# 2   ADNCYC         NaN             NaN           0.0    958.661668
#
#    solution_min_05  solution_max_05  min_bound_08  max_bound_08  \
# 0        46.001589        62.575103   -802.965046   1000.000000
# 1        63.279043        31.639522      0.000000    981.860834
# 2        63.279043        31.639522      0.000000    505.259946
#
#    solution_min_08  solution_max_08  deviation_FBA_KO  deviation_min_05  \
# 0        50.623234        62.575103         -0.374054        -17.277455
# 1        63.279043        50.623234               NaN          0.000000
# 2        63.279043        50.623234               NaN          0.000000
#
#    deviation_max_05  deviation_min_08  deviation_max_08
# 0         -0.703940        -12.655809         -0.703940
# 1        -31.639522          0.000000        -12.655809
# 2        -31.639522          0.000000        -12.655809

# %%
gene_7_7_summary=summary(reaction_list_genes_7_7_active_FVA08_solution,
model_genes_7_7_KO,model_KO_minimum_genes_7_7_FVA08,model_KO_maximum_genes_7_7_FVA08,
reaction_list_genes_7_7_active_FVA05_solution,model_KO_minimum_genes_7_7_FVA05,model_KO_maximum_genes_7_7_FVA05)

# %%
gene_7_7_summary
# Out:
#      reaction  bounds FBA  solutionFBA_KO  min_bound_05  max_bound_05  \
# 0         CAT   54.053036       63.147077           0.0   1000.000000
# 1       NADH9         NaN             NaN           0.0   1000.000000
# 2      NADH10         NaN             NaN           0.0   1000.000000
# 3      PYDXNK         NaN             NaN           0.0   1000.000000
# 4       PYDXK         NaN             NaN           0.0   1000.000000
# 5      GSPMDA         NaN             NaN           0.0   1000.000000
# 6      GSPMDS         NaN             NaN           0.0   1000.000000
# 7       NADH5         NaN             NaN           0.0   1000.000000
# 8     PPGPPDP         NaN             NaN           0.0    958.661668
# 9      GDPDPK         NaN             NaN           0.0    958.661668
# 10  NI2uabcpp         NaN             NaN           0.0   1000.000000
# 11  MG2uabcpp         NaN             NaN           0.0   1000.000000
# 12   MCTP2App         NaN             NaN           0.0     85.000383
# 13     PYDAMK         NaN             NaN           0.0   1000.000000
# 14   GLYBt2pp         NaN             NaN           0.0   1000.000000
# 15    CHLt2pp         NaN             NaN           0.0   1000.000000
# 16    GLYt2pp         NaN             NaN           0.0   1000.000000
# 17    GDPTPDP         NaN             NaN           0.0    958.661668
#
#     solution_min_05  solution_max_05  min_bound_08  max_bound_08  \
# 0         63.147077        56.197871           0.0   1000.000000
# 1         63.279043        62.453404           0.0   1000.000000
# 2         63.279043        62.453424           0.0   1000.000000
# 3         63.279043        50.754986           0.0   1000.000000
# 4         63.279043        50.755031           0.0   1000.000000
# 5         63.279043        50.754986           0.0   1000.000000
# 6         63.279043        50.754986           0.0   1000.000000
# 7         63.279043        62.453424           0.0   1000.000000
# 8         63.279043        31.639522           0.0    505.259946
# 9         63.279043        31.639522           0.0    505.259946
# 10        63.279043        50.484200           0.0    989.133574
# 11        63.279043        50.213405           0.0    968.633057
# 12        63.279043        31.639522           0.0     34.404415
# 13        63.279043        50.754986           0.0   1000.000000
# 14        63.279043        62.733175           0.0   1000.000000
# 15        63.279043        62.733175           0.0   1000.000000
# 16        63.279043        62.766584           0.0   1000.000000
# 17        63.279043        31.639522           0.0    505.259946
#
#     solution_min_08  solution_max_08  deviation_FBA_KO  deviation_min_05  \
# 0         63.147077        56.197871         -0.131966         -0.131966
# 1         63.279043        62.453404               NaN          0.000000
# 2         63.279043        62.453424               NaN          0.000000
# 3         63.279043        50.754986               NaN          0.000000
# 4         63.279043        50.755031               NaN          0.000000
# 5         63.279043        50.754986               NaN          0.000000
# 6         63.279043        50.754986               NaN          0.000000
# 7         63.279043        62.453424               NaN          0.000000
# 8         63.279043        50.623234               NaN          0.000000
# 9         63.279043        50.623234               NaN          0.000000
# 10        63.279043        50.623234               NaN          0.000000
# 11        63.279043        50.623234               NaN          0.000000
# 12        63.279043        50.623234               NaN          0.000000
# 13        63.279043        50.754986               NaN          0.000000
# 14        63.279043        62.733175               NaN          0.000000
# 15        63.279043        62.733175               NaN          0.000000
# 16        63.279043        62.766584               NaN          0.000000
# 17        63.279043        50.623234               NaN          0.000000
#
#     deviation_max_05  deviation_min_08  deviation_max_08
# 0          -7.081172         -0.131966         -7.081172
# 1          -0.825640          0.000000         -0.825640
# 2          -0.825620          0.000000         -0.825620
# 3         -12.524057          0.000000        -12.524057
# 4         -12.524012          0.000000        -12.524012
# 5         -12.524057          0.000000        -12.524057
# 6         -12.524057          0.000000        -12.524057
# 7          -0.825620          0.000000         -0.825620
# 8         -31.639522          0.000000        -12.655809
# 9         -31.639522          0.000000        -12.655809
# 10        -12.794843          0.000000        -12.655809
# 11        -13.065638          0.000000        -12.655809
# 12        -31.639522          0.000000        -12.655809
# 13        -12.524057          0.000000        -12.524057
# 14         -0.545869          0.000000         -0.545869
# 15         -0.545869          0.000000         -0.545869
# 16         -0.512459          0.000000         -0.512459
# 17        -31.639522          0.000000        -12.655809

# %%
BSeq1_summary=summary(reaction_list_BSeq1_active_FVA08_solution,
model_Bseq1_KO,model_KO_minimum_BSeq1_FVA08,model_KO_maximum_BSeq1_FVA08,
reaction_list_BSeq1_active_FVA05_solution,model_KO_minimum_BSeq1_FVA05,model_KO_maximum_BSeq1_FVA05)

# %%
BSeq1_summary
# Out:
#        reaction   bounds FBA  solutionFBA_KO  min_bound_05  max_bound_05  \
# 0         ACtex -1000.000000       52.702433  -1000.000000     -0.000000
# 1        GLUtex  1000.000000       59.113367  -1000.000000   1000.000000
# 2        GLYtex  -905.201781       62.986060  -1000.000000   1000.000000
# 3          Htex -1000.000000       61.776686  -1000.000000   1000.000000
# 4        H2Otex   589.651140       62.687425  -1000.000000   1000.000000
# ..          ...          ...             ...           ...           ...
# 109      FMNtex          NaN             NaN      0.000000    481.805840
# 110      FADtex          NaN             NaN      0.000000    353.867753
# 111      AI2tex          NaN             NaN   -812.043256      0.000000
# 112     FUSAtex          NaN             NaN      0.000000   1000.000000
# 113  4ABZGLUtex          NaN             NaN   -616.346907      0.000000
#
#      solution_min_05  solution_max_05  min_bound_08  max_bound_08  \
# 0          63.279043        52.702433  -1000.000000      0.000000
# 1          52.713757        63.279043  -1000.000000   1000.000000
# 2          63.136384        62.017625  -1000.000000   1000.000000
# 3          63.279043        56.317248  -1000.000000   1000.000000
# 4          61.010124        63.279043  -1000.000000   1000.000000
# ..               ...              ...           ...           ...
# 109        63.279043        31.639522      0.000000    237.967735
# 110        63.279043        31.639522      0.000000    146.478316
# 111        31.639522        63.279043   -325.146471      0.000000
# 112        63.279043        63.008094      0.000000   1000.000000
# 113        31.639522        63.279043   -253.216041      0.000000
#
#      solution_min_08  solution_max_08  deviation_FBA_KO  deviation_min_05  \
# 0          63.279043        52.702433        -10.576610          0.000000
# 1          52.713757        63.279043         -4.165676        -10.565286
# 2          63.136384        62.017625         -0.292983         -0.142660
# 3          63.279043        56.317248         -1.502357          0.000000
# 4          61.010124        63.279043         -0.591618         -2.268919
# ..               ...              ...               ...               ...
# 109        63.279043        50.623234               NaN          0.000000
# 110        63.279043        50.623234               NaN          0.000000
# 111        50.623234        63.279043               NaN        -31.639522
# 112        63.279043        63.008094               NaN          0.000000
# 113        50.623234        63.279043               NaN        -31.639522
#
#      deviation_max_05  deviation_min_08  deviation_max_08
# 0          -10.576610          0.000000        -10.576610
# 1            0.000000        -10.565286          0.000000
# 2           -1.261418         -0.142660         -1.261418
# 3           -6.961795          0.000000         -6.961795
# 4            0.000000         -2.268919          0.000000
# ..                ...               ...               ...
# 109        -31.639522          0.000000        -12.655809
# 110        -31.639522          0.000000        -12.655809
# 111          0.000000        -12.655809          0.000000
# 112         -0.270950          0.000000         -0.270950
# 113          0.000000        -12.655809          0.000000
#
# [114 rows x 16 columns]

# %%
BSeq2_summary=summary(reaction_list_BSeq2_active_FVA08_solution,
model_Bseq2_KO,model_KO_minimum_BSeq2_FVA08,model_KO_maximum_BSeq2_FVA08,
reaction_list_BSeq2_active_FVA05_solution,model_KO_minimum_BSeq2_FVA05,model_KO_maximum_BSeq2_FVA05)

# %%
BSeq2_summary
# Out:
#   reaction   bounds FBA  solutionFBA_KO  min_bound_05  max_bound_05  \
# 0   URItex   407.221353       63.279043       -1000.0        1000.0
# 1   ADNtex    12.944741       63.279043       -1000.0        1000.0
# 2  DADNtex  1000.000000       63.043415           0.0        1000.0
# 3  DCYTtex     1.655759       63.278595           0.0        1000.0
# 4   GUAtex          NaN             NaN       -1000.0          -0.0
# 5   INStex          NaN             NaN       -1000.0        1000.0
#
#    solution_min_05  solution_max_05  min_bound_08  max_bound_08  \
# 0        63.164682        63.128250       -1000.0        1000.0
# 1        63.128065        63.048299       -1000.0        1000.0
# 2        63.043415        63.279043           0.0        1000.0
# 3        63.278595        62.659145           0.0        1000.0
# 4        62.651958        63.279043       -1000.0          -0.0
# 5        62.733175        63.125936       -1000.0        1000.0
#
#    solution_min_08  solution_max_08  deviation_FBA_KO  deviation_min_05  \
# 0        63.164682        63.128250          0.000000         -0.114361
# 1        63.128065        63.048299          0.000000         -0.150979
# 2        63.043415        63.279043         -0.235628         -0.235628
# 3        63.278595        62.659145         -0.000448         -0.000448
# 4        62.651958        63.279043               NaN         -0.627085
# 5        62.733175        63.125936               NaN         -0.545869
#
#    deviation_max_05  deviation_min_08  deviation_max_08
# 0         -0.150793         -0.114361         -0.150793
# 1         -0.230744         -0.150979         -0.230744
# 2          0.000000         -0.235628          0.000000
# 3         -0.619898         -0.000448         -0.619898
# 4          0.000000         -0.627085          0.000000
# 5         -0.153107         -0.545869         -0.153107

# %% [markdown]
# Double reaction knock out FBA

# %%
import pandas as pd
from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,double_reaction_deletion)

# %%
cobra_model=model_LB.copy()
double_KO_reaction_BSeq1= double_reaction_deletion(cobra_model,reaction_list_BSeq1_act_ne)
double_KO_reaction_BSeq2= double_reaction_deletion(cobra_model,reaction_list_BSeq2_act_ne)
double_KO_reaction_gene_0_0= double_reaction_deletion(cobra_model,reaction_list_genes_0_0_act_ne)
double_KO_reaction_gene_7_7= double_reaction_deletion(cobra_model,reaction_list_genes_7_7_act_ne)
double_KO_reaction_SRR1536433=double_reaction_deletion(cobra_model,reaction_list_SRR1536433_act_ne)

# %%
double_KO_reaction_BSeq1["growth"]=double_KO_reaction_BSeq1["growth"].round(6)
double_KO_reaction_BSeq1.sort_values(by="growth")
# Out:
#                   ids     growth   status
# 128  {O2tex, SUCCtex}  -0.000000  optimal
# 158   {ASPtex, O2tex}  37.927906  optimal
# 347    {ACtex, O2tex}  38.150299  optimal
# 636   {H2Otex, O2tex}  38.499520  optimal
# 122   {CO2tex, O2tex}  40.266083  optimal
# ..                ...        ...      ...
# 335  {URAtex, GSNtex}  63.279043  optimal
# 315  {ILEtex, URAtex}  63.279043  optimal
# 191          {URAtex}  63.279043  optimal
# 121          {GMPtex}  63.279043  optimal
# 269         {XTSNtex}  63.279043  optimal
#
# [820 rows x 3 columns]

# %%
double_KO_reaction_BSeq2["growth"]=double_KO_reaction_BSeq2["growth"].round(6)
double_KO_reaction_BSeq2.sort_values(by="growth")

# %%
double_KO_reaction_gene_0_0.sort_values(by="growth")
# Out:
#                    ids    growth   status
# 198  {ACACT3r, H2Otex}  0.425541  optimal
# 106    {HACD1, H2Otex}  0.425541  optimal
# 358  {ACACT2r, H2Otex}  0.425541  optimal
# 12     {HACD3, H2Otex}  0.425541  optimal
# 259  {ACACT1r, H2Otex}  0.425541  optimal
# ..                 ...       ...      ...
# 347            {PAI2T}  0.876968  optimal
# 128     {VALTA, PAI2T}  0.876968  optimal
# 356     {PAI2I, VALTA}  0.876968  optimal
# 230     {PAI2I, PAI2T}  0.876968  optimal
# 162            {VALTA}  0.876997  optimal
#
# [378 rows x 3 columns]

# %%
double_KO_reaction_gene_7_7["growth"]=double_KO_reaction_gene_7_7["growth"].round(6)
double_KO_reaction_gene_7_7.sort_values(by="growth")[0:50]
# Out:
#                         ids    growth   status
# 454          {IPDPS, DMPPS}  0.000000  optimal
# 546     {SUCDi, CYTBO3_4pp}  0.720647  optimal
# 232       {SUCDi, NADH16pp}  0.721268  optimal
# 247     {AKGDH, CYTBO3_4pp}  0.749046  optimal
# 707    {SUCOAS, CYTBO3_4pp}  0.751040  optimal
# 500     {HACD2, CYTBO3_4pp}  0.769980  optimal
# 720    {ECOAH3, CYTBO3_4pp}  0.769980  optimal
# 715    {ECOAH2, CYTBO3_4pp}  0.769980  optimal
# 696   {ACACT3r, CYTBO3_4pp}  0.769980  optimal
# 484   {ACACT2r, CYTBO3_4pp}  0.769980  optimal
# 313    {ECOAH1, CYTBO3_4pp}  0.769980  optimal
# 389     {CYTBO3_4pp, HACD3}  0.769980  optimal
# 774     {HACD1, CYTBO3_4pp}  0.769980  optimal
# 159   {CYTBO3_4pp, ACACT1r}  0.769980  optimal
# 403     {HACD4, CYTBO3_4pp}  0.772118  optimal
# 763    {ECOAH4, CYTBO3_4pp}  0.772118  optimal
# 461   {CYTBO3_4pp, ACACT4r}  0.772118  optimal
# 146   {ACACT5r, CYTBO3_4pp}  0.773004  optimal
# 544    {ECOAH5, CYTBO3_4pp}  0.773004  optimal
# 138     {HACD5, CYTBO3_4pp}  0.773004  optimal
# 743     {HACD6, CYTBO3_4pp}  0.773891  optimal
# 565    {ECOAH6, CYTBO3_4pp}  0.773891  optimal
# 427   {ACACT6r, CYTBO3_4pp}  0.773891  optimal
# 340     {HACD7, CYTBO3_4pp}  0.776402  optimal
# 81    {ACACT7r, CYTBO3_4pp}  0.776402  optimal
# 805    {ECOAH7, CYTBO3_4pp}  0.776402  optimal
# 617  {CTECOAI7, CYTBO3_4pp}  0.776958  optimal
# 108     {Kt2pp, CYTBO3_4pp}  0.777103  optimal
# 401     {TRPS3, CYTBO3_4pp}  0.777366  optimal
# 792   {CYTBO3_4pp, RNTR1c2}  0.777591  optimal
# 101   {CYTBO3_4pp, RNTR2c2}  0.777591  optimal
# 816   {RNTR3c2, CYTBO3_4pp}  0.777591  optimal
# 781       {PPM, CYTBO3_4pp}  0.777612  optimal
# 144     {CYTBO3_4pp, PUNP1}  0.777612  optimal
# 158    {PPPGO3, CYTBO3_4pp}  0.777613  optimal
# 272            {CYTBO3_4pp}  0.777614  optimal
# 765  {NADH16pp, CYTBO3_4pp}  0.777614  optimal
# 245  {PROt2rpp, CYTBO3_4pp}  0.777614  optimal
# 166   {RNTR4c2, CYTBO3_4pp}  0.777614  optimal
# 650     {IPDPS, CYTBO3_4pp}  0.777614  optimal
# 324     {CYTBO3_4pp, DMPPS}  0.777614  optimal
# 191     {CYTBO3_4pp, VALTA}  0.777614  optimal
# 119          {HACD1, SUCDi}  0.836120  optimal
# 268        {SUCDi, ACACT1r}  0.836120  optimal
# 630         {ECOAH3, SUCDi}  0.836120  optimal
# 624         {ECOAH2, SUCDi}  0.836120  optimal
# 466          {SUCDi, HACD3}  0.836120  optimal
# 567        {ACACT3r, SUCDi}  0.836120  optimal
# 803          {HACD2, SUCDi}  0.836120  optimal
# 203         {ECOAH1, SUCDi}  0.836120  optimal

# %%
double_KO_reaction_SRR1536433.sort_values(by="growth")[0:30]
# Out:
#                 ids    growth   status
# 5  {ATPS4rpp, GAPD}  0.027338  optimal
# 4  {ATPS4rpp, E4PD}  0.284932  optimal
# 0        {ATPS4rpp}  0.284933  optimal
# 1      {GAPD, E4PD}  0.759441  optimal
# 3            {GAPD}  0.759443  optimal
# 2            {E4PD}  0.876996  optimal

# %% [markdown]
# Non-essential GENES single KO from my datasets, FBA

# %%
essential_genes=cobra.flux_analysis.variability.find_essential_genes(model_LB)
essential_genes_id=[]
for i in essential_genes:
    essential_genes_id.append(i.id)

len(essential_genes_id)
# Out:
# 117

# %%
with open('essential_genes.txt', 'w') as f:
    for i in essential_genes_id:
        f.write(i)
        f.write('\n')

# %%
def non_essential_genes(gene_list):
    non_essential_genes=[]
    for i in gene_list:
        if i not in essential_genes_id:
            non_essential_genes.append(i)
    non_essential_genes = [x for x in non_essential_genes if x.strip()]
    return (non_essential_genes)

# %%
non_essential_genes_genes_0_0 = non_essential_genes(gene_list_genes_0_0)
non_essential_genes_genes_7_7 = non_essential_genes(gene_list_genes_7_7)
non_essential_genes_genes_4_4 = non_essential_genes(gene_list_genes_4_4)
non_essential_genes_genes_6_6 = non_essential_genes(gene_list_genes_6_6)
non_essential_genes_BSeq1 = non_essential_genes(gene_list_BSeq1)
non_essential_genes_BSeq2 = non_essential_genes(gene_list_BSeq2)
non_essential_genes_SRR1536433 = non_essential_genes(gene_list_SRR1536433)

# %%
def single_gene_KO(model_LB,non_essential_genes,active_reactions):
    single_KO_gene=single_gene_deletion(model,non_essential_genes)
    def get_reactions(gene_ids):
        reactions = set()
        for gene in gene_ids:
            gene_obj = model_LB.genes.get_by_id(gene)
            reactions |= set(gene_obj.reactions)
        return list(reactions)
    
    single_KO_gene['reactions'] = single_KO_gene['ids'].apply(get_reactions)
    def get_reactions_ids(reaction_list):
        reactions = set()
        reactions_id=[]
        for n in range(len(reaction_list)):
            id=reaction_list[n].id
            if id in active_reactions:
                reactions_id.append(id)
        return list(reactions_id)

    single_KO_gene['reactions_id'] = single_KO_gene['reactions'].apply(get_reactions_ids)
    single_KO_gene['reactions_id_sorted'] = single_KO_gene['reactions_id'].apply(lambda x: sorted(x))
    single_KO_reactions  = single_KO_gene.drop(single_KO_gene[single_KO_gene['reactions_id_sorted'].apply(lambda x: len(x) == 0)].index)
    single_KO_reactions = single_KO_reactions.assign(reactions_id_tuple=single_KO_reactions['reactions_id_sorted'].apply(tuple))
    single_KO_reactions = single_KO_reactions.groupby('reactions_id_tuple').agg({'ids': list, 'growth': 'max'}).reset_index()
    single_KO_reactions.columns = ['reactions_id_sorted', 'ids', 'growth']
    single_KO_reactions = single_KO_reactions.rename(columns={'ids': 'genes'})
    single_KO_reactions = single_KO_reactions.rename(columns={'reactions_id_sorted': 'reaction/s'})      
    single_KO_reactions['growth'] = single_KO_reactions['growth'].round(6)
    single_KO_reactions = single_KO_reactions[single_KO_reactions['growth'] < 0.876]
    return (single_KO_reactions)

# %%
single_gene_KO(cobra_model,non_essential_genes_BSeq1,active_reactionsFBA)

# %%
single_gene_KO(cobra_model,non_essential_genes_BSeq2,active_reactionsFBA)

# %%
single_gene_KO(cobra_model,non_essential_genes_genes_0_0,active_reactionsFBA)
# Out:
# C:\Users\e\AppData\Local\Temp\ipykernel_6844\2641299889.py:35: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   common_reactions = single_KO_reactions.groupby('growth')['reactions_id_sorted'].apply(find_common_reaction)
# Empty DataFrame
# Columns: [genes, growth, reaction/s]
# Index: []

# %%
single_gene_KO(cobra_model,non_essential_genes_genes_6_6,active_reactionsFBA)
# Out:
#       reaction/s                                              genes    growth
# 2  (CYTBO3_4pp,)               [{b0431}, {b0430}, {b0432}, {b0429}]  0.777614
# 3    (NADH16pp,)  [{b2285}, {b2286}, {b2282}, {b2283}, {b2279}, ...  0.758643

# %%
single_gene_KO(cobra_model,non_essential_genes_genes_4_4,active_reactionsFBA)
# Out:
# C:\Users\e\AppData\Local\Temp\ipykernel_14080\465558763.py:32: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   common_reactions = single_KO_reactions.groupby('growth')['reactions_id_sorted'].apply(find_common_reaction)
# Empty DataFrame
# Columns: [growth, reaction/s]
# Index: []

# %%
single_gene_KO(cobra_model,non_essential_genes_genes_7_7,active_reactionsFBA)
# Out:
#                                   reactions_id_sorted  \
# 2                                            (AKGDH,)
# 3   (CTECOAI7, ECOAH1, ECOAH2, ECOAH3, ECOAH4, ECO...
# 4                                       (CYTBO3_4pp,)
# 6                                         (NADH16pp,)
# 11                                           (SUCDi,)
# 12                                          (SUCOAS,)
#
#                                                   ids    growth
# 2                                  [{b0726}, {b0727}]  0.863370
# 3                                           [{b3846}]  0.874523
# 4                [{b0431}, {b0430}, {b0432}, {b0429}]  0.777614
# 6   [{b2285}, {b2286}, {b2282}, {b2279}, {b2283}, ...  0.758643
# 11               [{b0724}, {b0722}, {b0721}, {b0723}]  0.841816
# 12                                 [{b0728}, {b0729}]  0.865115

# %%
single_gene_KO(cobra_model,non_essential_genes_SRR1536433,active_reactionsFBA)
# Out:
#   reactions_id_sorted      genes    growth
# 1        (E4PD, GAPD)  [{b1779}]  0.759443

# %% [markdown]
# Double GENE KO, associated reactions

# %%
#Doing the KO of two genes, depending on the GPR, the associated reaction/s will be set to bounds=0. Retrieve these associated reactions
#when the resulting growth rate of two or more  double gene KOs is identical compare the KO reactions associated and find the common one/s
#in all cases and retrieve only once the growth rate of the associated reaction/s KO. Do not retrieve the KOs that don't influience the 
#growth rate

cobra_model=model_LB.copy()

def double_gene_KO(model_LB,non_essential_genes,active_reactions):
    double_KO_gene=double_gene_deletion(model,non_essential_genes)
    def get_reactions(gene_ids):
        reactions = set()
        for gene in gene_ids:
            gene_obj = model_LB.genes.get_by_id(gene)
            reactions |= set(gene_obj.reactions)
        return list(reactions)
    
    double_KO_gene['reactions'] = double_KO_gene['ids'].apply(get_reactions)
    def get_reactions_ids(reaction_list):
        reactions = set()
        reactions_id=[]
        for n in range(len(reaction_list)):
            id=reaction_list[n].id
            if id in active_reactions:
                reactions_id.append(id)
        return list(reactions_id)

    double_KO_gene['reactions_id'] = double_KO_gene['reactions'].apply(get_reactions_ids)
    double_KO_gene['reactions_id_sorted'] = double_KO_gene['reactions_id'].apply(lambda x: sorted(x))
    double_KO_reactions = double_KO_gene.drop_duplicates(subset='reactions_id_sorted', keep='first')[["growth","reactions_id_sorted"]]
    double_KO_reactions['growth'] = double_KO_reactions['growth'].round(6)
    double_KO_reactions = double_KO_reactions[double_KO_reactions['growth'] != 0.876997]

    def find_common_reaction(x):
        reactions = set(x.iloc[0])
        for r in x:
            reactions = reactions.intersection(set(r))
        return reactions

    common_reactions = double_KO_reactions.groupby('growth')['reactions_id_sorted'].apply(find_common_reaction)
    final_table = pd.DataFrame({'growth': common_reactions.index, 'reaction/s': common_reactions.values})

    return (final_table)

# %%
double_gene_KO(cobra_model,non_essential_genes_genes_0_0,active_reactionsFBA)
# Out:
# Empty DataFrame
# Columns: [reactions_id_sorted, genes, growth]
# Index: []

# %%
double_gene_KO(cobra_model,non_essential_genes_BSeq1,active_reactionsFBA)
# Out:
# Empty DataFrame
# Columns: [reactions_id_sorted, genes, growth]
# Index: []

# %%
double_gene_KO(cobra_model,non_essential_genes_BSeq2,active_reactionsFBA)

# %%
double_gene_KO(cobra_model,non_essential_genes_SRR1536433,active_reactionsFBA)
# Out:
#      growth              reaction/s
# 0  0.027338  {ATPS4rpp, E4PD, GAPD}
# 1  0.759443            {E4PD, GAPD}

# %%
double_gene_KO(cobra_model,non_essential_genes_genes_7_7,active_reactionsFBA)
# Out:
#       growth                                         reaction/s
# 0   0.600788                             {CYTBO3_4pp, NADH16pp}
# 1   0.710456                                  {SUCDi, NADH16pp}
# 2   0.720647                                {CYTBO3_4pp, SUCDi}
# 3   0.735879                                  {AKGDH, NADH16pp}
# 4   0.737321                                 {NADH16pp, SUCOAS}
# 5   0.749046                                {CYTBO3_4pp, AKGDH}
# 6   0.751040                               {CYTBO3_4pp, SUCOAS}
# 7   0.755651  {HACD4, ECOAH1, HACD2, HACD1, HACD7, ECOAH4, H...
# 8   0.758641                                         {NADH16pp}
# 9   0.758643                                         {NADH16pp}
# 10  0.774996  {CYTBO3_4pp, HACD4, ECOAH1, HACD2, HACD1, HACD...
# 11  0.777521   {CYTBO3_4pp, RNTR2c2, RNTR4c2, RNTR1c2, RNTR3c2}
# 12  0.777612                                       {CYTBO3_4pp}
# 13  0.777614                                       {CYTBO3_4pp}
# 14  0.839696  {HACD4, ECOAH1, HACD2, HACD1, HACD7, ECOAH4, H...
# 15  0.841813                                            {SUCDi}
# 16  0.841816                                            {SUCDi}
# 17  0.861114  {HACD4, ECOAH1, HACD2, HACD1, HACD7, ECOAH4, H...
# 18  0.862850  {HACD4, ECOAH1, HACD2, HACD1, HACD7, ECOAH4, H...
# 19  0.863368                                            {AKGDH}
# 20  0.863370                                            {AKGDH}
# 21  0.865113                                           {SUCOAS}
# 22  0.865115                                           {SUCOAS}
# 23  0.874521  {HACD4, ECOAH1, HACD2, HACD1, HACD7, ECOAH4, H...
# 24  0.874523  {HACD4, ECOAH1, HACD2, HACD1, HACD7, ECOAH4, H...
# 25  0.876907        {RNTR2c2, PUNP1, RNTR4c2, RNTR1c2, RNTR3c2}
# 26  0.876909               {RNTR3c2, RNTR4c2, RNTR1c2, RNTR2c2}
# 27  0.876995                                                 {}

# %%
double_gene_KO(cobra_model,non_essential_genes_genes_4_4,active_reactionsFBA)
# Out:
# Empty DataFrame
# Columns: [reactions_id_sorted, genes, growth]
# Index: []

# %%
double_gene_KO(cobra_model,non_essential_genes_genes_6_6,active_reactionsFBA)
# Out:
#      growth              reaction/s
# 0  0.600788  {CYTBO3_4pp, NADH16pp}
# 1  0.758641              {NADH16pp}
# 2  0.758643              {NADH16pp}
# 3  0.777612            {CYTBO3_4pp}
# 4  0.777614            {CYTBO3_4pp}
# 5  0.876995                      {}

# %% [markdown]
# GENE constraints 0.5 and 0.8

# %%
#Selected genes--> associated reactions--> reactions active in condition FVA 0.5 or 0.8--> 
#set upperbound maximum for all the associated reactions to that gene
def gene_upperbound(gene_from_list):
    reaction_list=[]
    reaction_id=model_LB.genes.get_by_id(gene_from_list).reactions
    for i in reaction_id:
        reaction_list.append(i.id)
    reactions= list(set(reaction_list))
    active=[]
    for i in reactions:
        if i in reaction_list_genes_7_7_active_FVA05_solution.index:
            active.append(reaction_list_genes_7_7_active_FVA05_solution.loc[i])
    model_copy=model.copy()
    active=pd.DataFrame(active)
    if len(active) ==0:
        return
    else:
        for i in active.index:
            max_bound = max(abs(active["maximum"][i]),abs(active["minimum"][i]))
            model_copy.reactions.get_by_id(i).bounds = (max_bound, max_bound)
        print(gene_from_list,active.index,model_copy.optimize().objective_value)

# %%
print(list(map(gene_upperbound, gene_list_genes_7_7)))
# Out:
# b4069 Index(['ACS'], dtype='object') 0.6990716289465003
# b4067 Index(['ACt4pp', 'GLYCLTt4pp'], dtype='object') 0.8769972144269655
# b4382 Index(['DURIPP', 'TMDPP'], dtype='object') 0.32707356748294264
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b4383 Index(['PPM'], dtype='object') 0.0
# b4384 Index(['PUNP1', 'DURIPP'], dtype='object') 0.047681943096397304
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3846 Index(['ECOAH1', 'ECOAH5', 'HACD6', 'HACD4', 'HACD2', 'HACD7', 'HACD1',
#        'CTECOAI6', 'ECOAH4', 'ECOAH6', 'CTECOAI7', 'HACD3', 'HACD5', 'ECOAH2',
#        'ECOAH7', 'ECOAH3'],
#       dtype='object') 0.8769972144269801
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3845 Index(['ACACT6r', 'ACACT2r', 'ACACT3r', 'ACACT5r', 'ACACT4r', 'ACACT7r',
#        'ACACT1r'],
#       dtype='object') 0.876997214426983
# b1109 Index(['NADH10'], dtype='object') 0.7470887518257296
# b4238 Index(['RNTR4c2', 'RNTR3c2', 'RNTR1c2', 'RNTR2c2'], dtype='object') 0.8208525781496331
# b4237 Index(['RNTR4c2', 'RNTR3c2', 'RNTR1c2', 'RNTR2c2'], dtype='object') 0.8208525781496331
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b0180 Index(['3HAD60', '3HAD100', '3HAD120', '3HAD40', '3HAD160', '3HAD121',
#        '3HAD141', '3HAD80', '3HAD140', '3HAD161'],
#       dtype='object') 0.422237661186144
# b2201 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2200 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2199 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2198 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2197 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b0721 Index(['SUCDi'], dtype='object') 0.4401965381915145
# b0722 Index(['SUCDi'], dtype='object') 0.4401965381915145
# b0723 Index(['SUCDi'], dtype='object') 0.4401965381915145
# b0724 Index(['SUCDi'], dtype='object') 0.4401965381915145
# b0726 Index(['AKGDH'], dtype='object') 0.806356777722676
# b0727 Index(['AKGDH'], dtype='object') 0.806356777722676
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3199 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3200 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3201 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# b3849 Index(['Kt2pp'], dtype='object') 0.8769629969948065
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3850 Index(['PPPGO3', 'PPPGO'], dtype='object') 0.0
# b0029 Index(['DMPPS', 'IPDPS'], dtype='object') 0.8769972144269725
# b1261 Index(['TRPS1', 'TRPS3'], dtype='object') 0.0592215699141642
# b1260 Index(['TRPS1', 'TRPS3'], dtype='object') 0.0592215699141642
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b0402 Index(['PROt2rpp'], dtype='object') 0.876988628916501
# b0432 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0431 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0430 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0429 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0595 Index(['ICHORT'], dtype='object') 0.4384986072134932
# b0596 Index(['DHBD'], dtype='object') 0.4384986072134787
# b3770 Index(['VALTA'], dtype='object') 0.8769972144269751
# b2288 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2287 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2286 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2285 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2284 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2283 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2282 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2281 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2280 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2279 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2278 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2277 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2276 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b4464 Index(['HYXNtpp'], dtype='object') 0.8769972144269725
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 result = list(map(gene_upperbound, gene_list_genes_7_7))
#       2 print(result)
#
# Cell In[215], line 5, in gene_upperbound(gene_from_list)
#       3 def gene_upperbound(gene_from_list):
#       4     reaction_list=[]
# ----> 5     reaction_id=model.genes.get_by_id(gene_from_list).reactions
#       6     for i in reaction_id:
#       7         reaction_list.append(i.id)
#
# File c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\core\dictlist.py:75, in DictList.get_by_id(self, id)
#      73 def get_by_id(self, id: Union[Object, str]) -> Object:
#      74     """Return the element with a matching id."""
# ---> 75     return list.__getitem__(self, self._dict[id])
#
# KeyError: ''

# %%
print(list(map(gene_upperbound, gene_list_genes_0_0)))
# Out:
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b2342 Index(['ACACT6r', 'ACACT2r', 'ACACT3r', 'ACACT5r', 'ACACT4r', 'ACACT7r',
#        'ACACT1r'],
#       dtype='object') 0.876997214426983
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b2341 Index(['HACD4', 'ECOAH1', 'HACD2', 'HACD1', 'HACD7', 'ECOAH4', 'HACD3',
#        'HACD5', 'ECOAH2', 'ECOAH7', 'ECOAH5', 'ECOAH6', 'HACD6', 'ECOAH3'],
#       dtype='object') 0.8769972144269801
# b2201 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2200 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2199 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2198 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2197 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b3770 Index(['VALTA'], dtype='object') 0.8769972144269751
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3199 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3200 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b3201 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
print(list(map(gene_upperbound, gene_list_genes_4_4)))
# Out:
# b4382 Index(['DURIPP', 'TMDPP'], dtype='object') 0.32707356748294264
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b4383 Index(['PPM'], dtype='object') 0.0
# b4384 Index(['PUNP1', 'DURIPP'], dtype='object') 0.047681943096397304
# b2201 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2200 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2199 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2198 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2197 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
print(list(map(gene_upperbound, gene_list_genes_6_6)))
# Out:
# b0432 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0431 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0430 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b0429 Index(['CYTBO3_4pp'], dtype='object') 0.4385054007449375
# b4382 Index(['DURIPP', 'TMDPP'], dtype='object') 0.32707356748294264
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b4383 Index(['PPM'], dtype='object') 0.0
# b4384 Index(['PUNP1', 'DURIPP'], dtype='object') 0.047681943096397304
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b0180 Index(['3HAD60', '3HAD100', '3HAD120', '3HAD40', '3HAD160', '3HAD121',
#        '3HAD141', '3HAD80', '3HAD140', '3HAD161'],
#       dtype='object') 0.422237661186144
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b0641 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# b2201 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2200 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2199 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2198 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2197 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2288 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2287 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2286 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2285 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2284 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2283 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2282 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2281 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2280 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2279 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2278 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2277 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# b2276 Index(['NADH16pp'], dtype='object') 0.5898703925135672
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 print(list(map(gene_upperbound, gene_list_genes_6_6)))
#
# Cell In[215], line 5, in gene_upperbound(gene_from_list)
#       3 def gene_upperbound(gene_from_list):
#       4     reaction_list=[]
# ----> 5     reaction_id=model.genes.get_by_id(gene_from_list).reactions
#       6     for i in reaction_id:
#       7         reaction_list.append(i.id)
#
# File c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\core\dictlist.py:75, in DictList.get_by_id(self, id)
#      73 def get_by_id(self, id: Union[Object, str]) -> Object:
#      74     """Return the element with a matching id."""
# ---> 75     return list.__getitem__(self, self._dict[id])
#
# KeyError: ''

# %%
print(list(map(gene_upperbound, gene_list_BSeq1)))
# Out:
# b2201 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2200 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2199 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2198 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2197 Index(['PHEMEabcpp'], dtype='object') 0.4384986072134859
# b2224 Index(['ACACT1r'], dtype='object') 0.4384986072134654
# c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# b0054 Index(['ENLIPAabctex', 'ECA4COLIPAabctex'], dtype='object') 0.0
# b0029 Index(['DMPPS', 'IPDPS'], dtype='object') 0.8769972144269725
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[220], line 1
# ----> 1 print(list(map(gene_upperbound, gene_list_BSeq)))
#
# Cell In[215], line 5, in gene_upperbound(gene_from_list)
#       3 def gene_upperbound(gene_from_list):
#       4     reaction_list=[]
# ----> 5     reaction_id=model.genes.get_by_id(gene_from_list).reactions
#       6     for i in reaction_id:
#       7         reaction_list.append(i.id)
#
# File c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\core\dictlist.py:75, in DictList.get_by_id(self, id)
#      73 def get_by_id(self, id: Union[Object, str]) -> Object:
#      74     """Return the element with a matching id."""
# ---> 75     return list.__getitem__(self, self._dict[id])
#
# KeyError: ''

# %%
print(list(map(gene_upperbound, gene_list_BSeq2)))

# %%
print(list(map(gene_upperbound, gene_list_SRR1536433)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 print(list(map(gene_upperbound, gene_list_SRR1536433)))
#
# Cell In[215], line 5, in gene_upperbound(gene_from_list)
#       3 def gene_upperbound(gene_from_list):
#       4     reaction_list=[]
# ----> 5     reaction_id=model.genes.get_by_id(gene_from_list).reactions
#       6     for i in reaction_id:
#       7         reaction_list.append(i.id)
#
# File c:\Users\e\AppData\Local\Programs\Python\Python311\Lib\site-packages\cobra\core\dictlist.py:75, in DictList.get_by_id(self, id)
#      73 def get_by_id(self, id: Union[Object, str]) -> Object:
#      74     """Return the element with a matching id."""
# ---> 75     return list.__getitem__(self, self._dict[id])
#
# KeyError: ''

# %% [markdown]
# Flux deviations

# %%
import numpy as np
def deviation_reactions (reaction1,solutionFBA,reaction2=None, reaction3=None,reaction4=None,reaction5=None,reaction6=None):
    model_double_KO=model_LB.copy()
    model_double_KO.reactions.get_by_id(reaction1).bounds=(0,0)
    if reaction2 is not None and reaction2 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction2).bounds = (0, 0)
    if reaction3 is not None and reaction3 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction3).bounds = (0, 0)
    if reaction4 is not None and reaction4 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction4).bounds = (0, 0)
    if reaction5 is not None and reaction5 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction5).bounds = (0, 0)
    if reaction6 is not None and reaction6 in model_double_KO.reactions:
        model_double_KO.reactions.get_by_id(reaction6).bounds = (0, 0)
    solutionKO=model_double_KO.optimize()
    names=[]
    distances= []
    fluxes=[]
    new_fluxes=[]
    percentaje=[]
    for flux in range(0,len(solutionKO.fluxes.index)):
        name=solutionKO.fluxes.index[flux]
        distance=solutionKO[flux] - solutionFBA[flux]
        if abs(distance) > abs(solutionFBA[flux])*0.1 and abs(distance) > 0.1:
            names.append(name)
            distances.append(round(distance,6))
            fluxes.append(round(solutionFBA[flux],6))
            new_fluxes.append(round(solutionKO[flux],6))
            if solutionFBA[flux] == 0:
                percent= np.nan
            else:
                percent=solutionKO[flux]*100/solutionFBA[flux]
            percentaje.append(round(percent,6))
    wt_vs_KO={"Reaction":names,"Deviation":distances,"flux":fluxes,"new_flux":new_fluxes,"percentaje":percentaje}
    df=pd.DataFrame(wt_vs_KO, columns=["Reaction","Deviation","percentaje","flux","new_flux"])
    df = df[df['Reaction'] != reaction1]
    df = df[df['Reaction'] != reaction2]
    df = df[df['Reaction'] != reaction3]
    df = df[df['Reaction'] != reaction4]
    df = df[df['Reaction'] != reaction5]
    df = df[df['Reaction'] != reaction6]   
    df=df.set_index("Reaction")
    df = df.sort_values(
    by=['Deviation', 'percentaje'],
    ascending=[False, False],
    key=lambda col:col.abs(),
    na_position='first')
    return df

# %%
deviation_reactions(reaction1="AKGDH",solutionFBA=solutionFBA,reaction2="CYTBO3_4pp")
# Out:
#           Deviation  percentaje       flux   new_flux
# Reaction
# CYTBDpp   55.307027         NaN   0.000000  55.307027
# ATPS4rpp  -9.982717   85.826546  70.432494  60.449776
# NADH16pp   8.374517  122.039917  37.997044  46.371561
# MDH        6.689075  197.160131   6.884588  13.573663
# PDH        6.319658  165.220454   9.689687  16.009345
# ...             ...         ...        ...        ...
# PIt2rpp   -0.123422   85.410355   0.845957   0.722535
# ACLS      -0.111876   85.410355   0.766817   0.654941
# DHAD1     -0.111876   85.410355   0.766817   0.654941
# KARA1      0.111876   85.410355  -0.766817  -0.654941
# ADK3       0.101083   85.410355  -0.692840  -0.591757
#
# [71 rows x 4 columns]

# %%
deviation_reactions(reaction1="E4PD",solutionFBA=solutionFBA,reaction2="GAPD")
# Out:
#                                 Deviation  percentaje      flux  new_flux
# Reaction
# Htex                             1.080150   86.595645 -8.058200 -6.978051
# RPI                              0.871513   39.074748 -1.430463 -0.558950
# TALA                            -0.761793  -24.491739  0.611922 -0.149870
# TKT1                            -0.761793  -24.491739  0.611922 -0.149870
# TKT2                            -0.717381 -157.982817  0.278073 -0.439308
# XYLI2                            0.660937         NaN  0.000000  0.660937
# HEX7                             0.660937         NaN  0.000000  0.660937
# PPA                             -0.411629   86.595645  3.070861  2.659232
# PPM                              0.401357   86.595645 -2.994230 -2.592873
# R1PK                            -0.401278   86.595645  2.993640  2.592362
# R15BPK                          -0.401278   86.595645  2.993640  2.592362
# VALTA                            0.371112   -0.000000 -0.371112  0.000000
# VPAMTr                           0.321367         NaN  0.000000  0.321367
# PRPPS                            0.291637   86.595645 -2.175690 -1.884053
# FADRx                           -0.256964   86.595645  1.917019  1.660055
# ALATA_L                         -0.252968  149.574701 -0.510276 -0.763243
# PSERT                           -0.243448   83.840524  1.506536  1.263088
# PSP_L                           -0.243448   83.840524  1.506536  1.263088
# PGCD                            -0.243448   83.840524  1.506536  1.263088
# MTHFC                           -0.198858   77.057164  0.866753  0.667895
# MTHFD                           -0.198858   77.057164  0.866753  0.667895
# GLNS                            -0.184146   86.595645  1.373778  1.189632
# GHMT2r                          -0.172644   82.352970  0.978319  0.805675
# GARFT                           -0.135054   65.438052  0.390758  0.255705
# ASPK                            -0.125676   86.595645  0.937577  0.811901
# ASAD                             0.125676   86.595645 -0.937577 -0.811901
# BIOMASS_Ec_iML1515_core_75p37M  -0.117556   86.595645  0.876997  0.759441
# EX_pi_e                          0.113395   86.595645 -0.845957 -0.732562
# PItex                           -0.113395   86.595645  0.845957  0.732562
# PIt2rpp                         -0.113395   86.595645  0.845957  0.732562
# ACLS                            -0.102787   86.595645  0.766817  0.664030
# DHAD1                           -0.102787   86.595645  0.766817  0.664030
# KARA1                            0.102787   86.595645 -0.766817 -0.664030

# %%
deviation_reactions(reaction1="NADH16pp",solutionFBA=solutionFBA,reaction2="NADH18pp", reaction3="NADH17pp"
, reaction4="AKGDH")
# Out:
#           Deviation  percentaje      flux   new_flux
# Reaction
# FORtppi   18.639823         NaN  0.000000  18.639823
# PFL       18.638018         NaN  0.000000  18.638018
# FDH4pp    18.636950         NaN  0.000000  18.636950
# GLYCTO2   16.845006         NaN  0.000000  16.845006
# GLYCLTDx  16.845006         NaN  0.000000  16.845006
# ...             ...         ...       ...        ...
# PIt2rpp   -0.136123   83.908968  0.845957   0.709834
# ADK3       0.131366   81.039438 -0.692840  -0.561474
# ACLS      -0.123389   83.908968  0.766817   0.643429
# DHAD1     -0.123389   83.908968  0.766817   0.643429
# KARA1      0.123389   83.908968 -0.766817  -0.643429
#
# [78 rows x 4 columns]

# %%
deviation_reactions(reaction1="NADH16pp",solutionFBA=solutionFBA,reaction2="NADH18pp", reaction3="NADH17pp"
, reaction4="SUCOAS")[0:50]
# Out:
#             Deviation  percentaje       flux   new_flux
# Reaction
# FORtppi     18.171711         NaN   0.000000  18.171711
# PFL         18.169902         NaN   0.000000  18.169902
# FDH4pp      18.168832         NaN   0.000000  18.168832
# NADH5       17.225886         NaN   0.000000  17.225886
# CO2tpp      12.438658   48.179370 -24.003293 -11.564635
# CYTBO3_4pp  12.063401  127.258049  44.256288  56.319688
# MDH2        11.815238         NaN   0.000000  11.815238
# ATPS4rpp   -11.521706   83.641490  70.432494  58.910787
# PDH         -9.689687    0.000000   9.689687   0.000000
# MDH         -6.884588    0.000000   6.884588   0.000000
# ICL          6.100532         NaN   0.000000   6.100532
# MALS         6.100532         NaN   0.000000   6.100532
# O2tpp        6.031124  127.250987  22.131763  28.162887
# O2tex        6.031124  127.250987  22.131763  28.162887
# EX_o2_e     -6.031124  127.250987 -22.131763 -28.162887
# EX_co2_e     5.733053  123.884442  24.003293  29.736346
# CO2tex      -5.733053  123.884442 -24.003293 -29.736346
# AKGDH       -5.583000    6.483395   5.970063   0.387063
# PYK          4.072011  278.925464   2.275814   6.347824
# ME2          3.917896         NaN   0.000000   3.917896
# ICDHyr      -3.357043   51.438710   6.913003   3.555960
# SUCDi        2.849063  145.507315   6.260670   9.109732
# FUM          2.748014  139.915444   6.884588   9.632602
# CS           2.743489  139.685915   6.913003   9.656492
# ACONTb       2.743489  139.685915   6.913003   9.656492
# ACONTa       2.743489  139.685915   6.913003   9.656492
# PPC         -2.596107    0.000000   2.596107   0.000000
# ABTA         2.376135         NaN   0.000000   2.376135
# GLUDC        2.376135         NaN   0.000000   2.376135
# SSALy        2.376135         NaN   0.000000   2.376135
# PGI          2.355366  130.810714   7.644634  10.000000
# PGL         -2.355366   -0.000000   2.355366  -0.000000
# GND         -2.355366    0.000000   2.355366   0.000000
# G6PDH2r     -2.355366   -0.000000   2.355366  -0.000000
# NH4tpp      -1.508487   84.073397   9.471495   7.963008
# NH4tex      -1.508487   84.073397   9.471495   7.963008
# EX_nh4_e     1.508487   84.073397  -9.471495  -7.963008
# RPE         -1.461904  -64.259633   0.889996  -0.571908
# EX_h_e      -1.283398   84.073397   8.058200   6.774803
# Htex         1.283398   84.073397  -8.058200  -6.774803
# GLUDy        1.193510   84.085455  -7.499495  -6.305984
# TPI          0.926335  111.122826   8.328232   9.254566
# FBA          0.906660  110.727468   8.451764   9.358424
# PFK          0.906660  110.727468   8.451764   9.358424
# RPI          0.887903   37.928965  -1.430463  -0.542560
# TALA        -0.757537  -23.796288   0.611922  -0.145615
# TKT1        -0.757537  -23.796288   0.611922  -0.145615
# TKT2        -0.704366 -153.302455   0.278073  -0.426293
# PPM          0.496799   83.408110  -2.994230  -2.497431
# R1PK        -0.496705   83.407979   2.993640   2.496934

# %%
deviation_reactions(reaction1="CYTBO3_4pp",solutionFBA=solutionFBA)
# Out:
#           Deviation  percentaje       flux   new_flux
# Reaction
# CYTBDpp   52.839704         NaN   0.000000  52.839704
# ATPS4rpp -12.643599   82.048627  70.432494  57.788894
# NADH16pp   6.573001  117.298717  37.997044  44.570045
# O2tpp      4.291298  119.389770  22.131763  26.423061
# O2tex      4.291298  119.389770  22.131763  26.423061
# EX_o2_e   -4.291298  119.389770 -22.131763 -26.423061
# EX_co2_e   4.079213  116.994388  24.003293  28.082506
# CO2tpp    -4.079213  116.994388 -24.003293 -28.082506
# CO2tex    -4.079213  116.994388 -24.003293 -28.082506
# SUCOAS    -2.095357  138.030501  -5.509676  -7.605033
# AKGDH      2.043186  134.223854   5.970063   8.013248
# SUCDi      2.010253  132.109239   6.260670   8.270923
# MDH        1.939550  128.172342   6.884588   8.824138
# FUM        1.939550  128.172342   6.884588   8.824138
# CS         1.936330  128.009966   6.913003   8.849333
# ICDHyr     1.936330  128.009966   6.913003   8.849333
# ACONTb     1.936330  128.009966   6.913003   8.849333
# ACONTa     1.936330  128.009966   6.913003   8.849333
# PGI        1.626776  121.279978   7.644634   9.271410
# PGL       -1.626776   30.933186   2.355366   0.728590
# GND       -1.626776   30.933186   2.355366   0.728590
# G6PDH2r   -1.626776   30.933186   2.355366   0.728590
# PDH        1.621671  116.736051   9.689687  11.311358
# PYK        1.328606  158.379389   2.275814   3.604420
# NH4tpp    -1.073327   88.667817   9.471495   8.398168
# NH4tex    -1.073327   88.667817   9.471495   8.398168
# EX_nh4_e   1.073327   88.667817  -9.471495  -8.398168
# RPE       -1.007431  -13.194996   0.889996  -0.117435
# EX_h_e    -0.913170   88.667817   8.058200   7.145030
# Htex       0.913170   88.667817  -8.058200  -7.145030
# GLUDy      0.849856   88.667817  -7.499495  -6.649638
# RPI        0.615390   56.979651  -1.430463  -0.815073
# TALA      -0.522632   14.591871   0.611922   0.089291
# TKT1      -0.522632   14.591871   0.611922   0.089291
# TKT2      -0.484799  -74.342216   0.278073  -0.206726
# VALTA      0.371112   -0.000000  -0.371112   0.000000
# PPA       -0.347996   88.667817   3.070861   2.722865
# PPM        0.339312   88.667817  -2.994230  -2.654918
# R1PK      -0.339245   88.667817   2.993640   2.654395
# R15BPK    -0.339245   88.667817   2.993640   2.654395
# VPAMTr     0.329057         NaN   0.000000   0.329057
# PPC       -0.294196   88.667817   2.596107   2.301912
# ASPTA      0.290976   88.667817  -2.567693  -2.276717
# ALATA_L   -0.271231  153.153917  -0.510276  -0.781507
# PRPPS      0.246553   88.667817  -2.175690  -1.929137
# FADRx     -0.217240   88.667817   1.917019   1.699779
# PSERT     -0.170723   88.667817   1.506536   1.335813
# PSP_L     -0.170723   88.667817   1.506536   1.335813
# PGCD      -0.170723   88.667817   1.506536   1.335813
# GLNS      -0.155679   88.667817   1.373778   1.218099
# GHMT2r    -0.110865   88.667817   0.978319   0.867454
# ASPK      -0.106248   88.667817   0.937577   0.831329
# ASAD       0.106248   88.667817  -0.937577  -0.831329

# %%
deviation_reactions("SUCDi",solutionFBA,reaction2="NADH16pp")
# Out:
#             Deviation  percentaje       flux   new_flux
# Reaction
# NADH17pp    34.513658         NaN   0.000000  34.513658
# CYTBD2pp    34.510842         NaN   0.000000  34.510842
# CYTBO3_4pp -21.061440   52.410288  44.256288  23.194848
# FORtppi     18.140787         NaN   0.000000  18.140787
# FDH4pp      18.140787         NaN   0.000000  18.140787
# ...               ...         ...        ...        ...
# ADK3         0.142515   79.430349  -0.692840  -0.550325
# ACLS        -0.136165   82.242903   0.766817   0.630653
# DHAD1       -0.136165   82.242903   0.766817   0.630653
# KARA1        0.136165   82.242903  -0.766817  -0.630653
# HSDy         0.108719   82.242903  -0.612255  -0.503537
#
# [82 rows x 4 columns]

# %%
deviation_reactions(reaction1="SUCDi",solutionFBA=solutionFBA,reaction2="CYTBO3_4pp")
# Out:
#           Deviation   percentaje      flux   new_flux
# Reaction
# CYTBDpp   57.758751          NaN  0.000000  57.758751
# ASPT      45.876322          NaN  0.000000  45.876322
# ASPTA    -45.418555  1868.847043 -2.567693 -47.986248
# GLUDy    -44.540441   693.912558 -7.499495 -52.039936
# MDH       39.743841   677.287105  6.884588  46.628429
# ...             ...          ...       ...        ...
# ACLS      -0.136708    82.172064  0.766817   0.630110
# DHAD1     -0.136708    82.172064  0.766817   0.630110
# KARA1      0.136708    82.172064 -0.766817  -0.630110
# ADK3       0.123519    82.172064 -0.692840  -0.569321
# HSDy       0.109153    82.172064 -0.612255  -0.503103
#
# [75 rows x 4 columns]

# %%
deviation_reactions(reaction1="PHEMEabcpp",solutionFBA=solutionFBA,reaction2="AACPS3")
# Out:
#            Deviation  percentaje      flux  new_flux
# Reaction
# HACD7      -0.112009   54.067447  0.243854  0.131846
# ACACT7r    -0.112009   54.067447  0.243854  0.131846
# ECOAH7     -0.112009   54.067447  0.243854  0.131846
# FACOAE160  -0.111929    0.000000  0.111929  0.000000
# ACOAD7f     0.111929   -0.000000 -0.111929  0.000000
# AACPS1      0.111862         NaN  0.000000  0.111862
# FACOAE140   0.111862         NaN  0.000000  0.111862
# 3OAR160     0.111862         NaN  0.000000  0.111862
# 3OAS160     0.111862         NaN  0.000000  0.111862
# EAR160x     0.111862         NaN  0.000000  0.111862
# 3HAD160     0.111862         NaN  0.000000  0.111862
# MCOATA      0.111821  263.828925  0.068255  0.180076
# ACCOAC      0.111821  263.824714  0.068257  0.180078
# HCO3E       0.111586  124.206696  0.460971  0.572557

# %% [markdown]
# Flux deviation NOT biomass-related heterogenity reactions

# %%
reactions_expressed_not_biomass_SRR1536433=gene_to_reaction(expressed_not_biomass_SRR1536433)
reactions_expressed_not_biomass_Bseq1=gene_to_reaction(expressed_not_biomass_Bseq1)
reactions_expressed_not_biomass_Bseq2=gene_to_reaction(expressed_not_biomass_Bseq2)
reactions_expressed_not_biomass_0_0=gene_to_reaction(expressed_not_biomass_0_0)
reactions_expressed_not_biomass_7_7=gene_to_reaction(expressed_not_biomass_7_7)
reactions_expressed_not_biomass_4_4=gene_to_reaction(expressed_not_biomass_4_4)
reactions_expressed_not_biomass_6_6=gene_to_reaction(expressed_not_biomass_6_6)

# %%
non_essential_reactions_not_biomass_SRR1536433 =non_essential(reactions_expressed_not_biomass_SRR1536433)
reaction_list_SRR1536433_not_biomass_active =active (non_essential_reactions_not_biomass_SRR1536433,active_reactionsFBA)
non_essential_reactions_not_biomass_Bseq1 =non_essential(reactions_expressed_not_biomass_Bseq1)
reaction_list_Bseq1_not_biomass_active =active (non_essential_reactions_not_biomass_Bseq1,active_reactionsFBA)
non_essential_reactions_not_biomass_Bseq2 =non_essential(reactions_expressed_not_biomass_Bseq2)
reaction_list_Bseq2_not_biomass_active =active (non_essential_reactions_not_biomass_Bseq2,active_reactionsFBA)
non_essential_reactions_not_biomass_0_0 =non_essential(reactions_expressed_not_biomass_0_0)
reaction_list_0_0_not_biomass_active =active (non_essential_reactions_not_biomass_0_0,active_reactionsFBA)
non_essential_reactions_not_biomass_7_7 =non_essential(reactions_expressed_not_biomass_7_7)
reaction_list_7_7_not_biomass_active =active (non_essential_reactions_not_biomass_7_7,active_reactionsFBA)
non_essential_reactions_not_biomass_4_4 =non_essential(reactions_expressed_not_biomass_4_4)
reaction_list_4_4_not_biomass_active =active (non_essential_reactions_not_biomass_4_4,active_reactionsFBA)
non_essential_reactions_not_biomass_6_6 =non_essential(reactions_expressed_not_biomass_6_6)
reaction_list_6_6_not_biomass_active =active (non_essential_reactions_not_biomass_6_6,active_reactionsFBA)

# %%
import itertools
import numpy as np

# %%
def deviation_reactions_pairwise (list_active,solutionFBA):
    combination= []
    for c in itertools.combinations(list_active, 2):
        combination.append(c)
    combinations_array = np.array(combination)
    lista=[]
    for i in range(1,len(combinations_array)):
        model_double_KO=model_LB.copy()
        model_double_KO.reactions.get_by_id(combinations_array[i][0]).bounds=(0,0)
        model_double_KO.reactions.get_by_id(combinations_array[i][1]).bounds=(0,0)
        solutionKO=model_double_KO.optimize()
        names=[]
        distances= []
        for flux in range(0,len(solutionKO.fluxes.index)):
            name=solutionKO.fluxes.index[flux]
            distance=abs(solutionKO[flux] - solutionFBA[flux])
            if distance > abs(solutionFBA[flux])*0.1 and distance > 0.1:
                names.append(name)
                distances.append(distance)
        wt_vs_KO={"Reaction":names,"Deviation":distances}
        df=pd.DataFrame(wt_vs_KO, columns=["Reaction","Deviation"])
        df=df.set_index("Reaction").sort_values(by="Deviation")
        pair=[combinations_array[i][0],combinations_array[i][1]]
        lista.append(pair)
        lista.append(df)
    return lista

# %%
flux_deviation_SRR1536433_not_biomass=deviation_reactions_pairwise(reaction_list_SRR1536433_not_biomass_active,solutionFBA)
flux_deviation_Bseq1_not_biomass=deviation_reactions_pairwise(reaction_list_Bseq1_not_biomass_active,solutionFBA)
flux_deviation_Bseq2_not_biomass=deviation_reactions_pairwise(reaction_list_Bseq2_not_biomass_active,solutionFBA)
flux_deviation_0_0_not_biomass=deviation_reactions_pairwise(reaction_list_0_0_not_biomass_active,solutionFBA)
flux_deviation_7_7_not_biomass=deviation_reactions_pairwise(reaction_list_7_7_not_biomass_active,solutionFBA)
flux_deviation_4_4_not_biomass=deviation_reactions_pairwise(reaction_list_4_4_not_biomass_active,solutionFBA)
flux_deviation_6_6_not_biomass=deviation_reactions_pairwise(reaction_list_6_6_not_biomass_active,solutionFBA)

# %%
flux_deviation_SRR1536433_not_biomass[0:4]
# Out:
# [['GAPD', 'E4PD'],
#            Deviation
#  Reaction
#  ACLS       0.102787
#  DHAD1      0.102787
#  KARA1      0.102787
#  EX_pi_e    0.113395
#  PItex      0.113395
#  ...             ...
#  PGM       16.861985
#  ENO       16.861985
#  GAPD      17.105434
#  PGK       17.105434
#  TPI       17.269003
#
#  [88 rows x 1 columns],
#  ['ATPS4rpp', 'E4PD'],
#              Deviation
#  Reaction
#  CYTK1        0.107166
#  PPNDH        0.109689
#  PHETA1       0.109689
#  EX_k_e       0.115567
#  Ktex         0.115567
#  ...               ...
#  QMO2        32.755910
#  LEUt2rpp    43.937619
#  LEUt3pp     43.937619
#  CYTBO3_4pp  44.256288
#  ATPS4rpp    70.432494
#
#  [200 rows x 1 columns]]
